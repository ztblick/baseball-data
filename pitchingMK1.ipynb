# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#    gamePk                              gameGuid  \
# 0  747298  e5f968e3-58cb-4137-b71a-e7ded3dd5387
#
#                               link gameType season              gameDate  \
# 0  /api/v1.1/game/747298/feed/live        A   2024  2024-07-17T00:00:00Z
#
#   officialDate                                             status  \
# 0   2024-07-16  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                teams  \
# 0  {'away': {'leagueRecord': {'wins': 0, 'losses'...
#
#                                                venue  ... seasonDisplay  \
# 0  {'id': 5325, 'name': 'Globe Life Field', 'link...  ...          2024
#
#    dayNight                           description scheduledInnings  \
# 0     night  94th All-Star Game, in Arlington, TX                9
#
#   reverseHomeAwayStatus inningBreakLength seriesDescription recordSource  \
# 0                 False               120     All-Star Game            S
#
#   ifNecessary ifNecessaryDescription
# 0           N            Normal Game
#
# [1 rows x 27 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
player_df.T
# Out:
#                                                              ID669257  \
# id                                                             669257
# fullName                                                   Will Smith
# link                                            /api/v1/people/669257
# firstName                                                     William
# lastName                                                        Smith
# primaryNumber                                                      16
# birthDate                                                  1995-03-28
# currentAge                                                         29
# birthCity                                                  Louisville
# birthStateProvince                                                 KY
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            195
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                          Will
# useLastName                                                     Smith
# middleName                                                      Dills
# boxscoreName                                              Smith, W.D.
# nickName                                                       Smitty
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2016
# mlbDebutDate                                               2019-05-28
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                              Will Smith
# nameSlug                                            will-smith-669257
# firstLastName                                              Will Smith
# lastFirstName                                             Smith, Will
# lastInitName                                                 Smith, W
# initLastName                                                  W Smith
# fullFMLName                                       William Dills Smith
# fullLFMName                                      Smith, William Dills
# strikeZoneTop                                                    3.27
# strikeZoneBottom                                                 1.49
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID647304  \
# id                                                             647304
# fullName                                                  Josh Naylor
# link                                            /api/v1/people/647304
# firstName                                              Joshua-Douglas
# lastName                                                       Naylor
# primaryNumber                                                      22
# birthDate                                                  1997-06-22
# currentAge                                                         27
# birthCity                                                 Mississauga
# birthStateProvince                                                 ON
# birthCountry                                                   Canada
# height                                                         5' 11"
# weight                                                            250
# active                                                           True
# primaryPosition     {'code': '3', 'name': 'First Base', 'type': 'I...
# useName                                                          Josh
# useLastName                                                    Naylor
# middleName                                                      James
# boxscoreName                                                Naylor, J
# nickName                                                        Naylz
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2019-05-24
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                             Josh Naylor
# nameSlug                                           josh-naylor-647304
# firstLastName                                             Josh Naylor
# lastFirstName                                            Naylor, Josh
# lastInitName                                                Naylor, J
# initLastName                                                 J Naylor
# fullFMLName                               Joshua-Douglas James Naylor
# fullLFMName                              Naylor, Joshua-Douglas James
# strikeZoneTop                                                    3.15
# strikeZoneBottom                                                 1.49
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID694973  \
# id                                                             694973
# fullName                                                  Paul Skenes
# link                                            /api/v1/people/694973
# firstName                                                        Paul
# lastName                                                       Skenes
# primaryNumber                                                      30
# birthDate                                                  2002-05-29
# currentAge                                                         22
# birthCity                                                   Fullerton
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 6"
# weight                                                            235
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Paul
# useLastName                                                    Skenes
# middleName                                                      David
# boxscoreName                                                   Skenes
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2023
# mlbDebutDate                                               2024-05-11
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Paul Skenes
# nameSlug                                           paul-skenes-694973
# firstLastName                                             Paul Skenes
# lastFirstName                                            Skenes, Paul
# lastInitName                                                Skenes, P
# initLastName                                                 P Skenes
# fullFMLName                                         Paul David Skenes
# fullLFMName                                        Skenes, Paul David
# strikeZoneTop                                                   3.656
# strikeZoneBottom                                                1.677
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID666142  \
# id                                                             666142
# fullName                                                  Cole Ragans
# link                                            /api/v1/people/666142
# firstName                                                        Cole
# lastName                                                       Ragans
# primaryNumber                                                      55
# birthDate                                                  1997-12-12
# currentAge                                                         26
# birthCity                                               Crawfordville
# birthStateProvince                                                 FL
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Cole
# useLastName                                                    Ragans
# middleName                                                     Gatlin
# boxscoreName                                                   Ragans
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2016
# mlbDebutDate                                               2022-08-04
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                             Cole Ragans
# nameSlug                                           cole-ragans-666142
# firstLastName                                             Cole Ragans
# lastFirstName                                            Ragans, Cole
# lastInitName                                                Ragans, C
# initLastName                                                 C Ragans
# fullFMLName                                        Cole Gatlin Ragans
# fullLFMName                                       Ragans, Cole Gatlin
# strikeZoneTop                                                   3.549
# strikeZoneBottom                                                1.627
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID668881  \
# id                                                             668881
# fullName                                                Hunter Greene
# link                                            /api/v1/people/668881
# firstName                                                   Christian
# lastName                                                       Greene
# primaryNumber                                                      21
# birthDate                                                  1999-08-06
# currentAge                                                         24
# birthCity                                                 Los Angeles
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 5"
# weight                                                            242
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Hunter
# useLastName                                                    Greene
# middleName                                                     Hunter
# boxscoreName                                                Greene, H
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2017
# mlbDebutDate                                               2022-04-10
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                           Hunter Greene
# nameSlug                                         hunter-greene-668881
# firstLastName                                           Hunter Greene
# lastFirstName                                          Greene, Hunter
# lastInitName                                                Greene, H
# initLastName                                                 H Greene
# fullFMLName                                   Christian Hunter Greene
# fullLFMName                                  Greene, Christian Hunter
# strikeZoneTop                                                   3.575
# strikeZoneBottom                                                1.681
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID682829  \
# id                                                             682829
# fullName                                              Elly De La Cruz
# link                                            /api/v1/people/682829
# firstName                                                        Elly
# lastName                                                   De La Cruz
# primaryNumber                                                      44
# birthDate                                                  2002-01-11
# currentAge                                                         22
# birthCity                                       Sabana Grande de Boya
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 5"
# weight                                                            200
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                          Elly
# useLastName                                                De La Cruz
# middleName                                                    Antonio
# boxscoreName                                            De La Cruz, E
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                         NaN
# mlbDebutDate                                               2023-06-06
# batSide                        {'code': 'S', 'description': 'Switch'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                         Elly De La Cruz
# nameSlug                                       elly-de-la-cruz-682829
# firstLastName                                         Elly De La Cruz
# lastFirstName                                        De La Cruz, Elly
# lastInitName                                            De La Cruz, E
# initLastName                                             E De La Cruz
# fullFMLName                                   Elly Antonio De La Cruz
# fullLFMName                                  De La Cruz, Elly Antonio
# strikeZoneTop                                                    3.64
# strikeZoneBottom                                                 1.72
# nameMatrilineal                                               Sanchez
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID671218  \
# id                                                             671218
# fullName                                                 Heliot Ramos
# link                                            /api/v1/people/671218
# firstName                                                      Heliot
# lastName                                                        Ramos
# primaryNumber                                                      17
# birthDate                                                  1999-09-07
# currentAge                                                         24
# birthCity                                                     Humacao
# birthStateProvince                                                NaN
# birthCountry                                              Puerto Rico
# height                                                         5' 11"
# weight                                                            188
# active                                                           True
# primaryPosition     {'code': '8', 'name': 'Outfielder', 'type': 'O...
# useName                                                        Heliot
# useLastName                                                     Ramos
# middleName                                                     Lemuel
# boxscoreName                                                    Ramos
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2017
# mlbDebutDate                                               2022-04-10
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Heliot Ramos
# nameSlug                                          heliot-ramos-671218
# firstLastName                                            Heliot Ramos
# lastFirstName                                           Ramos, Heliot
# lastInitName                                                 Ramos, H
# initLastName                                                  H Ramos
# fullFMLName                                       Heliot Lemuel Ramos
# fullLFMName                                      Ramos, Heliot Lemuel
# strikeZoneTop                                                    3.17
# strikeZoneBottom                                                 1.51
# nameMatrilineal                                                Lebron
# pronunciation                                             Like Elliot
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID650911  \
# id                                                             650911
# fullName                                           Cristopher Sánchez
# link                                            /api/v1/people/650911
# firstName                                                  Cristopher
# lastName                                                      Sánchez
# primaryNumber                                                      61
# birthDate                                                  1996-12-12
# currentAge                                                         27
# birthCity                                                   La Romana
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 1"
# weight                                                            165
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                    Cristopher
# useLastName                                                   Sánchez
# middleName                                                     Alexis
# boxscoreName                                               Sánchez, C
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2021-06-06
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                      Cristopher Sánchez
# nameSlug                                    cristopher-sanchez-650911
# firstLastName                                      Cristopher Sánchez
# lastFirstName                                     Sánchez, Cristopher
# lastInitName                                               Sánchez, C
# initLastName                                                C Sánchez
# fullFMLName                                 Cristopher Alexis Sánchez
# fullLFMName                                Sánchez, Cristopher Alexis
# strikeZoneTop                                                   3.411
# strikeZoneBottom                                                1.565
# nameMatrilineal                                                Valera
# pronunciation                                          KRISS-tuh-furr
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID669373  \
# id                                                             669373
# fullName                                                 Tarik Skubal
# link                                            /api/v1/people/669373
# firstName                                                       Tarik
# lastName                                                       Skubal
# primaryNumber                                                      29
# birthDate                                                  1996-11-20
# currentAge                                                         27
# birthCity                                                     Hayward
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 3"
# weight                                                            240
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Tarik
# useLastName                                                    Skubal
# middleName                                                     Daniel
# boxscoreName                                                   Skubal
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2018
# mlbDebutDate                                               2020-08-18
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                            Tarik Skubal
# nameSlug                                          tarik-skubal-669373
# firstLastName                                            Tarik Skubal
# lastFirstName                                           Skubal, Tarik
# lastInitName                                                Skubal, T
# initLastName                                                 T Skubal
# fullFMLName                                       Tarik Daniel Skubal
# fullLFMName                                      Skubal, Tarik Daniel
# strikeZoneTop                                                    3.49
# strikeZoneBottom                                                1.601
# nameMatrilineal                                                   NaN
# pronunciation                                        Tare-ick sku-ble
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID547180  ...  \
# id                                                             547180  ...
# fullName                                                 Bryce Harper  ...
# link                                            /api/v1/people/547180  ...
# firstName                                                       Bryce  ...
# lastName                                                       Harper  ...
# primaryNumber                                                       3  ...
# birthDate                                                  1992-10-16  ...
# currentAge                                                         31  ...
# birthCity                                                   Las Vegas  ...
# birthStateProvince                                                 NV  ...
# birthCountry                                                      USA  ...
# height                                                          6' 3"  ...
# weight                                                            210  ...
# active                                                           True  ...
# primaryPosition     {'code': '3', 'name': 'First Base', 'type': 'I...  ...
# useName                                                         Bryce  ...
# useLastName                                                    Harper  ...
# middleName                                                   Aron Max  ...
# boxscoreName                                                   Harper  ...
# nickName                                                         Harp  ...
# gender                                                              M  ...
# isPlayer                                                         True  ...
# isVerified                                                       True  ...
# draftYear                                                        2010  ...
# mlbDebutDate                                               2012-04-28  ...
# batSide                          {'code': 'L', 'description': 'Left'}  ...
# pitchHand                       {'code': 'R', 'description': 'Right'}  ...
# nameFirstLast                                            Bryce Harper  ...
# nameSlug                                          bryce-harper-547180  ...
# firstLastName                                            Bryce Harper  ...
# lastFirstName                                           Harper, Bryce  ...
# lastInitName                                                Harper, B  ...
# initLastName                                                 B Harper  ...
# fullFMLName                                     Bryce Aron Max Harper  ...
# fullLFMName                                    Harper, Bryce Aron Max  ...
# strikeZoneTop                                                    3.25  ...
# strikeZoneBottom                                                 1.69  ...
# nameMatrilineal                                                   NaN  ...
# pronunciation                                               HARR-purr  ...
# nameTitle                                                         NaN  ...
# nameSuffix                                                        NaN  ...
#
#                                                              ID621381  \
# id                                                             621381
# fullName                                                  Matt Strahm
# link                                            /api/v1/people/621381
# firstName                                                     Matthew
# lastName                                                       Strahm
# primaryNumber                                                      25
# birthDate                                                  1991-11-12
# currentAge                                                         32
# birthCity                                                  West Fargo
# birthStateProvince                                                 ND
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Matt
# useLastName                                                    Strahm
# middleName                                                      Scott
# boxscoreName                                                   Strahm
# nickName                                                      Strahmy
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2012
# mlbDebutDate                                               2016-07-31
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                             Matt Strahm
# nameSlug                                           matt-strahm-621381
# firstLastName                                             Matt Strahm
# lastFirstName                                            Strahm, Matt
# lastInitName                                                Strahm, M
# initLastName                                                 M Strahm
# fullFMLName                                      Matthew Scott Strahm
# fullLFMName                                     Strahm, Matthew Scott
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nameMatrilineal                                                   NaN
# pronunciation                                                  STRAWM
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID606192  \
# id                                                             606192
# fullName                                            Teoscar Hernández
# link                                            /api/v1/people/606192
# firstName                                                     Teoscar
# lastName                                                    Hernández
# primaryNumber                                                      37
# birthDate                                                  1992-10-15
# currentAge                                                         31
# birthCity                                                       Cotui
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 2"
# weight                                                            215
# active                                                           True
# primaryPosition     {'code': '8', 'name': 'Outfielder', 'type': 'O...
# useName                                                       Teoscar
# useLastName                                                 Hernández
# middleName                                                       Jose
# boxscoreName                                             Hernández, T
# nickName                                                    Mr. Seeds
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2016-08-12
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                       Teoscar Hernández
# nameSlug                                     teoscar-hernandez-606192
# firstLastName                                       Teoscar Hernández
# lastFirstName                                      Hernández, Teoscar
# lastInitName                                             Hernández, T
# initLastName                                              T Hernández
# fullFMLName                                    Teoscar Jose Hernández
# fullLFMName                                   Hernández, Teoscar Jose
# strikeZoneTop                                                    3.55
# strikeZoneBottom                                                 1.62
# nameMatrilineal                                                   NaN
# pronunciation                                               tay-oscar
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID662253  \
# id                                                             662253
# fullName                                                 Andrés Muñoz
# link                                            /api/v1/people/662253
# firstName                                                      Andrés
# lastName                                                        Muñoz
# primaryNumber                                                      75
# birthDate                                                  1999-01-16
# currentAge                                                         25
# birthCity                                                  Los Mochis
# birthStateProvince                                            Sinaloa
# birthCountry                                                   Mexico
# height                                                          6' 2"
# weight                                                            222
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Andrés
# useLastName                                                     Muñoz
# middleName                                                   Clemente
# boxscoreName                                                 Muñoz, A
# nickName                                                     El Plebe
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2019-07-12
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Andrés Muñoz
# nameSlug                                          andres-munoz-662253
# firstLastName                                            Andrés Muñoz
# lastFirstName                                           Muñoz, Andrés
# lastInitName                                                 Muñoz, A
# initLastName                                                  A Muñoz
# fullFMLName                                     Andrés Clemente Muñoz
# fullLFMName                                    Muñoz, Andrés Clemente
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nameMatrilineal                                               Apodaca
# pronunciation                                      on-DRACE moon-yoce
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID680776  \
# id                                                             680776
# fullName                                                 Jarren Duran
# link                                            /api/v1/people/680776
# firstName                                                      Jarren
# lastName                                                        Duran
# primaryNumber                                                      16
# birthDate                                                  1996-09-05
# currentAge                                                         27
# birthCity                                                      Corona
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            205
# active                                                           True
# primaryPosition     {'code': '7', 'name': 'Outfielder', 'type': 'O...
# useName                                                        Jarren
# useLastName                                                     Duran
# middleName                                                    William
# boxscoreName                                                Duran, Ja
# nickName                                                          NaN
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2018
# mlbDebutDate                                               2021-07-17
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Jarren Duran
# nameSlug                                          jarren-duran-680776
# firstLastName                                            Jarren Duran
# lastFirstName                                           Duran, Jarren
# lastInitName                                                 Duran, J
# initLastName                                                  J Duran
# fullFMLName                                      Jarren William Duran
# fullLFMName                                     Duran, Jarren William
# strikeZoneTop                                                    3.61
# strikeZoneBottom                                                 1.72
# nameMatrilineal                                                   NaN
# pronunciation                                                 duh-ran
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID665489  \
# id                                                             665489
# fullName                                        Vladimir Guerrero Jr.
# link                                            /api/v1/people/665489
# firstName                                                    Vladimir
# lastName                                                     Guerrero
# primaryNumber                                                      27
# birthDate                                                  1999-03-16
# currentAge                                                         25
# birthCity                                                    Montreal
# birthStateProvince                                                 QC
# birthCountry                                                   Canada
# height                                                          6' 2"
# weight                                                            245
# active                                                           True
# primaryPosition     {'code': '3', 'name': 'First Base', 'type': 'I...
# useName                                                      Vladimir
# useLastName                                              Guerrero Jr.
# middleName                                                        NaN
# boxscoreName                                             Guerrero Jr.
# nickName                                                         El K
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                         NaN
# mlbDebutDate                                               2019-04-26
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                   Vladimir Guerrero Jr.
# nameSlug                                  vladimir-guerrero-jr-665489
# firstLastName                                   Vladimir Guerrero Jr.
# lastFirstName                                  Guerrero Jr., Vladimir
# lastInitName                                          Guerrero Jr., V
# initLastName                                           V Guerrero Jr.
# fullFMLName                                     Vladimir Guerrero Jr.
# fullLFMName                                   Guerrero Jr., Vladimir
# strikeZoneTop                                                    3.68
# strikeZoneBottom                                                 1.69
# nameMatrilineal                                                 Ramos
# pronunciation                                                     NaN
# nameTitle                                                         Jr.
# nameSuffix                                                        Jr.
#
#                                                              ID608331  \
# id                                                             608331
# fullName                                                    Max Fried
# link                                            /api/v1/people/608331
# firstName                                                         Max
# lastName                                                        Fried
# primaryNumber                                                      54
# birthDate                                                  1994-01-18
# currentAge                                                         30
# birthCity                                                Santa Monica
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                           Max
# useLastName                                                     Fried
# middleName                                                     Dorian
# boxscoreName                                                    Fried
# nickName                                                      Maximus
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2012
# mlbDebutDate                                               2017-08-08
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                               Max Fried
# nameSlug                                             max-fried-608331
# firstLastName                                               Max Fried
# lastFirstName                                              Fried, Max
# lastInitName                                                 Fried, M
# initLastName                                                  M Fried
# fullFMLName                                          Max Dorian Fried
# fullLFMName                                         Fried, Max Dorian
# strikeZoneTop                                                    3.37
# strikeZoneBottom                                                 1.56
# nameMatrilineal                                                   NaN
# pronunciation                                                   FREED
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID489446  \
# id                                                             489446
# fullName                                                  Kirby Yates
# link                                            /api/v1/people/489446
# firstName                                                       Kirby
# lastName                                                        Yates
# primaryNumber                                                      39
# birthDate                                                  1987-03-25
# currentAge                                                         37
# birthCity                                                       Lihue
# birthStateProvince                                                 HI
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            205
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Kirby
# useLastName                                                     Yates
# middleName                                                       Kali
# boxscoreName                                                    Yates
# nickName                                                Chubbs Senior
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2005
# mlbDebutDate                                               2014-06-07
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Kirby Yates
# nameSlug                                           kirby-yates-489446
# firstLastName                                             Kirby Yates
# lastFirstName                                            Yates, Kirby
# lastInitName                                                 Yates, K
# initLastName                                                  K Yates
# fullFMLName                                          Kirby Kali Yates
# fullLFMName                                         Yates, Kirby Kali
# strikeZoneTop                                                   3.301
# strikeZoneBottom                                                1.504
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID607208  \
# id                                                             607208
# fullName                                                  Trea Turner
# link                                            /api/v1/people/607208
# firstName                                                        Trea
# lastName                                                       Turner
# primaryNumber                                                       7
# birthDate                                                  1993-06-30
# currentAge                                                         31
# birthCity                                               Boynton Beach
# birthStateProvince                                                 FL
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                          Trea
# useLastName                                                    Turner
# middleName                                                      Vance
# boxscoreName                                                   Turner
# nickName                                                           T2
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2014
# mlbDebutDate                                               2015-08-21
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Trea Turner
# nameSlug                                           trea-turner-607208
# firstLastName                                             Trea Turner
# lastFirstName                                            Turner, Trea
# lastInitName                                                Turner, T
# initLastName                                                 T Turner
# fullFMLName                                         Trea Vance Turner
# fullLFMName                                        Turner, Trea Vance
# strikeZoneTop                                                    3.55
# strikeZoneBottom                                                 1.76
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID542881  \
# id                                                             542881
# fullName                                               Tyler Anderson
# link                                            /api/v1/people/542881
# firstName                                                       Tyler
# lastName                                                     Anderson
# primaryNumber                                                      31
# birthDate                                                  1989-12-30
# currentAge                                                         34
# birthCity                                                   Las Vegas
# birthStateProvince                                                 NV
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Tyler
# useLastName                                                  Anderson
# middleName                                                       John
# boxscoreName                                                 Anderson
# nickName                                                     Mr. Duck
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2011
# mlbDebutDate                                               2016-06-12
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                          Tyler Anderson
# nameSlug                                        tyler-anderson-542881
# firstLastName                                          Tyler Anderson
# lastFirstName                                         Anderson, Tyler
# lastInitName                                              Anderson, T
# initLastName                                               T Anderson
# fullFMLName                                       Tyler John Anderson
# fullLFMName                                      Anderson, Tyler John
# strikeZoneTop                                                    3.56
# strikeZoneBottom                                                 1.68
# nameMatrilineal                                                   NaN
# pronunciation                                                     NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
#                                                              ID670541
# id                                                             670541
# fullName                                               Yordan Alvarez
# link                                            /api/v1/people/670541
# firstName                                                      Yordan
# lastName                                                      Alvarez
# primaryNumber                                                      44
# birthDate                                                  1997-06-27
# currentAge                                                         27
# birthCity                                                   Las Tunas
# birthStateProvince                                                NaN
# birthCountry                                                     Cuba
# height                                                          6' 5"
# weight                                                            237
# active                                                           True
# primaryPosition     {'code': '7', 'name': 'Outfielder', 'type': 'O...
# useName                                                        Yordan
# useLastName                                                   Alvarez
# middleName                                                      Ruben
# boxscoreName                                               Alvarez, Y
# nickName                                                       Yordan
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2019-06-09
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Yordan Alvarez
# nameSlug                                        yordan-alvarez-670541
# firstLastName                                          Yordan Alvarez
# lastFirstName                                         Alvarez, Yordan
# lastInitName                                               Alvarez, Y
# initLastName                                                Y Alvarez
# fullFMLName                                      Yordan Ruben Alvarez
# fullLFMName                                     Alvarez, Yordan Ruben
# strikeZoneTop                                                    3.46
# strikeZoneBottom                                                 1.63
# nameMatrilineal                                               Cadogan
# pronunciation                                                YOR-dahn
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
#
# [41 rows x 64 columns]

# %%
player = statsapi.player_stat_data(694973, group= "pitching", type="season", sportId=1)
player
# Out:
# {'id': 694973,
#  'first_name': 'Paul',
#  'last_name': 'Skenes',
#  'active': True,
#  'current_team': 'Pittsburgh Pirates',
#  'position': 'P',
#  'nickname': None,
#  'last_played': None,
#  'mlb_debut': '2024-05-11',
#  'bat_side': 'Right',
#  'pitch_hand': 'Right',
#  'stats': [{'type': 'season',
#    'group': 'pitching',
#    'season': '2024',
#    'stats': {'gamesPlayed': 11,
#     'gamesStarted': 11,
#     'groundOuts': 58,
#     'airOuts': 44,
#     'runs': 14,
#     'doubles': 7,
#     'triples': 0,
#     'homeRuns': 7,
#     'strikeOuts': 89,
#     'baseOnBalls': 13,
#     'intentionalWalks': 0,
#     'hits': 48,
#     'hitByPitch': 3,
#     'avg': '.202',
#     'atBats': 238,
#     'obp': '.251',
#     'slg': '.319',
#     'ops': '.570',
#     'caughtStealing': 1,
#     'stolenBases': 2,
#     'stolenBasePercentage': '.667',
#     'groundIntoDoublePlay': 7,
#     'numberOfPitches': 1071,
#     'era': '1.90',
#     'inningsPitched': '66.1',
#     'wins': 6,
#     'losses': 0,
#     'saves': 0,
#     'saveOpportunities': 0,
#     'holds': 0,
#     'blownSaves': 0,
#     'earnedRuns': 14,
#     'whip': '0.92',
#     'battersFaced': 255,
#     'outs': 199,
#     'gamesPitched': 11,
#     'completeGames': 0,
#     'shutouts': 0,
#     'strikes': 721,
#     'strikePercentage': '.670',
#     'hitBatsmen': 3,
#     'balks': 0,
#     'wildPitches': 1,
#     'pickoffs': 1,
#     'totalBases': 76,
#     'groundOutsToAirouts': '1.32',
#     'winPercentage': '1.000',
#     'pitchesPerInning': '16.15',
#     'gamesFinished': 0,
#     'strikeoutWalkRatio': '6.85',
#     'strikeoutsPer9Inn': '12.08',
#     'walksPer9Inn': '1.76',
#     'hitsPer9Inn': '6.51',
#     'runsScoredPer9': '1.90',
#     'homeRunsPer9': '0.95',
#     'inheritedRunners': 0,
#     'inheritedRunnersScored': 0,
#     'catchersInterference': 0,
#     'sacBunts': 0,
#     'sacFlies': 1}}]}

# %%
def get_hitsPer9(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['hitsPer9Inn'])

def get_inningsPitched(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['inningsPitched'])

def get_gamesStarted(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['gamesStarted'])

player_hitsPer9 = player_df.id.apply(get_hitsPer9)
player_df = player_df.assign(hitsPer9=player_hitsPer9.values)

player_inningsPitched = player_df.id.apply(get_inningsPitched)
player_df = player_df.assign(inningsPitched=player_inningsPitched.values)

player_gamesStarted = player_df.id.apply(get_gamesStarted)
player_df = player_df.assign(gamesStarted=player_gamesStarted.values)

# %%
pitchers = player_df['hitsPer9'] != 0
pitcher_df = player_df.loc[pitchers]


# def get_last3HP9(player_id):
#     player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
#     if int(player['mlb_debut'][2]) == 2:
#         player = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season': 2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'career') 
#         float(player['stats'][0]['stats']['hitsPer9Inn'])
#     lastlast = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2022,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
#     lastlast = float(lastlast['stats'][0]['stats']['hitsPer9Inn'])
#     last = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
#     last = float(last['stats'][0]['stats']['hitsPer9Inn'])
#     current = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2024,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
#     current = float(current['stats'][0]['stats']['hitsPer9Inn'])
#     return (lastlast + last + current) / 3

# L3HP9 = pitcher_df.id.apply(get_last3HP9)
# pitcher_df = pitcher_df.assign(L3SeasonHP9=L3HP9.values)

startingPitchers = player_df['gamesStarted'] != 0
startingPitcher_df = player_df.loc[startingPitchers]
startingPitcher_df.sort_values(by = ['hitsPer9'], ascending = True)
# Out:
#               id            fullName                   link   firstName  \
# ID669373  669373        Tarik Skubal  /api/v1/people/669373       Tarik
# ID668881  668881       Hunter Greene  /api/v1/people/668881   Christian
# ID694973  694973         Paul Skenes  /api/v1/people/694973        Paul
# ID676979  676979     Garrett Crochet  /api/v1/people/676979     Garrett
# ID542881  542881      Tyler Anderson  /api/v1/people/542881       Tyler
# ID656557  656557        Tanner Houck  /api/v1/people/656557      Tanner
# ID666142  666142         Cole Ragans  /api/v1/people/666142        Cole
# ID625643  625643      Reynaldo López  /api/v1/people/625643    Reynaldo
# ID669203  669203       Corbin Burnes  /api/v1/people/669203      Corbin
# ID608331  608331           Max Fried  /api/v1/people/608331         Max
# ID607625  607625           Seth Lugo  /api/v1/people/607625       Jacob
# ID684007  684007       Shota Imanaga  /api/v1/people/684007       Shota
# ID650911  650911  Cristopher Sánchez  /api/v1/people/650911  Cristopher
# ID657277  657277          Logan Webb  /api/v1/people/657277       Logan
#
#           lastName primaryNumber   birthDate currentAge             birthCity  \
# ID669373    Skubal            29  1996-11-20         27               Hayward
# ID668881    Greene            21  1999-08-06         24           Los Angeles
# ID694973    Skenes            30  2002-05-29         22             Fullerton
# ID676979   Crochet            45  1999-06-21         25         Ocean Springs
# ID542881  Anderson            31  1989-12-30         34             Las Vegas
# ID656557     Houck            89  1996-06-29         28             St. Louis
# ID666142    Ragans            55  1997-12-12         26         Crawfordville
# ID625643     López            40  1994-01-04         30  San Pedro de Macoris
# ID669203    Burnes            39  1994-10-22         29           Bakersfield
# ID608331     Fried            54  1994-01-18         30          Santa Monica
# ID607625      Lugo            67  1989-11-17         34            Shreveport
# ID684007   Imanaga            18  1993-09-01         30            Kitakyushu
# ID650911   Sánchez            61  1996-12-12         27             La Romana
# ID657277      Webb            62  1996-11-18         27               Rocklin
#
#          birthStateProvince  ...                 fullLFMName strikeZoneTop  \
# ID669373                 CA  ...        Skubal, Tarik Daniel          3.49
# ID668881                 CA  ...    Greene, Christian Hunter         3.575
# ID694973                 CA  ...          Skenes, Paul David         3.656
# ID676979                 MS  ...      Crochet, Garrett Nolan          3.66
# ID542881                 NV  ...        Anderson, Tyler John          3.56
# ID656557                 MO  ...           Houck, Tanner Lee         3.575
# ID666142                 FL  ...         Ragans, Cole Gatlin         3.549
# ID625643                NaN  ...    López, Reynaldo Starling         3.411
# ID669203                 CA  ...        Burnes, Corbin Brian          3.62
# ID608331                 CA  ...           Fried, Max Dorian          3.37
# ID607625                 LA  ...            Lugo, Jacob Seth         3.549
# ID684007                NaN  ...             Imanaga, Shota          3.301
# ID650911                NaN  ...  Sánchez, Cristopher Alexis         3.411
# ID657277                 CA  ...              Webb, Logan T.          3.41
#
#          strikeZoneBottom nameMatrilineal     pronunciation nameTitle  \
# ID669373            1.601             NaN  Tare-ick sku-ble       NaN
# ID668881            1.681             NaN               NaN       NaN
# ID694973            1.677             NaN               NaN       NaN
# ID676979             1.68             NaN         CROW-shay       NaN
# ID542881             1.68             NaN               NaN       NaN
# ID656557            1.681             NaN              HOWk       NaN
# ID666142            1.627             NaN               NaN       NaN
# ID625643            1.565            Kely               NaN       NaN
# ID669203             1.69             NaN               NaN       NaN
# ID608331             1.56             NaN             FREED       NaN
# ID607625            1.627             NaN               NaN       NaN
# ID684007            1.504             NaN               NaN       NaN
# ID650911            1.565          Valera    KRISS-tuh-furr       NaN
# ID657277             1.58             NaN               NaN       NaN
#
#          nameSuffix hitsPer9 inningsPitched gamesStarted
# ID669373        NaN     6.28          116.0         19.0
# ID668881        NaN     6.36          110.1         19.0
# ID694973        NaN     6.51           66.1         11.0
# ID676979        NaN     6.62          107.1         20.0
# ID542881        NaN     6.94          118.0         19.0
# ID656557        NaN     7.31          117.0         19.0
# ID666142        NaN     7.33          116.2         20.0
# ID625643        NaN     7.34           95.2         17.0
# ID669203        NaN     7.51          118.2         19.0
# ID608331        NaN     7.58          108.0         18.0
# ID607625        NaN     7.65          127.0         20.0
# ID684007        NaN     8.54           97.0         17.0
# ID650911        NaN     8.62          103.1         18.0
# ID657277        NaN     9.12          124.1         20.0
#
# [14 rows x 44 columns]

# %%
season_data = statsapi.latest_season()
print(season_data['seasonId'])
# Out:
# 2024
