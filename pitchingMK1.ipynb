# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745720  26c39ab7-ba4b-4a03-a661-034f3148daec
# 1   747093  e0f09639-1ccb-4fd7-97f2-c042e21eb293
# 2   747096  544bcd7b-3766-4e09-9fb4-36207b8b09d7
# 3   744910  de72f558-409a-4a64-820e-0c68716ecba5
# 4   745638  9a64e28b-4001-4713-91e5-90c8a5b90a04
# 5   746041  1586aedb-4155-43a9-9d55-3961aa837cc2
# 6   745478  e09da135-b3b1-43cc-ba18-bedfff76f37c
# 7   744830  477d0d42-5345-4c40-8d84-5b5b8b84d98c
# 8   744994  2d50a694-005f-40ea-8547-3e67e31e8834
# 9   746613  fc1692ad-47ec-4c26-8882-3510e211abf4
# 10  746286  1c890c97-daf4-42c5-a57f-088a9bcc6cca
# 11  745880  39cba7e9-604e-4268-94bf-3e4eed895826
# 12  746852  7b583a6b-e62f-4a5d-93c9-f2bc5d8e6a19
# 13  746121  93a506bd-8de9-40ad-a5a9-fc0eca35fa05
# 14  746527  9acc484b-3c0b-4580-b240-61c344733f38
# 15  745229  9ea44381-b586-4141-a4cc-5bbc0bf42e4c
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745720/feed/live        R   2024  2024-07-20T17:05:00Z
# 1   /api/v1.1/game/747093/feed/live        R   2024  2024-07-20T17:07:00Z
# 2   /api/v1.1/game/747096/feed/live        R   2024  2024-07-20T23:20:00Z
# 3   /api/v1.1/game/744910/feed/live        R   2024  2024-07-20T19:07:00Z
# 4   /api/v1.1/game/745638/feed/live        R   2024  2024-07-20T20:07:00Z
# 5   /api/v1.1/game/746041/feed/live        R   2024  2024-07-20T20:10:00Z
# 6   /api/v1.1/game/745478/feed/live        R   2024  2024-07-20T22:40:00Z
# 7   /api/v1.1/game/744830/feed/live        R   2024  2024-07-20T22:45:00Z
# 8   /api/v1.1/game/744994/feed/live        R   2024  2024-07-20T23:05:00Z
# 9   /api/v1.1/game/746613/feed/live        R   2024  2024-07-20T23:10:00Z
# 10  /api/v1.1/game/746286/feed/live        R   2024  2024-07-20T23:10:00Z
# 11  /api/v1.1/game/745880/feed/live        R   2024  2024-07-20T23:10:00Z
# 12  /api/v1.1/game/746852/feed/live        R   2024  2024-07-20T23:15:00Z
# 13  /api/v1.1/game/746121/feed/live        R   2024  2024-07-20T23:15:00Z
# 14  /api/v1.1/game/746527/feed/live        R   2024  2024-07-21T00:10:00Z
# 15  /api/v1.1/game/745229/feed/live        R   2024  2024-07-21T01:40:00Z
#
#    officialDate                                             status  \
# 0    2024-07-20  {'abstractGameState': 'Final', 'codedGameState...
# 1    2024-07-20  {'abstractGameState': 'Final', 'codedGameState...
# 2    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 3    2024-07-20  {'abstractGameState': 'Final', 'codedGameState...
# 4    2024-07-20  {'abstractGameState': 'Live', 'codedGameState'...
# 5    2024-07-20  {'abstractGameState': 'Live', 'codedGameState'...
# 6    2024-07-20  {'abstractGameState': 'Live', 'codedGameState'...
# 7    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 8    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 9    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 10   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 11   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 12   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 13   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 14   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 15   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 41, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 62, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 47, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 59, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 27, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 55, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 50, 'losses...
# 13  {'away': {'leagueRecord': {'wins': 53, 'losses...
# 14  {'away': {'leagueRecord': {'wins': 47, 'losses...
# 15  {'away': {'leagueRecord': {'wins': 51, 'losses...
#
#                                                 venue  ... inningBreakLength  \
# 0   {'id': 3313, 'name': 'Yankee Stadium', 'link':...  ...               120
# 1   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...               120
# 2   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...               120
# 3   {'id': 14, 'name': 'Rogers Centre', 'link': '/...  ...               120
# 4   {'id': 10, 'name': 'Oakland Coliseum', 'link':...  ...               120
# 5   {'id': 4169, 'name': 'loanDepot park', 'link':...  ...               120
# 6   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...  ...               120
# 7   {'id': 3309, 'name': 'Nationals Park', 'link':...  ...               120
# 8   {'id': 5325, 'name': 'Globe Life Field', 'link...  ...               120
# 9   {'id': 5, 'name': 'Progressive Field', 'link':...  ...               120
# 10  {'id': 7, 'name': 'Kauffman Stadium', 'link': ...  ...               120
# 11  {'id': 3312, 'name': 'Target Field', 'link': '...  ...               120
# 12  {'id': 17, 'name': 'Wrigley Field', 'link': '/...  ...               145
# 13  {'id': 22, 'name': 'Dodger Stadium', 'link': '...  ...               145
# 14  {'id': 19, 'name': 'Coors Field', 'link': '/ap...  ...               120
# 15  {'id': 680, 'name': 'T-Mobile Park', 'link': '...  ...               120
#
#    gamesInSeries  seriesGameNumber  seriesDescription recordSource  \
# 0              4                 2     Regular Season            S
# 1              3                 1     Regular Season            S
# 2              3                 2     Regular Season            S
# 3              3                 2     Regular Season            S
# 4              3                 2     Regular Season            S
# 5              4                 2     Regular Season            S
# 6              3                 2     Regular Season            S
# 7              3                 2     Regular Season            S
# 8              3                 2     Regular Season            S
# 9              3                 2     Regular Season            S
# 10             3                 2     Regular Season            S
# 11             2                 1     Regular Season            S
# 12             3                 2     Regular Season            S
# 13             3                 2     Regular Season            S
# 14             3                 2     Regular Season            S
# 15             3                 2     Regular Season            S
#
#    ifNecessary ifNecessaryDescription       rescheduledFrom  \
# 0            N            Normal Game                   NaN
# 1            N            Normal Game  2024-07-19T23:20:00Z
# 2            N            Normal Game                   NaN
# 3            N            Normal Game                   NaN
# 4            N            Normal Game                   NaN
# 5            N            Normal Game                   NaN
# 6            N            Normal Game                   NaN
# 7            N            Normal Game                   NaN
# 8            N            Normal Game                   NaN
# 9            N            Normal Game                   NaN
# 10           N            Normal Game                   NaN
# 11           N            Normal Game                   NaN
# 12           N            Normal Game                   NaN
# 13           N            Normal Game                   NaN
# 14           N            Normal Game                   NaN
# 15           N            Normal Game                   NaN
#
#    rescheduledFromDate         description
# 0                  NaN                 NaN
# 1           2024-07-19  Makeup of 7/19 PPD
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# 5                  NaN                 NaN
# 6                  NaN                 NaN
# 7                  NaN                 NaN
# 8                  NaN                 NaN
# 9                  NaN                 NaN
# 10                 NaN                 NaN
# 11                 NaN                 NaN
# 12                 NaN                 NaN
# 13                 NaN                 NaN
# 14                 NaN                 NaN
# 15                 NaN                 NaN
#
# [16 rows x 32 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
player_df.T
# Out:
#                                                              ID543859  \
# id                                                             543859
# fullName                                               Michael Tonkin
# link                                            /api/v1/people/543859
# firstName                                                     Michael
# lastName                                                       Tonkin
# primaryNumber                                                      50
# birthDate                                                  1989-11-19
# currentAge                                                         34
# birthCity                                                    Glendale
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 7"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                       Michael
# useLastName                                                    Tonkin
# middleName                                                     Harvey
# boxscoreName                                                   Tonkin
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2008
# mlbDebutDate                                               2013-07-11
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Michael Tonkin
# nameSlug                                        michael-tonkin-543859
# firstLastName                                          Michael Tonkin
# lastFirstName                                         Tonkin, Michael
# lastInitName                                                Tonkin, M
# initLastName                                                 M Tonkin
# fullFMLName                                     Michael Harvey Tonkin
# fullLFMName                                    Tonkin, Michael Harvey
# strikeZoneTop                                                   3.756
# strikeZoneBottom                                                1.746
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID670764  \
# id                                                             670764
# fullName                                                 Taylor Walls
# link                                            /api/v1/people/670764
# firstName                                                      Taylor
# lastName                                                        Walls
# primaryNumber                                                       6
# birthDate                                                  1996-07-10
# currentAge                                                         28
# birthCity                                                     Cordele
# birthStateProvince                                                 GA
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                        Taylor
# useLastName                                                     Walls
# middleName                                                        NaN
# boxscoreName                                                    Walls
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2017
# mlbDebutDate                                               2021-05-22
# batSide                        {'code': 'S', 'description': 'Switch'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Taylor Walls
# nameSlug                                          taylor-walls-670764
# firstLastName                                            Taylor Walls
# lastFirstName                                           Walls, Taylor
# lastInitName                                                 Walls, T
# initLastName                                                  T Walls
# fullFMLName                                              Taylor Walls
# fullLFMName                                             Walls, Taylor
# strikeZoneTop                                                    3.45
# strikeZoneBottom                                                 1.57
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID641482  \
# id                                                             641482
# fullName                                                Nestor Cortes
# link                                            /api/v1/people/641482
# firstName                                                      Nestor
# lastName                                                       Cortes
# primaryNumber                                                      65
# birthDate                                                  1994-12-10
# currentAge                                                         29
# birthCity                                       Surgidero de Batabano
# birthStateProvince                                                NaN
# birthCountry                                                     Cuba
# height                                                         5' 11"
# weight                                                            210
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Nestor
# useLastName                                                    Cortes
# middleName                                                        NaN
# boxscoreName                                                   Cortes
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2013
# mlbDebutDate                                               2018-03-31
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                           Nestor Cortes
# nameSlug                                         nestor-cortes-641482
# firstLastName                                           Nestor Cortes
# lastFirstName                                          Cortes, Nestor
# lastInitName                                                Cortes, N
# initLastName                                                 N Cortes
# fullFMLName                                            Nestor  Cortes
# fullLFMName                                            Cortes, Nestor
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                  Hialeah Kid
# nameTitle                                                         Jr.
# nameSuffix                                                        Jr.
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID542888  \
# id                                                             542888
# fullName                                              Shawn Armstrong
# link                                            /api/v1/people/542888
# firstName                                                       Shawn
# lastName                                                    Armstrong
# primaryNumber                                                      64
# birthDate                                                  1990-09-11
# currentAge                                                         33
# birthCity                                                    New Bern
# birthStateProvince                                                 NC
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            225
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Shawn
# useLastName                                                 Armstrong
# middleName                                                    Michael
# boxscoreName                                                Armstrong
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2011
# mlbDebutDate                                               2015-08-08
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                         Shawn Armstrong
# nameSlug                                       shawn-armstrong-542888
# firstLastName                                         Shawn Armstrong
# lastFirstName                                        Armstrong, Shawn
# lastInitName                                             Armstrong, S
# initLastName                                              S Armstrong
# fullFMLName                                   Shawn Michael Armstrong
# fullLFMName                                  Armstrong, Shawn Michael
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                        Armie
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID518934  \
# id                                                             518934
# fullName                                                  DJ LeMahieu
# link                                            /api/v1/people/518934
# firstName                                                       David
# lastName                                                     LeMahieu
# primaryNumber                                                      26
# birthDate                                                  1988-07-13
# currentAge                                                         36
# birthCity                                                     Visalia
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '5', 'name': 'Third Base', 'type': 'I...
# useName                                                            DJ
# useLastName                                                  LeMahieu
# middleName                                                       John
# boxscoreName                                                 LeMahieu
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2009
# mlbDebutDate                                               2011-05-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             DJ LeMahieu
# nameSlug                                           dj-lemahieu-518934
# firstLastName                                             DJ LeMahieu
# lastFirstName                                            LeMahieu, DJ
# lastInitName                                              LeMahieu, D
# initLastName                                               D LeMahieu
# fullFMLName                                       David John LeMahieu
# fullLFMName                                      LeMahieu, David John
# strikeZoneTop                                                     3.3
# strikeZoneBottom                                                 1.55
# nickName                                                    Big Fundy
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                            luh-MAY-hyoo
# nameMatrilineal                                                   NaN
#
#                                                              ID664040  \
# id                                                             664040
# fullName                                                 Brandon Lowe
# link                                            /api/v1/people/664040
# firstName                                                     Brandon
# lastName                                                         Lowe
# primaryNumber                                                       8
# birthDate                                                  1994-07-06
# currentAge                                                         30
# birthCity                                                     Suffolk
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '4', 'name': 'Second Base', 'type': '...
# useName                                                       Brandon
# useLastName                                                      Lowe
# middleName                                                     Norman
# boxscoreName                                                  Lowe, B
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2018-08-05
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Brandon Lowe
# nameSlug                                          brandon-lowe-664040
# firstLastName                                            Brandon Lowe
# lastFirstName                                           Lowe, Brandon
# lastInitName                                                  Lowe, B
# initLastName                                                   B Lowe
# fullFMLName                                       Brandon Norman Lowe
# fullLFMName                                      Lowe, Brandon Norman
# strikeZoneTop                                                    3.29
# strikeZoneBottom                                                 1.53
# nickName                                                    Bamm-Bamm
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                       rhymes with 'now'
# nameMatrilineal                                                   NaN
#
#                                                              ID671737  \
# id                                                             671737
# fullName                                                  Taj Bradley
# link                                            /api/v1/people/671737
# firstName                                                         Taj
# lastName                                                      Bradley
# primaryNumber                                                      45
# birthDate                                                  2001-03-20
# currentAge                                                         23
# birthCity                                                 Los Angeles
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                           Taj
# useLastName                                                   Bradley
# middleName                                                        Ali
# boxscoreName                                               Bradley, T
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2018
# mlbDebutDate                                               2023-04-12
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Taj Bradley
# nameSlug                                           taj-bradley-671737
# firstLastName                                             Taj Bradley
# lastFirstName                                            Bradley, Taj
# lastInitName                                               Bradley, T
# initLastName                                                T Bradley
# fullFMLName                                           Taj Ali Bradley
# fullLFMName                                          Bradley, Taj Ali
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID664126  \
# id                                                             664126
# fullName                                               Pete Fairbanks
# link                                            /api/v1/people/664126
# firstName                                                       Peter
# lastName                                                    Fairbanks
# primaryNumber                                                      29
# birthDate                                                  1993-12-16
# currentAge                                                         30
# birthCity                                                   Milwaukee
# birthStateProvince                                                 WI
# birthCountry                                                      USA
# height                                                          6' 6"
# weight                                                            225
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Pete
# useLastName                                                 Fairbanks
# middleName                                                   Anderson
# boxscoreName                                                Fairbanks
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2019-06-09
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Pete Fairbanks
# nameSlug                                        pete-fairbanks-664126
# firstLastName                                          Pete Fairbanks
# lastFirstName                                         Fairbanks, Pete
# lastInitName                                             Fairbanks, P
# initLastName                                              P Fairbanks
# fullFMLName                                  Peter Anderson Fairbanks
# fullLFMName                                 Fairbanks, Peter Anderson
# strikeZoneTop                                                   3.656
# strikeZoneBottom                                                1.677
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID686752  \
# id                                                             686752
# fullName                                                  Ryan Pepiot
# link                                            /api/v1/people/686752
# firstName                                                        Ryan
# lastName                                                       Pepiot
# primaryNumber                                                      44
# birthDate                                                  1997-08-21
# currentAge                                                         26
# birthCity                                                Indianapolis
# birthStateProvince                                                 IN
# birthCountry                                                      USA
# height                                                          6' 3"
# weight                                                            215
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Ryan
# useLastName                                                    Pepiot
# middleName                                                    Michael
# boxscoreName                                                   Pepiot
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2019
# mlbDebutDate                                               2022-05-11
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Ryan Pepiot
# nameSlug                                           ryan-pepiot-686752
# firstLastName                                             Ryan Pepiot
# lastFirstName                                            Pepiot, Ryan
# lastInitName                                                Pepiot, R
# initLastName                                                 R Pepiot
# fullFMLName                                       Ryan Michael Pepiot
# fullLFMName                                      Pepiot, Ryan Michael
# strikeZoneTop                                                    3.49
# strikeZoneBottom                                                1.601
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                              PEH-pee-oh
# nameMatrilineal                                                   NaN
#
#                                                              ID657077  ...  \
# id                                                             657077  ...
# fullName                                                 Alex Verdugo  ...
# link                                            /api/v1/people/657077  ...
# firstName                                                   Alexander  ...
# lastName                                                      Verdugo  ...
# primaryNumber                                                      24  ...
# birthDate                                                  1996-05-15  ...
# currentAge                                                         28  ...
# birthCity                                                      Tucson  ...
# birthStateProvince                                                 AZ  ...
# birthCountry                                                      USA  ...
# height                                                          6' 0"  ...
# weight                                                            209  ...
# active                                                           True  ...
# primaryPosition     {'code': '7', 'name': 'Outfielder', 'type': 'O...  ...
# useName                                                          Alex  ...
# useLastName                                                   Verdugo  ...
# middleName                                                      Brady  ...
# boxscoreName                                                  Verdugo  ...
# gender                                                              M  ...
# isPlayer                                                         True  ...
# isVerified                                                       True  ...
# draftYear                                                        2014  ...
# mlbDebutDate                                               2017-09-01  ...
# batSide                          {'code': 'L', 'description': 'Left'}  ...
# pitchHand                        {'code': 'L', 'description': 'Left'}  ...
# nameFirstLast                                            Alex Verdugo  ...
# nameSlug                                          alex-verdugo-657077  ...
# firstLastName                                            Alex Verdugo  ...
# lastFirstName                                           Verdugo, Alex  ...
# lastInitName                                               Verdugo, A  ...
# initLastName                                                A Verdugo  ...
# fullFMLName                                   Alexander Brady Verdugo  ...
# fullLFMName                                  Verdugo, Alexander Brady  ...
# strikeZoneTop                                                    3.55  ...
# strikeZoneBottom                                                  1.6  ...
# nickName                                                        Dugie  ...
# nameTitle                                                         NaN  ...
# nameSuffix                                                        NaN  ...
# pronunciation                                             vehr-DOO-go  ...
# nameMatrilineal                                                   NaN  ...
#
#                                                              ID664076  \
# id                                                             664076
# fullName                                           Garrett Cleavinger
# link                                            /api/v1/people/664076
# firstName                                                     Garrett
# lastName                                                   Cleavinger
# primaryNumber                                                      60
# birthDate                                                  1994-04-23
# currentAge                                                         30
# birthCity                                                    Lawrence
# birthStateProvince                                                 KS
# birthCountry                                                      USA
# height                                                          6' 1"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                       Garrett
# useLastName                                                Cleavinger
# middleName                                                         J.
# boxscoreName                                               Cleavinger
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2020-09-17
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                      Garrett Cleavinger
# nameSlug                                    garrett-cleavinger-664076
# firstLastName                                      Garrett Cleavinger
# lastFirstName                                     Cleavinger, Garrett
# lastInitName                                            Cleavinger, G
# initLastName                                             G Cleavinger
# fullFMLName                                     Garrett J. Cleavinger
# fullLFMName                                    Cleavinger, Garrett J.
# strikeZoneTop                                                   3.411
# strikeZoneBottom                                                1.565
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID687330  \
# id                                                             687330
# fullName                                                  Kevin Kelly
# link                                            /api/v1/people/687330
# firstName                                                       Kevin
# lastName                                                        Kelly
# primaryNumber                                                      49
# birthDate                                                  1997-11-28
# currentAge                                                         26
# birthCity                                                 Springfield
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            200
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Kevin
# useLastName                                                     Kelly
# middleName                                                    Clayton
# boxscoreName                                                    Kelly
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2019
# mlbDebutDate                                               2023-04-01
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Kevin Kelly
# nameSlug                                           kevin-kelly-687330
# firstLastName                                             Kevin Kelly
# lastFirstName                                            Kelly, Kevin
# lastInitName                                                 Kelly, K
# initLastName                                                  K Kelly
# fullFMLName                                       Kevin Clayton Kelly
# fullLFMName                                      Kelly, Kevin Clayton
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID621107  \
# id                                                             621107
# fullName                                                   Zach Eflin
# link                                            /api/v1/people/621107
# firstName                                                     Zachary
# lastName                                                        Eflin
# primaryNumber                                                      24
# birthDate                                                  1994-04-08
# currentAge                                                         30
# birthCity                                                     Orlando
# birthStateProvince                                                 FL
# birthCountry                                                      USA
# height                                                          6' 6"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Zach
# useLastName                                                     Eflin
# middleName                                                      Adams
# boxscoreName                                                    Eflin
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2012
# mlbDebutDate                                               2016-06-14
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                              Zach Eflin
# nameSlug                                            zach-eflin-621107
# firstLastName                                              Zach Eflin
# lastFirstName                                             Eflin, Zach
# lastInitName                                                 Eflin, Z
# initLastName                                                  Z Eflin
# fullFMLName                                       Zachary Adams Eflin
# fullLFMName                                      Eflin, Zachary Adams
# strikeZoneTop                                                    3.68
# strikeZoneBottom                                                  1.7
# nickName                                                           Ef
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                 EFF-lin
# nameMatrilineal                                                   NaN
#
#                                                              ID666139  \
# id                                                             666139
# fullName                                                    Josh Lowe
# link                                            /api/v1/people/666139
# firstName                                                      Joshua
# lastName                                                         Lowe
# primaryNumber                                                      15
# birthDate                                                  1998-02-02
# currentAge                                                         26
# birthCity                                                  Chesapeake
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            205
# active                                                           True
# primaryPosition     {'code': '9', 'name': 'Outfielder', 'type': 'O...
# useName                                                          Josh
# useLastName                                                      Lowe
# middleName                                                     Edward
# boxscoreName                                                  Lowe, J
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2016
# mlbDebutDate                                               2021-09-08
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                               Josh Lowe
# nameSlug                                             josh-lowe-666139
# firstLastName                                               Josh Lowe
# lastFirstName                                              Lowe, Josh
# lastInitName                                                  Lowe, J
# initLastName                                                   J Lowe
# fullFMLName                                        Joshua Edward Lowe
# fullLFMName                                       Lowe, Joshua Edward
# strikeZoneTop                                                    3.72
# strikeZoneBottom                                                 1.76
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     low
# nameMatrilineal                                                   NaN
#
#                                                              ID592454  \
# id                                                             592454
# fullName                                                 Tommy Kahnle
# link                                            /api/v1/people/592454
# firstName                                                      Thomas
# lastName                                                       Kahnle
# primaryNumber                                                      41
# birthDate                                                  1989-08-07
# currentAge                                                         34
# birthCity                                                      Latham
# birthStateProvince                                                 NY
# birthCountry                                                      USA
# height                                                          6' 1"
# weight                                                            230
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Tommy
# useLastName                                                    Kahnle
# middleName                                                     Robert
# boxscoreName                                                   Kahnle
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2010
# mlbDebutDate                                               2014-04-03
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Tommy Kahnle
# nameSlug                                          tommy-kahnle-592454
# firstLastName                                            Tommy Kahnle
# lastFirstName                                           Kahnle, Tommy
# lastInitName                                                Kahnle, T
# initLastName                                                 T Kahnle
# fullFMLName                                      Thomas Robert Kahnle
# fullLFMName                                     Kahnle, Thomas Robert
# strikeZoneTop                                                   3.411
# strikeZoneBottom                                                1.565
# nickName                                                    King Kahn
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                cain-lee
# nameMatrilineal                                                   NaN
#
#                                                              ID683011  \
# id                                                             683011
# fullName                                                Anthony Volpe
# link                                            /api/v1/people/683011
# firstName                                                     Anthony
# lastName                                                        Volpe
# primaryNumber                                                      11
# birthDate                                                  2001-04-28
# currentAge                                                         23
# birthCity                                                    New York
# birthStateProvince                                                 NY
# birthCountry                                                      USA
# height                                                          5' 9"
# weight                                                            180
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                       Anthony
# useLastName                                                     Volpe
# middleName                                                    Michael
# boxscoreName                                                    Volpe
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2019
# mlbDebutDate                                               2023-03-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                           Anthony Volpe
# nameSlug                                         anthony-volpe-683011
# firstLastName                                           Anthony Volpe
# lastFirstName                                          Volpe, Anthony
# lastInitName                                                 Volpe, A
# initLastName                                                  A Volpe
# fullFMLName                                     Anthony Michael Volpe
# fullLFMName                                    Volpe, Anthony Michael
# strikeZoneTop                                                    3.38
# strikeZoneBottom                                                  1.6
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
#                                                              ID665966  \
# id                                                             665966
# fullName                                               Carlos Narvaez
# link                                            /api/v1/people/665966
# firstName                                                      Carlos
# lastName                                                      Narvaez
# primaryNumber                                                      94
# birthDate                                                  1998-11-26
# currentAge                                                         25
# birthCity                                                     Maracay
# birthStateProvince                                                NaN
# birthCountry                                                Venezuela
# height                                                         5' 11"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                        Carlos
# useLastName                                                   Narvaez
# middleName                                                       Luis
# boxscoreName                                                  Narvaez
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                         NaN
# mlbDebutDate                                               2024-07-20
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Carlos Narvaez
# nameSlug                                        carlos-narvaez-665966
# firstLastName                                          Carlos Narvaez
# lastFirstName                                         Narvaez, Carlos
# lastInitName                                               Narvaez, C
# initLastName                                                C Narvaez
# fullFMLName                                       Carlos Luis Narvaez
# fullLFMName                                      Narvaez, Carlos Luis
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                 Olivo
#
#                                                              ID661563  \
# id                                                             661563
# fullName                                                     Luis Gil
# link                                            /api/v1/people/661563
# firstName                                                        Luis
# lastName                                                          Gil
# primaryNumber                                                      81
# birthDate                                                  1998-06-03
# currentAge                                                         26
# birthCity                                                        Azua
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 2"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Luis
# useLastName                                                       Gil
# middleName                                                      Angel
# boxscoreName                                                      Gil
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2021-08-03
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                                Luis Gil
# nameSlug                                              luis-gil-661563
# firstLastName                                                Luis Gil
# lastFirstName                                               Gil, Luis
# lastInitName                                                   Gil, L
# initLastName                                                    L Gil
# fullFMLName                                            Luis Angel Gil
# fullLFMName                                           Gil, Luis Angel
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                    Heel
# nameMatrilineal                                                 Brito
#
#                                                              ID655889  \
# id                                                             655889
# fullName                                             Manuel Rodríguez
# link                                            /api/v1/people/655889
# firstName                                                      Manuel
# lastName                                                    Rodríguez
# primaryNumber                                                      39
# birthDate                                                  1996-08-06
# currentAge                                                         27
# birthCity                                                      Merida
# birthStateProvince                                            Yucatan
# birthCountry                                                   Mexico
# height                                                         5' 11"
# weight                                                            210
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Manuel
# useLastName                                                 Rodríguez
# middleName                                                   De Jesus
# boxscoreName                                             Rodríguez, M
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2021-07-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                        Manuel Rodríguez
# nameSlug                                      manuel-rodriguez-655889
# firstLastName                                        Manuel Rodríguez
# lastFirstName                                       Rodríguez, Manuel
# lastInitName                                             Rodríguez, M
# initLastName                                              M Rodríguez
# fullFMLName                                 Manuel De Jesus Rodríguez
# fullLFMName                                Rodríguez, Manuel De Jesus
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                Caamal
#
#                                                              ID656577
# id                                                             656577
# fullName                                                 Alex Jackson
# link                                            /api/v1/people/656577
# firstName                                                   Alexander
# lastName                                                      Jackson
# primaryNumber                                                      28
# birthDate                                                  1995-12-25
# currentAge                                                         28
# birthCity                                                   San Diego
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            238
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                          Alex
# useLastName                                                   Jackson
# middleName                                                      James
# boxscoreName                                                  Jackson
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2014
# mlbDebutDate                                               2019-04-07
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Alex Jackson
# nameSlug                                          alex-jackson-656577
# firstLastName                                            Alex Jackson
# lastFirstName                                           Jackson, Alex
# lastInitName                                               Jackson, A
# initLastName                                                A Jackson
# fullFMLName                                   Alexander James Jackson
# fullLFMName                                  Jackson, Alexander James
# strikeZoneTop                                                     3.5
# strikeZoneBottom                                                 1.65
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
#
# [41 rows x 52 columns]

# %%
player = statsapi.player_stat_data(694973, group= "pitching", type="season", sportId=1)
player
# Out:
# {'id': 694973,
#  'first_name': 'Paul',
#  'last_name': 'Skenes',
#  'active': True,
#  'current_team': 'Pittsburgh Pirates',
#  'position': 'P',
#  'nickname': None,
#  'last_played': None,
#  'mlb_debut': '2024-05-11',
#  'bat_side': 'Right',
#  'pitch_hand': 'Right',
#  'stats': [{'type': 'season',
#    'group': 'pitching',
#    'season': '2024',
#    'stats': {'gamesPlayed': 11,
#     'gamesStarted': 11,
#     'groundOuts': 58,
#     'airOuts': 44,
#     'runs': 14,
#     'doubles': 7,
#     'triples': 0,
#     'homeRuns': 7,
#     'strikeOuts': 89,
#     'baseOnBalls': 13,
#     'intentionalWalks': 0,
#     'hits': 48,
#     'hitByPitch': 3,
#     'avg': '.202',
#     'atBats': 238,
#     'obp': '.251',
#     'slg': '.319',
#     'ops': '.570',
#     'caughtStealing': 1,
#     'stolenBases': 2,
#     'stolenBasePercentage': '.667',
#     'groundIntoDoublePlay': 7,
#     'numberOfPitches': 1071,
#     'era': '1.90',
#     'inningsPitched': '66.1',
#     'wins': 6,
#     'losses': 0,
#     'saves': 0,
#     'saveOpportunities': 0,
#     'holds': 0,
#     'blownSaves': 0,
#     'earnedRuns': 14,
#     'whip': '0.92',
#     'battersFaced': 255,
#     'outs': 199,
#     'gamesPitched': 11,
#     'completeGames': 0,
#     'shutouts': 0,
#     'strikes': 721,
#     'strikePercentage': '.670',
#     'hitBatsmen': 3,
#     'balks': 0,
#     'wildPitches': 1,
#     'pickoffs': 1,
#     'totalBases': 76,
#     'groundOutsToAirouts': '1.32',
#     'winPercentage': '1.000',
#     'pitchesPerInning': '16.15',
#     'gamesFinished': 0,
#     'strikeoutWalkRatio': '6.85',
#     'strikeoutsPer9Inn': '12.08',
#     'walksPer9Inn': '1.76',
#     'hitsPer9Inn': '6.51',
#     'runsScoredPer9': '1.90',
#     'homeRunsPer9': '0.95',
#     'inheritedRunners': 0,
#     'inheritedRunnersScored': 0,
#     'catchersInterference': 0,
#     'sacBunts': 0,
#     'sacFlies': 1}}]}

# %%
def get_hitsPer9(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['hitsPer9Inn'])

def get_inningsPitched(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['inningsPitched'])

def get_gamesStarted(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['gamesStarted'])

player_hitsPer9 = player_df.id.apply(get_hitsPer9)
player_df = player_df.assign(hitsPer9=player_hitsPer9.values)

player_inningsPitched = player_df.id.apply(get_inningsPitched)
player_df = player_df.assign(inningsPitched=player_inningsPitched.values)

player_gamesStarted = player_df.id.apply(get_gamesStarted)
player_df = player_df.assign(gamesStarted=player_gamesStarted.values)

# %%
pitchers = player_df['hitsPer9'] != 0
pitcher_df = player_df.loc[pitchers]


def get_last3HP9(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    # if int(player['mlb_debut'][2]) == 2:
    #     player = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season': 2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'career') 
    #     float(player['stats'][0]['stats']['hitsPer9Inn'])
    lastlast = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2022,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
    lastlast = float(lastlast['stats'][0]['stats']['hitsPer9Inn'])
    # last = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
    # last = float(last['stats'][0]['stats']['hitsPer9Inn'])
    # current = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2024,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season') 
    # current = float(current['stats'][0]['stats']['hitsPer9Inn'])
    # return (lastlast + last + current) / 3
    return lastlast

L3HP9 = pitcher_df.id.apply(get_last3HP9)
pitcher_df = pitcher_df.assign(L3SeasonHP9=L3HP9.values)

startingPitchers = player_df['gamesStarted'] != 0
startingPitcher_df = player_df.loc[startingPitchers]
startingPitcher_df.sort_values(by = ['hitsPer9'], ascending = True)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[100], line 19
#      12     # last = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season')
#      13     # last = float(last['stats'][0]['stats']['hitsPer9Inn'])
#      14     # current = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2024,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season')
#      15     # current = float(current['stats'][0]['stats']['hitsPer9Inn'])
#      16     # return (lastlast + last + current) / 3
#      17     return lastlast
# ---> 19 L3HP9 = pitcher_df.id.apply(get_last3HP9)
#      20 pitcher_df = pitcher_df.assign(L3SeasonHP9=L3HP9.values)
#      22 startingPitchers = player_df['gamesStarted'] != 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[100], line 10, in get_last3HP9(player_id)
#       6 player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
#       7 # if int(player['mlb_debut'][2]) == 2:
#       8 #     player = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season': 2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'career')
#       9 #     float(player['stats'][0]['stats']['hitsPer9Inn'])
# ---> 10 lastlast = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2022,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season')
#      11 lastlast = float(lastlast['stats'][0]['stats']['hitsPer9Inn'])
#      12 # last = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2023,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season')
#      13 # last = float(last['stats'][0]['stats']['hitsPer9Inn'])
#      14 # current = statsapi.player_stats(next(x['id'] for x in statsapi.get('sports_players',{'season':2024,'gameType':'W'})['people'] if x['id']==player_id), 'pitching', 'season')
#      15 # current = float(current['stats'][0]['stats']['hitsPer9Inn'])
#      16 # return (lastlast + last + current) / 3
#
# StopIteration:

# %%
season_data = statsapi.latest_season()
print(season_data['seasonId'])

# %%
team = statsapi.lookup_team(133)
player = statsapi.lookup_player(133)

print ("Starting Pitchers for the " + team[0]['name'] + ":")

for index in range (0, len(player)):
    guy = player[index]
    if int(guy['primaryPosition']['code']) == 1:
        dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
        if dude['stats'][0]['stats']['gamesStarted'] > 10:
            print (guy['fullName'])
