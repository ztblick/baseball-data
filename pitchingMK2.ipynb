# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745717  107667f4-a7d6-4ee0-91ee-0479bd158455
# 1   746612  2f169a9a-fa83-464b-839f-6c3c4fffc697
# 2   745473  bbd9cf73-afa6-4cc5-8785-0a7fa6238609
# 3   746034  b7941d0e-6c24-4f12-99a1-87af6291683e
# 4   747095  19a90f0e-c8b5-48bd-a0c5-47cd59594361
# 5   745881  641f18f1-e96f-4909-9c36-c83030dfcd15
# 6   744988  287f47ef-a785-43c2-b8be-d7ed9ce7310f
# 7   746850  0a47bde8-f628-40ed-a06a-0836386b6512
# 8   746280  f4d9f6b4-0bb3-4ae2-9115-c76c02e17aef
# 9   746526  26fdca47-3cc5-447c-8ec7-b8aa0b06c425
# 10  745635  bb665643-5d2a-407b-a5a7-730a292f6758
# 11  745232  af82149c-a034-4fcc-a2c7-0d97e4758b34
# 12  746124  c40d1955-e314-4701-96ab-72b6ba0de967
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745717/feed/live        R   2024  2024-07-22T17:05:00Z
# 1   /api/v1.1/game/746612/feed/live        R   2024  2024-07-22T22:40:00Z
# 2   /api/v1.1/game/745473/feed/live        R   2024  2024-07-22T22:40:00Z
# 3   /api/v1.1/game/746034/feed/live        R   2024  2024-07-22T22:40:00Z
# 4   /api/v1.1/game/747095/feed/live        R   2024  2024-07-22T23:20:00Z
# 5   /api/v1.1/game/745881/feed/live        R   2024  2024-07-22T23:40:00Z
# 6   /api/v1.1/game/744988/feed/live        R   2024  2024-07-23T00:05:00Z
# 7   /api/v1.1/game/746850/feed/live        R   2024  2024-07-23T00:05:00Z
# 8   /api/v1.1/game/746280/feed/live        R   2024  2024-07-23T00:10:00Z
# 9   /api/v1.1/game/746526/feed/live        R   2024  2024-07-23T00:40:00Z
# 10  /api/v1.1/game/745635/feed/live        R   2024  2024-07-23T01:40:00Z
# 11  /api/v1.1/game/745232/feed/live        R   2024  2024-07-23T01:40:00Z
# 12  /api/v1.1/game/746124/feed/live        R   2024  2024-07-23T02:10:00Z
#
#    officialDate                                             status  \
# 0    2024-07-22  {'abstractGameState': 'Final', 'codedGameState...
# 1    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 2    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 3    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 4    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 5    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 6    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 7    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 8    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 9    2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 10   2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 11   2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
# 12   2024-07-22  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 52, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 47, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 63, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 27, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 57, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 51, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 53, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 52, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 42, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 48, 'losses...
#
#                                                 venue  ... dayNight  \
# 0   {'id': 3313, 'name': 'Yankee Stadium', 'link':...  ...      day
# 1   {'id': 5, 'name': 'Progressive Field', 'link':...  ...    night
# 2   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...  ...    night
# 3   {'id': 4169, 'name': 'loanDepot park', 'link':...  ...    night
# 4   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...    night
# 5   {'id': 3312, 'name': 'Target Field', 'link': '...  ...    night
# 6   {'id': 5325, 'name': 'Globe Life Field', 'link...  ...    night
# 7   {'id': 17, 'name': 'Wrigley Field', 'link': '/...  ...    night
# 8   {'id': 7, 'name': 'Kauffman Stadium', 'link': ...  ...    night
# 9   {'id': 19, 'name': 'Coors Field', 'link': '/ap...  ...    night
# 10  {'id': 10, 'name': 'Oakland Coliseum', 'link':...  ...    night
# 11  {'id': 680, 'name': 'T-Mobile Park', 'link': '...  ...    night
# 12  {'id': 22, 'name': 'Dodger Stadium', 'link': '...  ...    night
#
#    scheduledInnings  reverseHomeAwayStatus  inningBreakLength gamesInSeries  \
# 0                 9                  False                120             4
# 1                 9                  False                120             4
# 2                 9                  False                120             3
# 3                 9                  False                120             4
# 4                 9                  False                120             3
# 5                 9                  False                145             3
# 6                 9                  False                120             4
# 7                 9                  False                120             3
# 8                 9                  False                120             3
# 9                 9                  False                120             3
# 10                9                  False                120             3
# 11                9                  False                120             3
# 12                9                  False                120             4
#
#    seriesGameNumber seriesDescription recordSource ifNecessary  \
# 0                 4    Regular Season            S           N
# 1                 1    Regular Season            S           N
# 2                 1    Regular Season            S           N
# 3                 4    Regular Season            S           N
# 4                 1    Regular Season            S           N
# 5                 1    Regular Season            S           N
# 6                 1    Regular Season            S           N
# 7                 1    Regular Season            S           N
# 8                 1    Regular Season            S           N
# 9                 1    Regular Season            S           N
# 10                1    Regular Season            S           N
# 11                1    Regular Season            S           N
# 12                1    Regular Season            S           N
#
#    ifNecessaryDescription
# 0             Normal Game
# 1             Normal Game
# 2             Normal Game
# 3             Normal Game
# 4             Normal Game
# 5             Normal Game
# 6             Normal Game
# 7             Normal Game
# 8             Normal Game
# 9             Normal Game
# 10            Normal Game
# 11            Normal Game
# 12            Normal Game
#
# [13 rows x 29 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
# player_df.T
gameteams_df = pd.DataFrame(r['gameData']['teams'])
gameteams_df
# Out:
#                                                               away  \
# springLeague     {'id': 115, 'name': 'Grapefruit League', 'link...
# allStarStatus                                                    N
# id                                                             139
# name                                                Tampa Bay Rays
# link                                             /api/v1/teams/139
# season                                                        2024
# venue            {'id': 12, 'name': 'Tropicana Field', 'link': ...
# springVenue            {'id': 2534, 'link': '/api/v1/venues/2534'}
# teamCode                                                       tba
# fileCode                                                        tb
# abbreviation                                                    TB
# teamName                                                      Rays
# locationName                                        St. Petersburg
# firstYearOfPlay                                               1996
# league           {'id': 103, 'name': 'American League', 'link':...
# division         {'id': 201, 'name': 'American League East', 'l...
# sport            {'id': 1, 'link': '/api/v1/sports/1', 'name': ...
# shortName                                                Tampa Bay
# record           {'gamesPlayed': 100, 'wildCardGamesBack': '-',...
# franchiseName                                            Tampa Bay
# clubName                                                      Rays
# active                                                        True
#
#                                                               home
# springLeague     {'id': 115, 'name': 'Grapefruit League', 'link...
# allStarStatus                                                    N
# id                                                             147
# name                                              New York Yankees
# link                                             /api/v1/teams/147
# season                                                        2024
# venue            {'id': 3313, 'name': 'Yankee Stadium', 'link':...
# springVenue            {'id': 2523, 'link': '/api/v1/venues/2523'}
# teamCode                                                       nya
# fileCode                                                       nyy
# abbreviation                                                   NYY
# teamName                                                   Yankees
# locationName                                                 Bronx
# firstYearOfPlay                                               1903
# league           {'id': 103, 'name': 'American League', 'link':...
# division         {'id': 201, 'name': 'American League East', 'l...
# sport            {'id': 1, 'link': '/api/v1/sports/1', 'name': ...
# shortName                                               NY Yankees
# record           {'gamesPlayed': 102, 'wildCardGamesBack': '-',...
# franchiseName                                             New York
# clubName                                                   Yankees
# active                                                        True

# %%
def get_hitsPer9(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['hitsPer9Inn'])

def get_inningsPitched(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['inningsPitched'])

def get_gamesStarted(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['gamesStarted'])

player_hitsPer9 = player_df.id.apply(get_hitsPer9)
player_df = player_df.assign(hitsPer9=player_hitsPer9.values)

player_inningsPitched = player_df.id.apply(get_inningsPitched)
player_df = player_df.assign(inningsPitched=player_inningsPitched.values)

player_gamesStarted = player_df.id.apply(get_gamesStarted)
player_df = player_df.assign(gamesStarted=player_gamesStarted.values)

# %%
pitchers = player_df['hitsPer9'] != 0
pitcher_df = player_df.loc[pitchers]

startingPitchers = player_df['gamesStarted'] != 0
startingPitcher_df = player_df.loc[startingPitchers]
startingPitcher_df.sort_values(by = ['hitsPer9'], ascending = True)
# Out:
#               id         fullName                   link firstName   lastName  \
# ID661563  661563         Luis Gil  /api/v1/people/661563      Luis        Gil
# ID671737  671737      Taj Bradley  /api/v1/people/671737       Taj    Bradley
# ID573186  573186   Marcus Stroman  /api/v1/people/573186    Marcus    Stroman
# ID607074  607074     Carlos Rodón  /api/v1/people/607074    Carlos      Rodón
# ID641482  641482    Nestor Cortes  /api/v1/people/641482    Nestor     Cortes
# ID621107  621107       Zach Eflin  /api/v1/people/621107   Zachary      Eflin
# ID543037  543037      Gerrit Cole  /api/v1/people/543037    Gerrit       Cole
# ID641793  641793     Zack Littell  /api/v1/people/641793      Zack    Littell
# ID542888  542888  Shawn Armstrong  /api/v1/people/542888     Shawn  Armstrong
# ID669358  669358        Shane Baz  /api/v1/people/669358     Shane        Baz
#
#          primaryNumber   birthDate currentAge              birthCity  \
# ID661563            81  1998-06-03         26                   Azua
# ID671737            45  2001-03-20         23            Los Angeles
# ID573186             0  1991-05-01         33                Medford
# ID607074            55  1992-12-10         31                  Miami
# ID641482            65  1994-12-10         29  Surgidero de Batabano
# ID621107            24  1994-04-08         30                Orlando
# ID543037            45  1990-09-08         33          Newport Beach
# ID641793            52  1995-10-05         28             Burlington
# ID542888            64  1990-09-11         33               New Bern
# ID669358            11  1999-06-17         25                Houston
#
#          birthStateProvince  ... strikeZoneTop strikeZoneBottom     nickName  \
# ID661563                NaN  ...         3.467            1.589          NaN
# ID671737                 CA  ...         3.467            1.589          NaN
# ID573186                 NY  ...          3.38             1.56         HDMH
# ID607074                 FL  ...         3.467            1.589          Los
# ID641482                NaN  ...         3.319            1.513  Hialeah Kid
# ID621107                 FL  ...          3.68              1.7           Ef
# ID543037                 CA  ...         3.549            1.627       Chef G
# ID641793                 NC  ...         3.549            1.627          Lit
# ID542888                 NC  ...         3.467            1.589        Armie
# ID669358                 TX  ...         3.467            1.589          NaN
#
#          nameTitle nameSuffix pronunciation nameMatrilineal hitsPer9  \
# ID661563       NaN        NaN          Heel           Brito     5.45
# ID671737       NaN        NaN           NaN             NaN     6.33
# ID573186       NaN        NaN           NaN             NaN     7.91
# ID607074       NaN        NaN       row-DON             NaN     8.37
# ID641482       Jr.        Jr.           NaN             NaN     8.65
# ID621107       NaN        NaN       EFF-lin             NaN     9.40
# ID543037       NaN        NaN           NaN             NaN     9.51
# ID641793       NaN        NaN      lah-TELL             NaN    10.85
# ID542888       NaN        NaN           NaN             NaN    10.97
# ID669358       NaN        NaN           BOZ             NaN    11.20
#
#          inningsPitched gamesStarted
# ID661563          102.1         19.0
# ID671737           75.1         13.0
# ID573186          110.1         20.0
# ID607074          114.0         21.0
# ID641482          119.2         21.0
# ID621107          104.1         18.0
# ID543037           29.1          6.0
# ID641793          107.0         20.0
# ID542888           42.2          5.0
# ID669358           13.2          3.0
#
# [10 rows x 44 columns]

# %%
away_id = int(gameteams_df['away']['id'])
home_id = int(gameteams_df['home']['id'])
print(statsapi.team_leaders(away_id,'gamesStarted',limit=3,season=2024))
# Out:
# Rank Name                 Value
#  1   Zack Littell          20
#  2   Zach Eflin            18
#  3   Aaron Civale          17
#  3   Ryan Pepiot           17

# %%
away_players = statsapi.lookup_player(away_id)
away_avg_HP9 = 0.0
num_away_pitchers = 0.0

for index in range (0, len(away_players)):
    guy = away_players[index]
    if int(guy['primaryPosition']['code']) == 1:
        dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
        if dude['stats'][0]['stats']['gamesStarted'] >= 17:
            away_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
            num_away_pitchers += 1
away_avg_HP9 /= num_away_pitchers
away_avg_HP9
# Out:
# 8.913333333333334

# %%
player = statsapi.player_stat_data(694973, group= "pitching", type="season", sportId=1)
# player

# %%
home_players = statsapi.lookup_player(home_id)
home_avg_HP9 = 0.0
num_home_pitchers = 0.0

for index in range (0, len(home_players)):
    guy = home_players[index]
    if int(guy['primaryPosition']['code']) == 1:
        dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
        if dude['stats'][0]['stats']['gamesStarted'] >= 17:
            home_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
            num_home_pitchers += 1
home_avg_HP9 /= num_home_pitchers
home_avg_HP9
# Out:
# 7.595

# %%
def get_avg(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['avg'])

def get_atBats(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['atBats'])



averages = player_df.id.apply(get_avg)
player_df = player_df.assign(avg=averages.values)

player_atBats = player_df.id.apply(get_atBats)
player_df = player_df.assign(atBats=player_atBats.values)

# %%
for index in range (0, len(away_players)):
    guy = away_players[index]
    guy['dayScore'] += home_avg_HP9
for index in range (0, len(home_players)):
    guy = home_players[index]
    guy['dayScore'] += away_avg_HP9
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 for index in range (0, len(away_players)):
#       2     guy = away_players[index]
# ----> 3     guy['dayScore'] += home_avg_HP9
#       4 for index in range (0, len(home_players)):
#       5     guy = home_players[index]
#
# KeyError: 'dayScore'

# %%
oppHP9 = player_df.id * 0
player_df = player_df.assign(oppHP9=oppHP9.values)

for game in range (0, len(df)):
    url = HOST + df.loc[game,'link']
    r = requests.get(url=url).json()
    gameteams_df = pd.DataFrame(r['gameData']['teams'])
    away_id = int(gameteams_df['away']['id'])
    home_id = int(gameteams_df['home']['id'])

    away_players = statsapi.lookup_player(away_id)
    away_avg_HP9 = 0.0
    num_away_pitchers = 0.0
    for index in range (0, len(away_players)):
        guy = away_players[index]
        if int(guy['primaryPosition']['code']) == 1:
            dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
            if dude['stats'][0]['stats']['gamesStarted'] >= 17:
                away_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
                num_away_pitchers += 1
    away_avg_HP9 /= num_away_pitchers

    home_players = statsapi.lookup_player(home_id)
    home_avg_HP9 = 0.0
    num_home_pitchers = 0.0
    
    for index in range (0, len(home_players)):
        guy = home_players[index]
        if int(guy['primaryPosition']['code']) == 1:
            dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
            if dude['stats'][0]['stats']['gamesStarted'] >= 17:
                home_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
                num_home_pitchers += 1
    home_avg_HP9 /= num_home_pitchers

    
    for index in range (0, len(away_players)):
        guy = away_players[index]
        guy['primaryNumber'] = str(home_avg_HP9)
    for index in range (0, len(home_players)):
        guy = home_players[index]
        guy['primaryNumber'] = str(away_avg_HP9)

    # for index in range (0, len(away_players)):
    # guy = away_players[index]
    # guy['dayScore'] += home_avg_HP9
    # for index in range (0, len(home_players)):
    #     guy = home_players[index]
    #     guy['dayScore'] += away_avg_HP9
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 31
#      29 if int(guy['primaryPosition']['code']) == 1:
#      30     dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
# ---> 31     if dude['stats'][0]['stats']['gamesStarted'] >= 17:
#      32         home_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
#      33         num_home_pitchers += 1
#
# IndexError: list index out of range

# %%
player_df.T
# Out:
#                                                              ID543859  \
# id                                                             543859
# fullName                                               Michael Tonkin
# link                                            /api/v1/people/543859
# firstName                                                     Michael
# lastName                                                       Tonkin
# primaryNumber                                                      50
# birthDate                                                  1989-11-19
# currentAge                                                         34
# birthCity                                                    Glendale
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 7"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                       Michael
# useLastName                                                    Tonkin
# middleName                                                     Harvey
# boxscoreName                                                   Tonkin
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2008
# mlbDebutDate                                               2013-07-11
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Michael Tonkin
# nameSlug                                        michael-tonkin-543859
# firstLastName                                          Michael Tonkin
# lastFirstName                                         Tonkin, Michael
# lastInitName                                                Tonkin, M
# initLastName                                                 M Tonkin
# fullFMLName                                     Michael Harvey Tonkin
# fullLFMName                                    Tonkin, Michael Harvey
# strikeZoneTop                                                   3.756
# strikeZoneBottom                                                1.746
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                          5.7
# inningsPitched                                                   47.1
# gamesStarted                                                      0.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID670764  \
# id                                                             670764
# fullName                                                 Taylor Walls
# link                                            /api/v1/people/670764
# firstName                                                      Taylor
# lastName                                                        Walls
# primaryNumber                                                       6
# birthDate                                                  1996-07-10
# currentAge                                                         28
# birthCity                                                     Cordele
# birthStateProvince                                                 GA
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                        Taylor
# useLastName                                                     Walls
# middleName                                                        NaN
# boxscoreName                                                    Walls
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2017
# mlbDebutDate                                               2021-05-22
# batSide                        {'code': 'S', 'description': 'Switch'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Taylor Walls
# nameSlug                                          taylor-walls-670764
# firstLastName                                            Taylor Walls
# lastFirstName                                           Walls, Taylor
# lastInitName                                                 Walls, T
# initLastName                                                  T Walls
# fullFMLName                                              Taylor Walls
# fullLFMName                                             Walls, Taylor
# strikeZoneTop                                                    3.46
# strikeZoneBottom                                                 1.58
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                              0.16
# atBats                                                           81.0
# oppHP9                                                              0
#
#                                                              ID641482  \
# id                                                             641482
# fullName                                                Nestor Cortes
# link                                            /api/v1/people/641482
# firstName                                                      Nestor
# lastName                                                       Cortes
# primaryNumber                                                      65
# birthDate                                                  1994-12-10
# currentAge                                                         29
# birthCity                                       Surgidero de Batabano
# birthStateProvince                                                NaN
# birthCountry                                                     Cuba
# height                                                         5' 11"
# weight                                                            210
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Nestor
# useLastName                                                    Cortes
# middleName                                                        NaN
# boxscoreName                                                   Cortes
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2013
# mlbDebutDate                                               2018-03-31
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                           Nestor Cortes
# nameSlug                                         nestor-cortes-641482
# firstLastName                                           Nestor Cortes
# lastFirstName                                          Cortes, Nestor
# lastInitName                                                Cortes, N
# initLastName                                                 N Cortes
# fullFMLName                                            Nestor  Cortes
# fullLFMName                                            Cortes, Nestor
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                  Hialeah Kid
# nameTitle                                                         Jr.
# nameSuffix                                                        Jr.
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                         8.65
# inningsPitched                                                  119.2
# gamesStarted                                                     21.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID542888  \
# id                                                             542888
# fullName                                              Shawn Armstrong
# link                                            /api/v1/people/542888
# firstName                                                       Shawn
# lastName                                                    Armstrong
# primaryNumber                                                      64
# birthDate                                                  1990-09-11
# currentAge                                                         33
# birthCity                                                    New Bern
# birthStateProvince                                                 NC
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            225
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Shawn
# useLastName                                                 Armstrong
# middleName                                                    Michael
# boxscoreName                                                Armstrong
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2011
# mlbDebutDate                                               2015-08-08
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                         Shawn Armstrong
# nameSlug                                       shawn-armstrong-542888
# firstLastName                                         Shawn Armstrong
# lastFirstName                                        Armstrong, Shawn
# lastInitName                                             Armstrong, S
# initLastName                                              S Armstrong
# fullFMLName                                   Shawn Michael Armstrong
# fullLFMName                                  Armstrong, Shawn Michael
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                        Armie
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                        10.97
# inningsPitched                                                   42.2
# gamesStarted                                                      5.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID518934  \
# id                                                             518934
# fullName                                                  DJ LeMahieu
# link                                            /api/v1/people/518934
# firstName                                                       David
# lastName                                                     LeMahieu
# primaryNumber                                                      26
# birthDate                                                  1988-07-13
# currentAge                                                         36
# birthCity                                                     Visalia
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '5', 'name': 'Third Base', 'type': 'I...
# useName                                                            DJ
# useLastName                                                  LeMahieu
# middleName                                                       John
# boxscoreName                                                 LeMahieu
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2009
# mlbDebutDate                                               2011-05-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             DJ LeMahieu
# nameSlug                                           dj-lemahieu-518934
# firstLastName                                             DJ LeMahieu
# lastFirstName                                            LeMahieu, DJ
# lastInitName                                              LeMahieu, D
# initLastName                                               D LeMahieu
# fullFMLName                                       David John LeMahieu
# fullLFMName                                      LeMahieu, David John
# strikeZoneTop                                                    3.31
# strikeZoneBottom                                                 1.55
# nickName                                                    Big Fundy
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                            luh-MAY-hyoo
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                             0.181
# atBats                                                          127.0
# oppHP9                                                              0
#
#                                                              ID664040  \
# id                                                             664040
# fullName                                                 Brandon Lowe
# link                                            /api/v1/people/664040
# firstName                                                     Brandon
# lastName                                                         Lowe
# primaryNumber                                                       8
# birthDate                                                  1994-07-06
# currentAge                                                         30
# birthCity                                                     Suffolk
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                         5' 10"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '4', 'name': 'Second Base', 'type': '...
# useName                                                       Brandon
# useLastName                                                      Lowe
# middleName                                                     Norman
# boxscoreName                                                  Lowe, B
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2018-08-05
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Brandon Lowe
# nameSlug                                          brandon-lowe-664040
# firstLastName                                            Brandon Lowe
# lastFirstName                                           Lowe, Brandon
# lastInitName                                                  Lowe, B
# initLastName                                                   B Lowe
# fullFMLName                                       Brandon Norman Lowe
# fullLFMName                                      Lowe, Brandon Norman
# strikeZoneTop                                                    3.27
# strikeZoneBottom                                                 1.52
# nickName                                                    Bamm-Bamm
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                       rhymes with 'now'
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                             0.238
# atBats                                                          172.0
# oppHP9                                                              0
#
#                                                              ID671737  \
# id                                                             671737
# fullName                                                  Taj Bradley
# link                                            /api/v1/people/671737
# firstName                                                         Taj
# lastName                                                      Bradley
# primaryNumber                                                      45
# birthDate                                                  2001-03-20
# currentAge                                                         23
# birthCity                                                 Los Angeles
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                           Taj
# useLastName                                                   Bradley
# middleName                                                        Ali
# boxscoreName                                               Bradley, T
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2018
# mlbDebutDate                                               2023-04-12
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Taj Bradley
# nameSlug                                           taj-bradley-671737
# firstLastName                                             Taj Bradley
# lastFirstName                                            Bradley, Taj
# lastInitName                                               Bradley, T
# initLastName                                                T Bradley
# fullFMLName                                           Taj Ali Bradley
# fullLFMName                                          Bradley, Taj Ali
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                         6.33
# inningsPitched                                                   75.1
# gamesStarted                                                     13.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID664126  \
# id                                                             664126
# fullName                                               Pete Fairbanks
# link                                            /api/v1/people/664126
# firstName                                                       Peter
# lastName                                                    Fairbanks
# primaryNumber                                                      29
# birthDate                                                  1993-12-16
# currentAge                                                         30
# birthCity                                                   Milwaukee
# birthStateProvince                                                 WI
# birthCountry                                                      USA
# height                                                          6' 6"
# weight                                                            225
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Pete
# useLastName                                                 Fairbanks
# middleName                                                   Anderson
# boxscoreName                                                Fairbanks
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2019-06-09
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Pete Fairbanks
# nameSlug                                        pete-fairbanks-664126
# firstLastName                                          Pete Fairbanks
# lastFirstName                                         Fairbanks, Pete
# lastInitName                                             Fairbanks, P
# initLastName                                              P Fairbanks
# fullFMLName                                  Peter Anderson Fairbanks
# fullLFMName                                 Fairbanks, Peter Anderson
# strikeZoneTop                                                   3.656
# strikeZoneBottom                                                1.677
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                         7.27
# inningsPitched                                                   34.2
# gamesStarted                                                      0.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID657077  \
# id                                                             657077
# fullName                                                 Alex Verdugo
# link                                            /api/v1/people/657077
# firstName                                                   Alexander
# lastName                                                      Verdugo
# primaryNumber                                                      24
# birthDate                                                  1996-05-15
# currentAge                                                         28
# birthCity                                                      Tucson
# birthStateProvince                                                 AZ
# birthCountry                                                      USA
# height                                                          6' 0"
# weight                                                            209
# active                                                           True
# primaryPosition     {'code': '7', 'name': 'Outfielder', 'type': 'O...
# useName                                                          Alex
# useLastName                                                   Verdugo
# middleName                                                      Brady
# boxscoreName                                                  Verdugo
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2014
# mlbDebutDate                                               2017-09-01
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                            Alex Verdugo
# nameSlug                                          alex-verdugo-657077
# firstLastName                                            Alex Verdugo
# lastFirstName                                           Verdugo, Alex
# lastInitName                                               Verdugo, A
# initLastName                                                A Verdugo
# fullFMLName                                   Alexander Brady Verdugo
# fullLFMName                                  Verdugo, Alexander Brady
# strikeZoneTop                                                    3.54
# strikeZoneBottom                                                  1.6
# nickName                                                        Dugie
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                             vehr-DOO-go
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                             0.229
# atBats                                                          371.0
# oppHP9                                                              0
#
#                                                              ID676356  ...  \
# id                                                             676356  ...
# fullName                                                 Jonny DeLuca  ...
# link                                            /api/v1/people/676356  ...
# firstName                                                    Jonathan  ...
# lastName                                                       DeLuca  ...
# primaryNumber                                                      21  ...
# birthDate                                                  1998-07-10  ...
# currentAge                                                         26  ...
# birthCity                                               Thousand Oaks  ...
# birthStateProvince                                                 CA  ...
# birthCountry                                                      USA  ...
# height                                                          6' 0"  ...
# weight                                                            200  ...
# active                                                           True  ...
# primaryPosition     {'code': '9', 'name': 'Outfielder', 'type': 'O...  ...
# useName                                                         Jonny  ...
# useLastName                                                    DeLuca  ...
# middleName                                                      Davis  ...
# boxscoreName                                                   DeLuca  ...
# gender                                                              M  ...
# isPlayer                                                         True  ...
# isVerified                                                       True  ...
# draftYear                                                        2019  ...
# mlbDebutDate                                               2023-06-07  ...
# batSide                         {'code': 'R', 'description': 'Right'}  ...
# pitchHand                       {'code': 'R', 'description': 'Right'}  ...
# nameFirstLast                                            Jonny DeLuca  ...
# nameSlug                                          jonny-deluca-676356  ...
# firstLastName                                            Jonny DeLuca  ...
# lastFirstName                                           DeLuca, Jonny  ...
# lastInitName                                                DeLuca, J  ...
# initLastName                                                 J DeLuca  ...
# fullFMLName                                     Jonathan Davis DeLuca  ...
# fullLFMName                                    DeLuca, Jonathan Davis  ...
# strikeZoneTop                                                    3.28  ...
# strikeZoneBottom                                                 1.56  ...
# nickName                                                          NaN  ...
# nameTitle                                                         NaN  ...
# nameSuffix                                                        NaN  ...
# pronunciation                                                     NaN  ...
# nameMatrilineal                                                   NaN  ...
# hitsPer9                                                          0.0  ...
# inningsPitched                                                    0.0  ...
# gamesStarted                                                      0.0  ...
# avg                                                             0.168  ...
# atBats                                                          161.0  ...
# oppHP9                                                              0  ...
#
#                                                              ID664076  \
# id                                                             664076
# fullName                                           Garrett Cleavinger
# link                                            /api/v1/people/664076
# firstName                                                     Garrett
# lastName                                                   Cleavinger
# primaryNumber                                                      60
# birthDate                                                  1994-04-23
# currentAge                                                         30
# birthCity                                                    Lawrence
# birthStateProvince                                                 KS
# birthCountry                                                      USA
# height                                                          6' 1"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                       Garrett
# useLastName                                                Cleavinger
# middleName                                                         J.
# boxscoreName                                               Cleavinger
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2015
# mlbDebutDate                                               2020-09-17
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                        {'code': 'L', 'description': 'Left'}
# nameFirstLast                                      Garrett Cleavinger
# nameSlug                                    garrett-cleavinger-664076
# firstLastName                                      Garrett Cleavinger
# lastFirstName                                     Cleavinger, Garrett
# lastInitName                                            Cleavinger, G
# initLastName                                             G Cleavinger
# fullFMLName                                     Garrett J. Cleavinger
# fullLFMName                                    Cleavinger, Garrett J.
# strikeZoneTop                                                   3.411
# strikeZoneBottom                                                1.565
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                          7.2
# inningsPitched                                                   40.0
# gamesStarted                                                      0.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID687330  \
# id                                                             687330
# fullName                                                  Kevin Kelly
# link                                            /api/v1/people/687330
# firstName                                                       Kevin
# lastName                                                        Kelly
# primaryNumber                                                      49
# birthDate                                                  1997-11-28
# currentAge                                                         26
# birthCity                                                 Springfield
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            200
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                         Kevin
# useLastName                                                     Kelly
# middleName                                                    Clayton
# boxscoreName                                                    Kelly
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2019
# mlbDebutDate                                               2023-04-01
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                             Kevin Kelly
# nameSlug                                           kevin-kelly-687330
# firstLastName                                             Kevin Kelly
# lastFirstName                                            Kelly, Kevin
# lastInitName                                                 Kelly, K
# initLastName                                                  K Kelly
# fullFMLName                                       Kevin Clayton Kelly
# fullLFMName                                      Kelly, Kevin Clayton
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                         9.64
# inningsPitched                                                   42.0
# gamesStarted                                                      0.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID621107  \
# id                                                             621107
# fullName                                                   Zach Eflin
# link                                            /api/v1/people/621107
# firstName                                                     Zachary
# lastName                                                        Eflin
# primaryNumber                                                      24
# birthDate                                                  1994-04-08
# currentAge                                                         30
# birthCity                                                     Orlando
# birthStateProvince                                                 FL
# birthCountry                                                      USA
# height                                                          6' 6"
# weight                                                            220
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Zach
# useLastName                                                     Eflin
# middleName                                                      Adams
# boxscoreName                                                    Eflin
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2012
# mlbDebutDate                                               2016-06-14
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                              Zach Eflin
# nameSlug                                            zach-eflin-621107
# firstLastName                                              Zach Eflin
# lastFirstName                                             Eflin, Zach
# lastInitName                                                 Eflin, Z
# initLastName                                                  Z Eflin
# fullFMLName                                       Zachary Adams Eflin
# fullLFMName                                      Eflin, Zachary Adams
# strikeZoneTop                                                    3.68
# strikeZoneBottom                                                  1.7
# nickName                                                           Ef
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                 EFF-lin
# nameMatrilineal                                                   NaN
# hitsPer9                                                          9.4
# inningsPitched                                                  104.1
# gamesStarted                                                     18.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID666139  \
# id                                                             666139
# fullName                                                    Josh Lowe
# link                                            /api/v1/people/666139
# firstName                                                      Joshua
# lastName                                                         Lowe
# primaryNumber                                                      15
# birthDate                                                  1998-02-02
# currentAge                                                         26
# birthCity                                                  Chesapeake
# birthStateProvince                                                 VA
# birthCountry                                                      USA
# height                                                          6' 4"
# weight                                                            205
# active                                                           True
# primaryPosition     {'code': '9', 'name': 'Outfielder', 'type': 'O...
# useName                                                          Josh
# useLastName                                                      Lowe
# middleName                                                     Edward
# boxscoreName                                                  Lowe, J
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2016
# mlbDebutDate                                               2021-09-08
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                               Josh Lowe
# nameSlug                                             josh-lowe-666139
# firstLastName                                               Josh Lowe
# ...
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2019
# mlbDebutDate                                               2023-03-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                           Anthony Volpe
# nameSlug                                         anthony-volpe-683011
# firstLastName                                           Anthony Volpe
# lastFirstName                                          Volpe, Anthony
# lastInitName                                                 Volpe, A
# initLastName                                                  A Volpe
# fullFMLName                                     Anthony Michael Volpe
# fullLFMName                                    Volpe, Anthony Michael
# strikeZoneTop                                                    3.39
# strikeZoneBottom                                                  1.6
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                             0.251
# atBats                                                          418.0
# oppHP9                                                              0
#
#                                                              ID665966  \
# id                                                             665966
# fullName                                               Carlos Narvaez
# link                                            /api/v1/people/665966
# firstName                                                      Carlos
# lastName                                                      Narvaez
# primaryNumber                                                      94
# birthDate                                                  1998-11-26
# currentAge                                                         25
# birthCity                                                     Maracay
# birthStateProvince                                                NaN
# birthCountry                                                Venezuela
# height                                                         5' 11"
# weight                                                            190
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                        Carlos
# useLastName                                                   Narvaez
# middleName                                                       Luis
# boxscoreName                                                  Narvaez
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                         NaN
# mlbDebutDate                                               2024-07-20
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                          Carlos Narvaez
# nameSlug                                        carlos-narvaez-665966
# firstLastName                                          Carlos Narvaez
# lastFirstName                                         Narvaez, Carlos
# lastInitName                                               Narvaez, C
# initLastName                                                C Narvaez
# fullFMLName                                       Carlos Luis Narvaez
# fullLFMName                                      Narvaez, Carlos Luis
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                 Olivo
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                               1.0
# atBats                                                            1.0
# oppHP9                                                              0
#
#                                                              ID661563  \
# id                                                             661563
# fullName                                                     Luis Gil
# link                                            /api/v1/people/661563
# firstName                                                        Luis
# lastName                                                          Gil
# primaryNumber                                                      81
# birthDate                                                  1998-06-03
# currentAge                                                         26
# birthCity                                                        Azua
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 2"
# weight                                                            185
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                          Luis
# useLastName                                                       Gil
# middleName                                                      Angel
# boxscoreName                                                      Gil
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2021-08-03
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                                Luis Gil
# nameSlug                                              luis-gil-661563
# firstLastName                                                Luis Gil
# lastFirstName                                               Gil, Luis
# lastInitName                                                   Gil, L
# initLastName                                                    L Gil
# fullFMLName                                            Luis Angel Gil
# fullLFMName                                           Gil, Luis Angel
# strikeZoneTop                                                   3.467
# strikeZoneBottom                                                1.589
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                    Heel
# nameMatrilineal                                                 Brito
# hitsPer9                                                         5.45
# inningsPitched                                                  102.1
# gamesStarted                                                     19.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID655889  \
# id                                                             655889
# fullName                                             Manuel Rodríguez
# link                                            /api/v1/people/655889
# firstName                                                      Manuel
# lastName                                                    Rodríguez
# primaryNumber                                                      39
# birthDate                                                  1996-08-06
# currentAge                                                         27
# birthCity                                                      Merida
# birthStateProvince                                            Yucatan
# birthCountry                                                   Mexico
# height                                                         5' 11"
# weight                                                            210
# active                                                           True
# primaryPosition     {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...
# useName                                                        Manuel
# useLastName                                                 Rodríguez
# middleName                                                   De Jesus
# boxscoreName                                             Rodríguez, M
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2021-07-30
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                        Manuel Rodríguez
# nameSlug                                      manuel-rodriguez-655889
# firstLastName                                        Manuel Rodríguez
# lastFirstName                                       Rodríguez, Manuel
# lastInitName                                             Rodríguez, M
# initLastName                                              M Rodríguez
# fullFMLName                                 Manuel De Jesus Rodríguez
# fullLFMName                                Rodríguez, Manuel De Jesus
# strikeZoneTop                                                   3.319
# strikeZoneBottom                                                1.513
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                Caamal
# hitsPer9                                                         8.31
# inningsPitched                                                   13.0
# gamesStarted                                                      0.0
# avg                                                               0.0
# atBats                                                            0.0
# oppHP9                                                              0
#
#                                                              ID656577
# id                                                             656577
# fullName                                                 Alex Jackson
# link                                            /api/v1/people/656577
# firstName                                                   Alexander
# lastName                                                      Jackson
# primaryNumber                                                      28
# birthDate                                                  1995-12-25
# currentAge                                                         28
# birthCity                                                   San Diego
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 2"
# weight                                                            238
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                          Alex
# useLastName                                                   Jackson
# middleName                                                      James
# boxscoreName                                                  Jackson
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                        2014
# mlbDebutDate                                               2019-04-07
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Alex Jackson
# nameSlug                                          alex-jackson-656577
# firstLastName                                            Alex Jackson
# lastFirstName                                           Jackson, Alex
# lastInitName                                               Jackson, A
# initLastName                                                A Jackson
# fullFMLName                                   Alexander James Jackson
# fullLFMName                                  Jackson, Alexander James
# strikeZoneTop                                                    3.49
# strikeZoneBottom                                                 1.66
# nickName                                                          NaN
# nameTitle                                                         NaN
# nameSuffix                                                        NaN
# pronunciation                                                     NaN
# nameMatrilineal                                                   NaN
# hitsPer9                                                          0.0
# inningsPitched                                                    0.0
# gamesStarted                                                      0.0
# avg                                                             0.088
# atBats                                                           91.0
# oppHP9                                                              0
#
# [47 rows x 52 columns]
