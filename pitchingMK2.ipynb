# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   746614  6bd79b38-55bb-4164-995f-90a53079ef33
# 1   745475  aad2fd45-097a-4fb0-a801-826c9b3f50ad
# 2   746036  94181dbc-ecca-4fd3-8c65-64eab678a8cd
# 3   744828  429e512a-91e3-4daf-be0a-39f8f6d271f4
# 4   745715  2080e423-2257-437a-ac27-96ec5a77623f
# 5   744904  9448e12c-07ab-4cc7-aac2-990ba2f00bea
# 6   747090  f8c05529-1a3e-45d8-82b1-782cd7f749be
# 7   745878  99415897-4394-40f7-b051-339653ac4c67
# 8   744985  61262b76-01ac-4bd4-a595-e3bae5d1307e
# 9   746848  95ff96cc-74d1-4472-b7ba-4dcc9227e9e4
# 10  746281  99fc9351-1b96-451a-ba25-d9293dde0d77
# 11  746524  786fdb9b-3ef1-4525-b9cc-5ca747cba6a3
# 12  745632  07ba878b-6194-472d-84ed-393d5e23b190
# 13  745227  6339eba6-5788-415f-aec6-13d9f9d362ec
# 14  746118  c33054bd-195f-4f0f-a188-e793aa351c22
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/746614/feed/live        R   2024  2024-07-23T22:40:00Z
# 1   /api/v1.1/game/745475/feed/live        R   2024  2024-07-23T22:40:00Z
# 2   /api/v1.1/game/746036/feed/live        R   2024  2024-07-23T22:40:00Z
# 3   /api/v1.1/game/744828/feed/live        R   2024  2024-07-23T22:45:00Z
# 4   /api/v1.1/game/745715/feed/live        R   2024  2024-07-23T23:05:00Z
# 5   /api/v1.1/game/744904/feed/live        R   2024  2024-07-23T23:07:00Z
# 6   /api/v1.1/game/747090/feed/live        R   2024  2024-07-23T23:20:00Z
# 7   /api/v1.1/game/745878/feed/live        R   2024  2024-07-23T23:40:00Z
# 8   /api/v1.1/game/744985/feed/live        R   2024  2024-07-24T00:05:00Z
# 9   /api/v1.1/game/746848/feed/live        R   2024  2024-07-24T00:05:00Z
# 10  /api/v1.1/game/746281/feed/live        R   2024  2024-07-24T00:10:00Z
# 11  /api/v1.1/game/746524/feed/live        R   2024  2024-07-24T00:40:00Z
# 12  /api/v1.1/game/745632/feed/live        R   2024  2024-07-24T01:40:00Z
# 13  /api/v1.1/game/745227/feed/live        R   2024  2024-07-24T01:40:00Z
# 14  /api/v1.1/game/746118/feed/live        R   2024  2024-07-24T02:10:00Z
#
#    officialDate                                             status  \
# 0    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 1    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 2    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 3    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 4    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 5    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 6    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 7    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 8    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 9    2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 10   2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 11   2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 12   2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 13   2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
# 14   2024-07-23  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 52, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 60, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 52, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 51, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 48, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 63, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 27, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 57, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 51, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 53, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 52, 'losses...
# 13  {'away': {'leagueRecord': {'wins': 43, 'losses...
# 14  {'away': {'leagueRecord': {'wins': 48, 'losses...
#
#                                                 venue  ... dayNight  \
# 0   {'id': 5, 'name': 'Progressive Field', 'link':...  ...    night
# 1   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...  ...    night
# 2   {'id': 4169, 'name': 'loanDepot park', 'link':...  ...    night
# 3   {'id': 3309, 'name': 'Nationals Park', 'link':...  ...    night
# 4   {'id': 3313, 'name': 'Yankee Stadium', 'link':...  ...    night
# 5   {'id': 14, 'name': 'Rogers Centre', 'link': '/...  ...    night
# 6   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...    night
# 7   {'id': 3312, 'name': 'Target Field', 'link': '...  ...    night
# 8   {'id': 5325, 'name': 'Globe Life Field', 'link...  ...    night
# 9   {'id': 17, 'name': 'Wrigley Field', 'link': '/...  ...    night
# 10  {'id': 7, 'name': 'Kauffman Stadium', 'link': ...  ...    night
# 11  {'id': 19, 'name': 'Coors Field', 'link': '/ap...  ...    night
# 12  {'id': 10, 'name': 'Oakland Coliseum', 'link':...  ...    night
# 13  {'id': 680, 'name': 'T-Mobile Park', 'link': '...  ...    night
# 14  {'id': 22, 'name': 'Dodger Stadium', 'link': '...  ...    night
#
#     scheduledInnings  reverseHomeAwayStatus inningBreakLength gamesInSeries  \
# 0                  9                  False               120             4
# 1                  9                  False               120             3
# 2                  9                  False               120             3
# 3                  9                  False               120             3
# 4                  9                  False               145             2
# 5                  9                  False               120             3
# 6                  9                  False               120             3
# 7                  9                  False               120             3
# 8                  9                  False               120             4
# 9                  9                  False               120             3
# 10                 9                  False               120             3
# 11                 9                  False               120             3
# 12                 9                  False               120             3
# 13                 9                  False               120             3
# 14                 9                  False               120             4
#
#    seriesGameNumber seriesDescription recordSource ifNecessary  \
# 0                 2    Regular Season            S           N
# 1                 2    Regular Season            S           N
# 2                 1    Regular Season            S           N
# 3                 1    Regular Season            S           N
# 4                 1    Regular Season            S           N
# 5                 1    Regular Season            S           N
# 6                 2    Regular Season            S           N
# 7                 2    Regular Season            S           N
# 8                 2    Regular Season            S           N
# 9                 2    Regular Season            S           N
# 10                2    Regular Season            S           N
# 11                2    Regular Season            S           N
# 12                2    Regular Season            S           N
# 13                2    Regular Season            S           N
# 14                2    Regular Season            S           N
#
#     ifNecessaryDescription
# 0              Normal Game
# 1              Normal Game
# 2              Normal Game
# 3              Normal Game
# 4              Normal Game
# 5              Normal Game
# 6              Normal Game
# 7              Normal Game
# 8              Normal Game
# 9              Normal Game
# 10             Normal Game
# 11             Normal Game
# 12             Normal Game
# 13             Normal Game
# 14             Normal Game
#
# [15 rows x 28 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
# player_df.T
gameteams_df = pd.DataFrame(r['gameData']['teams'])
player_df
# Out:
#               id             fullName                   link       firstName  \
# ID647304  647304          Josh Naylor  /api/v1/people/647304  Joshua-Douglas
# ID669373  669373         Tarik Skubal  /api/v1/people/669373           Tarik
# ID689225  689225         Beau Brieske  /api/v1/people/689225            Beau
# ID687922  687922         Easton Lucas  /api/v1/people/687922          Easton
# ID682985  682985         Riley Greene  /api/v1/people/682985           Riley
# ID595978  595978        Austin Hedges  /api/v1/people/595978          Austin
# ID663947  663947         Tyler Holton  /api/v1/people/663947          Weston
# ID471911  471911      Carlos Carrasco  /api/v1/people/471911          Carlos
# ID686823  686823         Will Brennan  /api/v1/people/686823         William
# ID661403  661403       Emmanuel Clase  /api/v1/people/661403        Emmanuel
# ID658648  658648          Pedro Avila  /api/v1/people/658648           Pedro
# ID608348  608348         Carson Kelly  /api/v1/people/608348          Carson
# ID665926  665926       Andrés Giménez  /api/v1/people/665926          Andrés
# ID570482  570482          Gio Urshela  /api/v1/people/570482        Giovanny
# ID676632  676632         Bligh Madris  /api/v1/people/676632           Bligh
# ID656427  656427        Jack Flaherty  /api/v1/people/656427            Jack
# ID675540  675540        Xzavion Curry  /api/v1/people/675540         Xzavion
# ID592192  592192           Mark Canha  /api/v1/people/592192            Mark
# ID671345  671345          Jason Foley  /api/v1/people/671345           Jason
# ID666310  666310            Bo Naylor  /api/v1/people/666310            Noah
# ID681807  681807            David Fry  /api/v1/people/681807           David
# ID671922  671922           Cade Smith  /api/v1/people/671922            Cade
# ID628317  628317          Kenta Maeda  /api/v1/people/628317           Kenta
# ID608070  608070         José Ramírez  /api/v1/people/608070            José
# ID680757  680757          Steven Kwan  /api/v1/people/680757          Steven
# ID682657  682657       Angel Martínez  /api/v1/people/682657           Angel
# ID663837  663837        Matt Vierling  /api/v1/people/663837         Matthew
# ID690993  690993           Colt Keith  /api/v1/people/690993          Colten
# ID669234  669234  Justyn-Henry Malloy  /api/v1/people/669234    Justyn-Henry
# ID656716  656716       Zach McKinstry  /api/v1/people/656716         Zachary
# ID680704  680704         Nick Sandlin  /api/v1/people/680704            Nick
# ID571946  571946        Shelby Miller  /api/v1/people/571946          Shelby
# ID594902  594902           Ben Lively  /api/v1/people/594902          Edward
# ID595879  595879          Javier Báez  /api/v1/people/595879           Ednel
# ID605130  605130         Scott Barlow  /api/v1/people/605130           Scott
# ID605177  605177        Andrew Chafin  /api/v1/people/605177          Andrew
# ID682177  682177    Daniel Schneemann  /api/v1/people/682177          Daniel
# ID678877  678877       Jhonkensy Noel  /api/v1/people/678877       Jhonkensy
# ID677587  677587       Brayan Rocchio  /api/v1/people/677587          Brayan
# ID672456  672456       Keider Montero  /api/v1/people/672456          Keider
# ID671289  671289        Tyler Freeman  /api/v1/people/671289           Tyler
# ID668670  668670          Jake Rogers  /api/v1/people/668670           Jacob
# ID666214  666214           Joey Wentz  /api/v1/people/666214          Joseph
# ID628451  628451          Andy Ibáñez  /api/v1/people/628451            Andy
# ID668909  668909       Gavin Williams  /api/v1/people/668909           Gavin
# ID657265  657265     Peter Strzelecki  /api/v1/people/657265           Peter
# ID683769  683769        Hunter Gaddis  /api/v1/people/683769          Hunter
# ID682120  682120           Tim Herrin  /api/v1/people/682120             Tim
# ID676440  676440         Tanner Bibee  /api/v1/people/676440          Tanner
# ID676684  676684            Will Vest  /api/v1/people/676684         William
# ID672761  672761        Wenceel Pérez  /api/v1/people/672761         Wenceel
# ID656412  656412           Alex Faedo  /api/v1/people/656412       Alexander
#
#             lastName primaryNumber   birthDate currentAge  \
# ID647304      Naylor            22  1997-06-22         27
# ID669373      Skubal            29  1996-11-20         27
# ID689225     Brieske             4  1998-04-04         26
# ID687922       Lucas            57  1996-09-23         27
# ID682985      Greene            31  2000-09-28         23
# ID595978      Hedges            27  1992-08-18         31
# ID663947      Holton            87  1996-06-13         28
# ID471911    Carrasco            59  1987-03-21         37
# ID686823     Brennan            17  1998-02-02         26
# ID661403       Clase            48  1998-03-18         26
# ID658648       Avila            60  1997-01-14         27
# ID608348       Kelly            15  1994-07-14         30
# ID665926     Giménez             0  1998-09-04         25
# ID570482     Urshela            13  1991-10-11         32
# ID676632      Madris            40  1996-02-29         28
# ID656427    Flaherty             9  1995-10-15         28
# ID675540       Curry            44  1998-07-27         25
# ID592192       Canha            21  1989-02-15         35
# ID671345       Foley            68  1995-11-01         28
# ID666310      Naylor            23  2000-02-21         24
# ID681807         Fry             6  1995-11-20         28
# ID671922       Smith            36  1999-05-09         25
# ID628317       Maeda            18  1988-04-11         36
# ID608070     Ramírez            11  1992-09-17         31
# ID680757        Kwan            38  1997-09-05         26
# ID682657    Martínez             1  2002-01-27         22
# ID663837    Vierling             8  1996-09-16         27
# ID690993       Keith            33  2001-08-14         22
# ID669234      Malloy            44  2000-02-19         24
# ID656716   McKinstry            39  1995-04-29         29
# ID680704     Sandlin            52  1997-01-10         27
# ID571946      Miller             7  1990-10-10         33
# ID594902      Lively            39  1992-03-05         32
# ID595879        Báez            28  1992-12-01         31
# ID605130      Barlow            58  1992-12-18         31
# ID605177      Chafin            17  1990-06-17         34
# ID682177  Schneemann            10  1997-01-23         27
# ID678877        Noel            43  2001-07-15         23
# ID677587     Rocchio             4  2001-01-13         23
# ID672456     Montero            54  2000-07-06         24
# ID671289     Freeman             2  1999-05-21         25
# ID668670      Rogers            34  1995-04-18         29
# ID666214       Wentz            43  1997-10-06         26
# ID628451      Ibáñez            77  1993-04-03         31
# ID668909    Williams            32  1999-07-26         24
# ID657265  Strzelecki            34  1994-10-24         29
# ID683769      Gaddis            33  1998-04-09         26
# ID682120      Herrin            29  1996-10-08         27
# ID676440       Bibee            28  1999-03-05         25
# ID676684        Vest            19  1995-06-06         29
# ID672761       Pérez            46  1999-10-30         24
# ID656412       Faedo            49  1995-11-12         28
#
#                      birthCity birthStateProvince  ...        firstLastName  \
# ID647304           Mississauga                 ON  ...          Josh Naylor
# ID669373               Hayward                 CA  ...         Tarik Skubal
# ID689225              Chandler                 AZ  ...         Beau Brieske
# ID687922         Thousand Oaks                 CA  ...         Easton Lucas
# ID682985               Orlando                 FL  ...         Riley Greene
# ID595978   San Juan Capistrano                 CA  ...        Austin Hedges
# ID663947           Tallahassee                 FL  ...         Tyler Holton
# ID471911          Barquisimeto                NaN  ...      Carlos Carrasco
# ID686823      Colorado Springs                 CO  ...         Will Brennan
# ID661403          Rio San Juan                NaN  ...       Emmanuel Clase
# ID658648               Caracas                NaN  ...          Pedro Avila
# ID608348               Chicago                 IL  ...         Carson Kelly
# ID665926          Barquisimeto                NaN  ...       Andrés Giménez
# ID570482             Cartagena                NaN  ...          Gio Urshela
# ID676632             Las Vegas                 NV  ...         Bligh Madris
# ID656427               Burbank                 CA  ...        Jack Flaherty
# ID675540            Orangeburg                 SC  ...        Xzavion Curry
# ID592192              San Jose                 CA  ...           Mark Canha
# ID671345             Manhasset                 NY  ...          Jason Foley
# ID666310           Mississauga                 ON  ...            Bo Naylor
# ID681807           Colleyville                 TX  ...            David Fry
# ID671922             Vancouver                 BC  ...           Cade Smith
# ID628317                 Osaka                NaN  ...          Kenta Maeda
# ID608070                  Bani                NaN  ...         José Ramírez
# ID680757             Los Gatos                 CA  ...          Steven Kwan
# ID682657         Santo Domingo                NaN  ...       Angel Martínez
# ID663837             St. Louis                 MO  ...        Matt Vierling
# ID690993            Zanesville                 OH  ...           Colt Keith
# ID669234              New York                 NY  ...  Justyn-Henry Malloy
# ID656716                Toledo                 OH  ...       Zach McKinstry
# ID680704                 Evans                 GA  ...         Nick Sandlin
# ID571946            Round Rock                 TX  ...        Shelby Miller
# ID594902             Pensacola                 FL  ...           Ben Lively
# ID595879               Bayamon                NaN  ...          Javier Báez
# ID605130            New London                 CT  ...         Scott Barlow
# ID605177             Kettering                 OH  ...        Andrew Chafin
# ID682177             San Diego                 CA  ...    Daniel Schneemann
# ID678877  San Pedro de Macoris                NaN  ...       Jhonkensy Noel
# ID677587               Caracas                NaN  ...       Brayan Rocchio
# ID672456  Santa Teresa del Tuy                NaN  ...       Keider Montero
# ID671289      Rancho Cucamonga                 CA  ...        Tyler Freeman
# ID668670                Canyon                 TX  ...          Jake Rogers
# ID666214              Lawrence                 KS  ...           Joey Wentz
# ID628451                Havana                NaN  ...          Andy Ibáñez
# ID668909          Fayetteville                 NC  ...       Gavin Williams
# ID657265                Queens                 NY  ...     Peter Strzelecki
# ID683769                Canton                 GA  ...        Hunter Gaddis
# ID682120           Terre Haute                 IN  ...           Tim Herrin
# ID676440         Mission Viejo                 CA  ...         Tanner Bibee
# ID676684               Houston                 TX  ...            Will Vest
# ID672761                  Azua                NaN  ...        Wenceel Pérez
# ID656412                 Tampa                 FL  ...           Alex Faedo
#
#                  lastFirstName   lastInitName  initLastName  \
# ID647304          Naylor, Josh      Naylor, J      J Naylor
# ID669373         Skubal, Tarik      Skubal, T      T Skubal
# ID689225         Brieske, Beau     Brieske, B     B Brieske
# ID687922         Lucas, Easton       Lucas, E       E Lucas
# ID682985         Greene, Riley      Greene, R      R Greene
# ID595978        Hedges, Austin      Hedges, A      A Hedges
# ID663947         Holton, Tyler      Holton, T      T Holton
# ID471911      Carrasco, Carlos    Carrasco, C    C Carrasco
# ID686823         Brennan, Will     Brennan, W     W Brennan
# ID661403       Clase, Emmanuel       Clase, E       E Clase
# ID658648          Avila, Pedro       Avila, P       P Avila
# ID608348         Kelly, Carson       Kelly, C       C Kelly
# ID665926       Giménez, Andrés     Giménez, A     A Gimenez
# ID570482          Urshela, Gio     Urshela, G     G Urshela
# ID676632         Madris, Bligh      Madris, B      B Madris
# ID656427        Flaherty, Jack    Flaherty, J    J Flaherty
# ID675540        Curry, Xzavion       Curry, X       X Curry
# ID592192           Canha, Mark       Canha, M       M Canha
# ID671345          Foley, Jason       Foley, J       J Foley
# ID666310            Naylor, Bo      Naylor, B      B Naylor
# ID681807            Fry, David         Fry, D         D Fry
# ID671922           Smith, Cade       Smith, C       C Smith
# ID628317          Maeda, Kenta       Maeda, K       K Maeda
# ID608070         Ramírez, José     Ramírez, J     J Ramírez
# ID680757          Kwan, Steven        Kwan, S        S Kwan
# ID682657       Martínez, Angel    Martínez, A    A Martínez
# ID663837        Vierling, Matt    Vierling, M    M Vierling
# ID690993           Keith, Colt       Keith, C       C Keith
# ID669234  Malloy, Justyn-Henry      Malloy, J      J Malloy
# ID656716       McKinstry, Zach   McKinstry, Z   Z McKinstry
# ID680704         Sandlin, Nick     Sandlin, N     N Sandlin
# ID571946        Miller, Shelby      Miller, S      S Miller
# ID594902           Lively, Ben      Lively, B      B Lively
# ID595879          Báez, Javier        Báez, J        J Báez
# ID605130         Barlow, Scott      Barlow, S      S Barlow
# ID605177        Chafin, Andrew      Chafin, A      A Chafin
# ID682177    Schneemann, Daniel  Schneemann, D  D Schneemann
# ID678877       Noel, Jhonkensy        Noel, J        J Noel
# ID677587       Rocchio, Brayan     Rocchio, B     B Rocchio
# ID672456       Montero, Keider     Montero, K     K Montero
# ID671289        Freeman, Tyler     Freeman, T     T Freeman
# ID668670          Rogers, Jake      Rogers, J      J Rogers
# ID666214           Wentz, Joey       Wentz, J       J Wentz
# ID628451          Ibáñez, Andy      Ibáñez, A      A Ibáñez
# ID668909       Williams, Gavin    Williams, G    G Williams
# ID657265     Strzelecki, Peter  Strzelecki, P  P Strzelecki
# ID683769        Gaddis, Hunter      Gaddis, H      H Gaddis
# ID682120           Herrin, Tim      Herrin, T      T Herrin
# ID676440         Bibee, Tanner       Bibee, T       T Bibee
# ID676684            Vest, Will        Vest, W        W Vest
# ID672761        Pérez, Wenceel       Pérez, W       W Pérez
# ID656412           Faedo, Alex       Faedo, A       A Faedo
#
#                           fullFMLName                   fullLFMName  \
# ID647304  Joshua-Douglas James Naylor  Naylor, Joshua-Douglas James
# ID669373          Tarik Daniel Skubal          Skubal, Tarik Daniel
# ID689225          Beau Conner Brieske          Brieske, Beau Conner
# ID687922           Easton James Lucas           Lucas, Easton James
# ID682985            Riley Alan Greene            Greene, Riley Alan
# ID595978        Austin Charles Hedges        Hedges, Austin Charles
# ID663947          Weston Tyler Holton          Holton, Weston Tyler
# ID471911         Carlos Luis Carrasco         Carrasco, Carlos Luis
# ID686823       William Daniel Brennan       Brennan, William Daniel
# ID661403               Emmanuel Clase               Clase, Emmanuel
# ID658648           Pedro Manuel Avila           Avila, Pedro Manuel
# ID608348        Carson Franklin Kelly        Kelly, Carson Franklin
# ID665926       Andrés Alfonso Giménez       Giménez, Andrés Alfonso
# ID570482             Giovanny Urshela             Urshela, Giovanny
# ID676632            Bligh John Madris            Madris, Bligh John
# ID656427           Jack Rafe Flaherty           Flaherty, Jack Rafe
# ID675540         Xzavion Rashan Curry         Curry, Xzavion Rashan
# ID592192             Mark David Canha             Canha, Mark David
# ID671345           Jason Joseph Foley           Foley, Jason Joseph
# ID666310               Noah G. Naylor               Naylor, Noah G.
# ID681807                   David  Fry                    Fry, David
# ID671922    Cade Jared Benjamin Smith    Smith, Cade Jared Benjamin
# ID628317                  Kenta Maeda                  Maeda, Kenta
# ID608070         José Enrique Ramírez         Ramírez, José Enrique
# ID680757           Steven Robert Kwan           Kwan, Steven Robert
# ID682657               Angel Martínez              Martínez, Angel
# ID663837     Matthew Gregory Vierling     Vierling, Matthew Gregory
# ID690993          Colten Thomas Keith          Keith, Colten Thomas
# ID669234   Justyn-Henry Conrad Malloy   Malloy, Justyn-Henry Conrad
# ID656716            Zachary McKinstry            McKinstry, Zachary
# ID680704          Nick Howard Sandlin          Sandlin, Nick Howard
# ID571946        Shelby Charles Miller        Miller, Shelby Charles
# ID594902        Edward Bennett Lively        Lively, Edward Bennett
# ID595879            Ednel Javier Báez            Báez, Ednel Javier
# ID605130              Scott A. Barlow              Barlow, Scott A.
# ID605177        Andrew Gregory Chafin        Chafin, Andrew Gregory
# ID682177            Daniel Schneemann           Schneemann, Daniel
# ID678877               Jhonkensy Noel              Noel, Jhonkensy
# ID677587         Brayan Hommy Rocchio         Rocchio, Brayan Hommy
# ID672456       Keider Eduardo Montero       Montero, Keider Eduardo
# ID671289         Tyler Andrew Freeman         Freeman, Tyler Andrew
# ID668670             Jacob Ray Rogers             Rogers, Jacob Ray
# ID666214         Joseph Barrett Wentz         Wentz, Joseph Barrett
# ID628451                  Andy Ibáñez                  Ibáñez, Andy
# ID668909         Gavin Scott Williams         Williams, Gavin Scott
# ID657265          Peter J. Strzelecki          Strzelecki, Peter J.
# ID683769           Hunter Reid Gaddis           Gaddis, Hunter Reid
# ID682120            Tim Edward Herrin            Herrin, Tim Edward
# ID676440           Tanner Hayes Bibee           Bibee, Tanner Hayes
# ID676684            William Lane Vest            Vest, William Lane
# ID672761         Wenceel Xavier Pérez         Pérez, Wenceel Xavier
# ID656412      Alexander Michael Faedo      Faedo, Alexander Michael
#
#          strikeZoneTop strikeZoneBottom     pronunciation nameMatrilineal
# ID647304          3.15             1.51               NaN             NaN
# ID669373          3.49            1.601  Tare-ick sku-ble             NaN
# ID689225          3.49            1.601               NaN             NaN
# ID687922         3.549            1.627               NaN             NaN
# ID682985          3.73             1.71               NaN             NaN
# ID595978           3.3             1.49               NaN             NaN
# ID663947         3.467            1.589               NaN             NaN
# ID471911         3.549            1.627      cuh-RAZZ-coh             NaN
# ID686823          3.29             1.55               NaN             NaN
# ID661403         3.467            1.589            clas-A      De La Cruz
# ID658648          3.33             1.48         AH-vee-la         Puentes
# ID608348          3.36             1.56               NaN             NaN
# ID665926          3.23             1.47         he-MEN-ez          Osorio
# ID570482          3.51             1.63      urr-SHELL-ah             NaN
# ID676632          3.36             1.57               NaN             NaN
# ID656427          3.48             1.62               NaN             NaN
# ID675540         3.371            1.535               NaN             NaN
# ID592192          3.32             1.44            CAN-uh             NaN
# ID671345         3.549            1.627               NaN             NaN
# ID666310          3.25             1.53               NaN             NaN
# ID681807          3.35             1.53               NaN             NaN
# ID671922         3.575            1.681               NaN             NaN
# ID628317         3.411            1.565        mah-EH-dah             NaN
# ID608070          3.42             1.64               NaN             NaN
# ID680757          3.23              1.5               NaN             NaN
# ID682657          3.23             1.46               NaN             NaN
# ID663837          3.48             1.63         VEER-ling             NaN
# ID690993          3.34             1.55               NaN             NaN
# ID669234          3.52             1.62               NaN             NaN
# ID656716           3.5              1.6      muh-KIN-stry             NaN
# ID680704         3.319            1.513               NaN             NaN
# ID571946          3.49            1.601               NaN             NaN
# ID594902         3.549            1.627               NaN             NaN
# ID595879          3.48             1.59               NaN             NaN
# ID605130          3.49            1.601               NaN             NaN
# ID605177         3.467            1.589          CHAY-fin             NaN
# ID682177          3.41             1.65               NaN             NaN
# ID678877          3.52             1.72               NaN          Do Lee
# ID677587          3.14             1.45               NaN        Zambrano
# ID672456         3.411            1.565               NaN        Martinez
# ID671289          3.24             1.41               NaN             NaN
# ID668670          3.34             1.48               NaN             NaN
# ID666214         3.575            1.681               NaN             NaN
# ID628451           3.2             1.48       ee-BAHN-yez       Velazquez
# ID668909         3.656            1.677               NaN             NaN
# ID657265         3.467            1.589               NaN             NaN
# ID683769         3.656            1.677               NaN             NaN
# ID682120         3.656            1.677               NaN             NaN
# ID676440         3.467            1.589               NaN             NaN
# ID676684         3.371            1.535               NaN             NaN
# ID672761          3.21             1.45               NaN          Vargas
# ID656412         3.575            1.681       fie-a-dough             NaN
#
# [52 rows x 39 columns]

# %%
def get_hitsPer9(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['hitsPer9Inn'])

def get_inningsPitched(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['inningsPitched'])

def get_gamesStarted(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
    if player['position'] != 'P':
        return 0
    return float(player['stats'][0]['stats']['gamesStarted'])

player_hitsPer9 = player_df.id.apply(get_hitsPer9)
player_df = player_df.assign(hitsPer9=player_hitsPer9.values)

player_inningsPitched = player_df.id.apply(get_inningsPitched)
player_df = player_df.assign(inningsPitched=player_inningsPitched.values)

player_gamesStarted = player_df.id.apply(get_gamesStarted)
player_df = player_df.assign(gamesStarted=player_gamesStarted.values)

# %%
pitchers = player_df['hitsPer9'] != 0
pitcher_df = player_df.loc[pitchers]

startingPitchers = player_df['gamesStarted'] != 0
startingPitcher_df = player_df.loc[startingPitchers]
startingPitcher_df.sort_values(by = ['hitsPer9'], ascending = True)
# Out:
#               id         fullName                   link  firstName  lastName  \
# ID663947  663947     Tyler Holton  /api/v1/people/663947     Weston    Holton
# ID669373  669373     Tarik Skubal  /api/v1/people/669373      Tarik    Skubal
# ID656427  656427    Jack Flaherty  /api/v1/people/656427       Jack  Flaherty
# ID656412  656412       Alex Faedo  /api/v1/people/656412  Alexander     Faedo
# ID676440  676440     Tanner Bibee  /api/v1/people/676440     Tanner     Bibee
# ID689225  689225     Beau Brieske  /api/v1/people/689225       Beau   Brieske
# ID594902  594902       Ben Lively  /api/v1/people/594902     Edward    Lively
# ID672456  672456   Keider Montero  /api/v1/people/672456     Keider   Montero
# ID471911  471911  Carlos Carrasco  /api/v1/people/471911     Carlos  Carrasco
# ID675540  675540    Xzavion Curry  /api/v1/people/675540    Xzavion     Curry
# ID668909  668909   Gavin Williams  /api/v1/people/668909      Gavin  Williams
# ID628317  628317      Kenta Maeda  /api/v1/people/628317      Kenta     Maeda
#
#          primaryNumber   birthDate currentAge             birthCity  \
# ID663947            87  1996-06-13         28           Tallahassee
# ID669373            29  1996-11-20         27               Hayward
# ID656427             9  1995-10-15         28               Burbank
# ID656412            49  1995-11-12         28                 Tampa
# ID676440            28  1999-03-05         25         Mission Viejo
# ID689225             4  1998-04-04         26              Chandler
# ID594902            39  1992-03-05         32             Pensacola
# ID672456            54  2000-07-06         24  Santa Teresa del Tuy
# ID471911            59  1987-03-21         37          Barquisimeto
# ID675540            44  1998-07-27         25            Orangeburg
# ID668909            32  1999-07-26         24          Fayetteville
# ID628317            18  1988-04-11         36                 Osaka
#
#          birthStateProvince  ... initLastName              fullFMLName  \
# ID663947                 FL  ...     T Holton      Weston Tyler Holton
# ID669373                 CA  ...     T Skubal      Tarik Daniel Skubal
# ID656427                 CA  ...   J Flaherty       Jack Rafe Flaherty
# ID656412                 FL  ...      A Faedo  Alexander Michael Faedo
# ID676440                 CA  ...      T Bibee       Tanner Hayes Bibee
# ID689225                 AZ  ...    B Brieske      Beau Conner Brieske
# ID594902                 FL  ...     B Lively    Edward Bennett Lively
# ID672456                NaN  ...    K Montero   Keider Eduardo Montero
# ID471911                NaN  ...   C Carrasco     Carlos Luis Carrasco
# ID675540                 SC  ...      X Curry     Xzavion Rashan Curry
# ID668909                 NC  ...   G Williams     Gavin Scott Williams
# ID628317                NaN  ...      K Maeda              Kenta Maeda
#
#                        fullLFMName strikeZoneTop strikeZoneBottom  \
# ID663947      Holton, Weston Tyler         3.467            1.589
# ID669373      Skubal, Tarik Daniel          3.49            1.601
# ID656427       Flaherty, Jack Rafe          3.48             1.62
# ID656412  Faedo, Alexander Michael         3.575            1.681
# ID676440       Bibee, Tanner Hayes         3.467            1.589
# ID689225      Brieske, Beau Conner          3.49            1.601
# ID594902    Lively, Edward Bennett         3.549            1.627
# ID672456   Montero, Keider Eduardo         3.411            1.565
# ID471911     Carrasco, Carlos Luis         3.549            1.627
# ID675540     Curry, Xzavion Rashan         3.371            1.535
# ID668909     Williams, Gavin Scott         3.656            1.677
# ID628317              Maeda, Kenta         3.411            1.565
#
#              pronunciation nameMatrilineal hitsPer9 inningsPitched  \
# ID663947               NaN             NaN     6.00           54.0
# ID669373  Tare-ick sku-ble             NaN     6.66          123.0
# ID656427               NaN             NaN     7.15          100.2
# ID656412       fie-a-dough             NaN     7.29           45.2
# ID676440               NaN             NaN     7.56          110.2
# ID689225               NaN             NaN     8.10           33.1
# ID594902               NaN             NaN     8.10           93.1
# ID672456               NaN        Martinez     9.66           31.2
# ID471911      cuh-RAZZ-coh             NaN     9.85           91.1
# ID675540               NaN             NaN     9.87           17.1
# ID668909               NaN             NaN    10.00           18.0
# ID628317        mah-EH-dah             NaN    10.72           71.1
#
#          gamesStarted
# ID663947          1.0
# ID669373         20.0
# ID656427         17.0
# ID656412          1.0
# ID676440         20.0
# ID689225          1.0
# ID594902         17.0
# ID672456          5.0
# ID471911         18.0
# ID675540          3.0
# ID668909          4.0
# ID628317         16.0
#
# [12 rows x 42 columns]

# %%
away_id = int(gameteams_df['away']['id'])
home_id = int(gameteams_df['home']['id'])
print(statsapi.team_leaders(away_id,'gamesStarted',limit=3,season=2024))
# Out:
# Rank Name                 Value
#  1   Tarik Skubal          20
#  2   Reese Olson           19
#  3   Jack Flaherty         17

# %%
away_players = statsapi.lookup_player(away_id)
away_avg_HP9 = 0.0
num_away_pitchers = 0.0

for index in range (0, len(away_players)):
    guy = away_players[index]
    if int(guy['primaryPosition']['code']) == 1:
        dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
        if dude['stats'][0]['stats']['gamesStarted'] >= 0:
            away_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
            num_away_pitchers += 1
away_avg_HP9 /= num_away_pitchers
away_avg_HP9
# Out:
# 9.186666666666666

# %%
player = statsapi.player_stat_data(694973, group= "pitching", type="season", sportId=1)
# player

# %%
home_players = statsapi.lookup_player(home_id)
home_avg_HP9 = 0.0
num_home_pitchers = 0.0

for index in range (0, len(home_players)):
    guy = home_players[index]
    if int(guy['primaryPosition']['code']) == 1:
        dude = statsapi.player_stat_data(guy['id'], group= "pitching", type="season", sportId=1)
        if dude['stats'][0]['stats']['gamesStarted'] >= 17:
            home_avg_HP9 += float(dude['stats'][0]['stats']['hitsPer9Inn'])
            num_home_pitchers += 1
home_avg_HP9 /= num_home_pitchers
home_avg_HP9
# Out:
# 8.955

# %%
def get_avg(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['avg'])

def get_atBats(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['atBats']) 


averages = player_df.id.apply(get_avg)
player_df = player_df.assign(avg=averages.values)

player_atBats = player_df.id.apply(get_atBats)
player_df = player_df.assign(atBats=player_atBats.values)

# player_df

# %%
batScore = player_df.avg * player_df.atBats / 30
player_df = player_df.assign(batScore=batScore.values)

dayScore = player_df.batScore * 0
player_df = player_df.assign(dayScore=dayScore.values)

oppHP9 = player_df.id * 0
player_df = player_df.assign(oppHP9=oppHP9.values)

# %%
s = HOST + '/api/v1/schedule?sportId=1&hydrate=probablePitcher&startDate=2024-07-23&endDate=2024-07-23'
t = requests.get(url=s).json()
t_df = pd.DataFrame(t['dates'][0]['games'])
# print(t_df['teams'][1]['home']['probablePitcher']['id'])
print(t_df['teams'][1]['home'].get('probablePitcher'))
home_pitcher_id = t_df['teams'][1]['home']['probablePitcher']['id']
home_pitcher = player_df.loc[player_df['id'] == home_pitcher_id]
# Out:
# {'id': 694973, 'fullName': 'Paul Skenes', 'link': '/api/v1/people/694973'}
# Empty DataFrame
# Columns: [id, fullName, link, firstName, lastName, primaryNumber, birthDate, currentAge, birthCity, birthStateProvince, birthCountry, height, weight, active, primaryPosition, useName, useLastName, middleName, boxscoreName, nickName, gender, isPlayer, isVerified, draftYear, mlbDebutDate, batSide, pitchHand, nameFirstLast, nameSlug, firstLastName, lastFirstName, lastInitName, initLastName, fullFMLName, fullLFMName, strikeZoneTop, strikeZoneBottom, pronunciation, nameMatrilineal, hitsPer9, inningsPitched, gamesStarted, avg, atBats, batScore, oppHP9, dayScore]
# Index: []
#
# [0 rows x 47 columns]

# %%
for game in range (0, len(t_df)):
    url = HOST + df.loc[game,'link']
    r = requests.get(url=url).json()
    gameteams_df = pd.DataFrame(r['gameData']['teams'])
    player_df = pd.DataFrame(r['gameData']['players'])
    player_df = player_df.T

    def get_avg(player_id):
        player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
        if player['position'] == 'P':
            return 0
        return float(player['stats'][0]['stats']['avg'])

    def get_atBats(player_id):
        player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
        if player['position'] == 'P':
            return 0
        return float(player['stats'][0]['stats']['atBats'])

    def get_hitsPer9(player_id):
        player = statsapi.player_stat_data(int(player_id), group= "pitching", type="season", sportId=1)
        if player['position'] != 'P':
            return 0
        return float(player['stats'][0]['stats']['hitsPer9Inn'])
    
    averages = player_df.id.apply(get_avg)
    player_df = player_df.assign(avg=averages.values)
    
    player_atBats = player_df.id.apply(get_atBats)
    player_df = player_df.assign(atBats=player_atBats.values)

    player_hitsPer9 = player_df.id.apply(get_hitsPer9)
    player_df = player_df.assign(hitsPer9=player_hitsPer9.values)

    oppHP9 = player_df.id * 0
    player_df = player_df.assign(oppHP9=oppHP9.values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[274], line 32
#      29 player_atBats = player_df.id.apply(get_atBats)
#      30 player_df = player_df.assign(atBats=player_atBats.values)
# ---> 32 player_hitsPer9 = player_df.id.apply(get_hitsPer9)
#      33 player_df = player_df.assign(hitsPer9=player_hitsPer9.values)
#      35 oppHP9 = player_df.id * 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[274], line 24, in get_hitsPer9(player_id)
#      22 if player['position'] != 'P':
#      23     return 0
# ---> 24 return float(player['stats'][0]['stats']['hitsPer9Inn'])
#
# IndexError: list index out of range

# %% [markdown]
# ### The code below iterates through all of today's games and applies the HP9 of the opposing pitcher to the dayScore of the hitters

# %%
for game in range (0, len(t_df)):
    url = HOST + df.loc[game,'link']
    r = requests.get(url=url).json()
    gameteams_df = pd.DataFrame(r['gameData']['teams'])
    player_df = pd.DataFrame(r['gameData']['players'])
    player_df = player_df.T

    away_pitcher_id = t_df['teams'][game]['away']['probablePitcher']['id']
    away_pitcher = player_df.loc[player_df['id'] == away_pitcher_id]
    away_HP9 = float(away_pitcher['hitsPer9'].iloc[0])
    
    home_pitcher_id = t_df['teams'][game]['home']['probablePitcher']['id']
    home_pitcher = player_df.loc[player_df['id'] == home_pitcher_id]
    home_HP9 = float(home_pitcher['hitsPer9'].iloc[0])

    for index in range (0, len(away_players)):
        guy_id = away_players[index]['id']
        player_df.loc[player_df['id'] == guy_id, 'oppHP9'] = home_HP9
    for index in range (0, len(home_players)):
        guy_id = home_players[index]['id']
        player_df.loc[player_df['id'] == guy_id, 'oppHP9'] = away_HP9

    
player_df.T

# %%
batScore = player_df.avg * player_df.atBats / 30
player_df = player_df.assign(batScore=batScore.values)

dayScore = player_df.batScore + player_df.oppHP9
player_df = player_df.assign(dayScore=dayScore.values)
