# %% [markdown]
# ### Following the example from https://chineloosuji.medium.com/web-scraping-stats-game-scores-from-mlb-com-using-requests-library-b3c32e2b2ec9

# %%
# Import necessary modules
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
import time
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# This URL requests data from the MLB API for all the teams overall data:

# %%
url = 'https://bdfed.stitch.mlbinfra.com/bdfed/stats/team?stitch_env=prod&sportId=1&gameType=R&group=hitting&order=desc&sortStat=homeRuns&stats=season&season=2024&limit=30&offset=0'

# %%
r = requests.get(url=url).json()

# %%
df = pd.DataFrame(r['stats'])
df
# Out:
#     year  type  rank      shortName  teamId teamAbbrev               teamName  \
# 0   2024  team     1      Baltimore     110        BAL      Baltimore Orioles
# 1   2024  team     2     NY Yankees     147        NYY       New York Yankees
# 2   2024  team     3     LA Dodgers     119        LAD    Los Angeles Dodgers
# 3   2024  team     4        NY Mets     121        NYM          New York Mets
# 4   2024  team     5   Philadelphia     143        PHI  Philadelphia Phillies
# 5   2024  team     6      Minnesota     142        MIN        Minnesota Twins
# 6   2024  team     7        Oakland     133        OAK      Oakland Athletics
# 7   2024  team     7      San Diego     135         SD       San Diego Padres
# 8   2024  team     9        Houston     117        HOU         Houston Astros
# 9   2024  team    10      Cleveland     114        CLE    Cleveland Guardians
# 10  2024  team    11         Boston     111        BOS         Boston Red Sox
# ...

# %% [markdown]
# Next, we should figure out how to call the API for the games on each day.

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745724  b6d7215e-13ca-41ec-bd09-a5fb467c09e5
# 1   745885  0fd7b32c-a6dd-4eb1-b006-a3be3356a79e
# 2   746856  3db8a4c0-178f-4e10-801a-039f1eb7fb5f
# 3   745476  30063974-c609-4855-8008-85713d5d7a88
# 4   744835  eb7aae7f-ecd4-4c17-9abf-1a26fee10f12
# 5   744995  7f71d8a3-7f50-4c0f-9d99-ea0acccb0088
# 6   745642  8f8eeffa-f4a0-48ff-84fd-05615fc6b2b2
# 7   746694  0b048c1f-1532-4c74-8b40-01c1ca9870e3
# 8   746615  665c587f-fff8-4cf7-ae06-522df223fc42
# 9   745235  99ca8a4f-eb23-4e50-aad8-d27bcd8d108e
# 10  746044  d601b05a-5fec-4238-9441-4031c9128cfb
# 11  747099  79057cd4-f8f8-4194-af55-cef95b71bb23
# 12  746129  10816efa-777f-41a0-adea-fa411b09edf0
# 13  746529  82342214-5cdd-414f-9279-19ff99e8c235
# 14  745395  0db13004-99b5-481f-9608-6d248c17e50c
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745724/feed/live        R   2024  2024-07-06T17:05:00Z
# ...

# %%
df.loc[14,'teams']
# Out:
# {'away': {'leagueRecord': {'wins': 43, 'losses': 45, 'pct': '.489'},
#   'team': {'id': 109,
#    'name': 'Arizona Diamondbacks',
#    'link': '/api/v1/teams/109'},
#   'splitSquad': False,
#   'seriesNumber': 29},
#  'home': {'leagueRecord': {'wins': 49, 'losses': 43, 'pct': '.533'},
#   'team': {'id': 135, 'name': 'San Diego Padres', 'link': '/api/v1/teams/135'},
#   'splitSquad': False,
#   'seriesNumber': 30}}
