# %% [markdown]
# ### Testing out the MLB Stats API

# %%
# Import necessary modules
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# How to call the API for the games on each day:

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745724  b6d7215e-13ca-41ec-bd09-a5fb467c09e5
# 1   745885  0fd7b32c-a6dd-4eb1-b006-a3be3356a79e
# 2   746856  3db8a4c0-178f-4e10-801a-039f1eb7fb5f
# 3   745476  30063974-c609-4855-8008-85713d5d7a88
# 4   744835  eb7aae7f-ecd4-4c17-9abf-1a26fee10f12
# 5   744995  7f71d8a3-7f50-4c0f-9d99-ea0acccb0088
# 6   745642  8f8eeffa-f4a0-48ff-84fd-05615fc6b2b2
# 7   746694  0b048c1f-1532-4c74-8b40-01c1ca9870e3
# 8   746615  665c587f-fff8-4cf7-ae06-522df223fc42
# 9   745235  99ca8a4f-eb23-4e50-aad8-d27bcd8d108e
# 10  746044  d601b05a-5fec-4238-9441-4031c9128cfb
# 11  747099  79057cd4-f8f8-4194-af55-cef95b71bb23
# 12  746129  10816efa-777f-41a0-adea-fa411b09edf0
# 13  746529  82342214-5cdd-414f-9279-19ff99e8c235
# 14  745395  0db13004-99b5-481f-9608-6d248c17e50c
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745724/feed/live        R   2024  2024-07-06T17:05:00Z
# 1   /api/v1.1/game/745885/feed/live        R   2024  2024-07-06T18:10:00Z
# 2   /api/v1.1/game/746856/feed/live        R   2024  2024-07-06T18:20:00Z
# 3   /api/v1.1/game/745476/feed/live        R   2024  2024-07-06T20:05:00Z
# 4   /api/v1.1/game/744835/feed/live        R   2024  2024-07-06T20:05:00Z
# 5   /api/v1.1/game/744995/feed/live        R   2024  2024-07-06T20:05:00Z
# 6   /api/v1.1/game/745642/feed/live        R   2024  2024-07-06T20:07:00Z
# 7   /api/v1.1/game/746694/feed/live        R   2024  2024-07-06T20:10:00Z
# 8   /api/v1.1/game/746615/feed/live        R   2024  2024-07-06T20:10:00Z
# 9   /api/v1.1/game/745235/feed/live        R   2024  2024-07-06T20:10:00Z
# 10  /api/v1.1/game/746044/feed/live        R   2024  2024-07-06T20:10:00Z
# 11  /api/v1.1/game/747099/feed/live        R   2024  2024-07-06T23:15:00Z
# 12  /api/v1.1/game/746129/feed/live        R   2024  2024-07-06T23:15:00Z
# 13  /api/v1.1/game/746529/feed/live        R   2024  2024-07-07T01:10:00Z
# 14  /api/v1.1/game/745395/feed/live        R   2024  2024-07-07T01:40:00Z
#
#    officialDate                                             status  \
# 0    2024-07-06  {'abstractGameState': 'Final', 'codedGameState...
# 1    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 2    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 3    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 4    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 5    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 6    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 7    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 8    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 9    2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 10   2024-07-06  {'abstractGameState': 'Live', 'codedGameState'...
# 11   2024-07-06  {'abstractGameState': 'Preview', 'codedGameSta...
# 12   2024-07-06  {'abstractGameState': 'Preview', 'codedGameSta...
# 13   2024-07-06  {'abstractGameState': 'Preview', 'codedGameSta...
# 14   2024-07-06  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 48, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 46, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 36, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 42, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 46, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 44, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 56, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 40, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 44, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 39, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 26, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 58, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 52, 'losses...
# 13  {'away': {'leagueRecord': {'wins': 48, 'losses...
# 14  {'away': {'leagueRecord': {'wins': 43, 'losses...
#
#                                                 venue  \
# 0   {'id': 3313, 'name': 'Yankee Stadium', 'link':...
# 1   {'id': 3312, 'name': 'Target Field', 'link': '...
# 2   {'id': 17, 'name': 'Wrigley Field', 'link': '/...
# 3   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...
# 4   {'id': 3309, 'name': 'Nationals Park', 'link':...
# 5   {'id': 5325, 'name': 'Globe Life Field', 'link...
# 6   {'id': 10, 'name': 'Oakland Coliseum', 'link':...
# 7   {'id': 2602, 'name': 'Great American Ball Park...
# 8   {'id': 5, 'name': 'Progressive Field', 'link':...
# 9   {'id': 680, 'name': 'T-Mobile Park', 'link': '...
# 10  {'id': 4169, 'name': 'loanDepot park', 'link':...
# 11  {'id': 4705, 'name': 'Truist Park', 'link': '/...
# 12  {'id': 22, 'name': 'Dodger Stadium', 'link': '...
# 13  {'id': 19, 'name': 'Coors Field', 'link': '/ap...
# 14  {'id': 2680, 'name': 'Petco Park', 'link': '/a...
#
#                                     content  isTie  gameNumber  publicFacing  \
# 0   {'link': '/api/v1/game/745724/content'}  False           1          True
# 1   {'link': '/api/v1/game/745885/content'}    NaN           1          True
# 2   {'link': '/api/v1/game/746856/content'}    NaN           1          True
# 3   {'link': '/api/v1/game/745476/content'}    NaN           1          True
# 4   {'link': '/api/v1/game/744835/content'}    NaN           1          True
# 5   {'link': '/api/v1/game/744995/content'}    NaN           1          True
# 6   {'link': '/api/v1/game/745642/content'}    NaN           1          True
# 7   {'link': '/api/v1/game/746694/content'}    NaN           1          True
# 8   {'link': '/api/v1/game/746615/content'}    NaN           1          True
# 9   {'link': '/api/v1/game/745235/content'}    NaN           1          True
# 10  {'link': '/api/v1/game/746044/content'}    NaN           1          True
# 11  {'link': '/api/v1/game/747099/content'}    NaN           1          True
# 12  {'link': '/api/v1/game/746129/content'}    NaN           1          True
# 13  {'link': '/api/v1/game/746529/content'}    NaN           1          True
# 14  {'link': '/api/v1/game/745395/content'}    NaN           1          True
#
#    doubleHeader gamedayType tiebreaker       calendarEventID seasonDisplay  \
# 0             N           P          N  14-745724-2024-07-06          2024
# 1             N           P          N  14-745885-2024-07-06          2024
# 2             N           P          N  14-746856-2024-07-06          2024
# 3             N           P          N  14-745476-2024-07-06          2024
# 4             N           P          N  14-744835-2024-07-06          2024
# 5             N           P          N  14-744995-2024-07-06          2024
# 6             N           P          N  14-745642-2024-07-06          2024
# 7             N           P          N  14-746694-2024-07-06          2024
# 8             N           P          N  14-746615-2024-07-06          2024
# 9             N           P          N  14-745235-2024-07-06          2024
# 10            N           P          N  14-746044-2024-07-06          2024
# 11            N           P          N  14-747099-2024-07-06          2024
# 12            N           P          N  14-746129-2024-07-06          2024
# 13            N           P          N  14-746529-2024-07-06          2024
# 14            N           P          N  14-745395-2024-07-06          2024
#
#    dayNight  scheduledInnings  reverseHomeAwayStatus  inningBreakLength  \
# 0       day                 9                  False                120
# 1       day                 9                  False                120
# 2       day                 9                  False                120
# 3       day                 9                  False                120
# 4       day                 9                  False                120
# 5       day                 9                  False                120
# 6       day                 9                  False                120
# 7       day                 9                  False                120
# 8       day                 9                  False                120
# 9       day                 9                  False                120
# 10      day                 9                  False                120
# 11    night                 9                  False                145
# 12      day                 9                  False                145
# 13    night                 9                  False                120
# 14    night                 9                  False                120
#
#     gamesInSeries  seriesGameNumber seriesDescription recordSource  \
# 0               3                 2    Regular Season            S
# 1               3                 2    Regular Season            S
# 2               3                 2    Regular Season            S
# 3               4                 2    Regular Season            S
# 4               4                 2    Regular Season            S
# 5               3                 2    Regular Season            S
# 6               3                 2    Regular Season            S
# 7               3                 2    Regular Season            S
# 8               3                 2    Regular Season            S
# 9               3                 2    Regular Season            S
# 10              3                 2    Regular Season            S
# 11              3                 2    Regular Season            S
# 12              3                 2    Regular Season            S
# 13              3                 2    Regular Season            S
# 14              3                 2    Regular Season            S
#
#    ifNecessary ifNecessaryDescription
# 0            N            Normal Game
# 1            N            Normal Game
# 2            N            Normal Game
# 3            N            Normal Game
# 4            N            Normal Game
# 5            N            Normal Game
# 6            N            Normal Game
# 7            N            Normal Game
# 8            N            Normal Game
# 9            N            Normal Game
# 10           N            Normal Game
# 11           N            Normal Game
# 12           N            Normal Game
# 13           N            Normal Game
# 14           N            Normal Game

# %%
df.loc[14,'teams']
# Out:
# {'away': {'leagueRecord': {'wins': 43, 'losses': 45, 'pct': '.489'},
#   'team': {'id': 109,
#    'name': 'Arizona Diamondbacks',
#    'link': '/api/v1/teams/109'},
#   'splitSquad': False,
#   'seriesNumber': 29},
#  'home': {'leagueRecord': {'wins': 49, 'losses': 43, 'pct': '.533'},
#   'team': {'id': 135, 'name': 'San Diego Padres', 'link': '/api/v1/teams/135'},
#   'splitSquad': False,
#   'seriesNumber': 30}}

# %%
# Getting the players from today's first game:
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df.T
# Out:
#               id            fullName                   link  firstName  \
# ID543859  543859      Michael Tonkin  /api/v1/people/543859    Michael
# ID641482  641482       Nestor Cortes  /api/v1/people/641482     Nestor
# ID518934  518934         DJ LeMahieu  /api/v1/people/518934      David
# ID608701  608701       Rob Refsnyder  /api/v1/people/608701     Robert
# ID657077  657077        Alex Verdugo  /api/v1/people/657077  Alexander
# ID677161  677161          Zack Kelly  /api/v1/people/677161    Zachery
# ID592155  592155          Cam Booser  /api/v1/people/592155    Cameron
# ID445276  445276       Kenley Jansen  /api/v1/people/445276     Kenley
# ID677800  677800        Wilyer Abreu  /api/v1/people/677800     Wilyer
# ID670174  670174     Josh Winckowski  /api/v1/people/670174     Joshua
# ID657514  657514  Brennan Bernardino  /api/v1/people/657514    Brennan
# ID676710  676710     Kutter Crawford  /api/v1/people/676710     Kutter
# ID669224  669224        Austin Wells  /api/v1/people/669224     Austin
# ID642086  642086       Dominic Smith  /api/v1/people/642086    Dominic
# ID700250  700250            Ben Rice  /api/v1/people/700250   Benjamin
# ID650402  650402      Gleyber Torres  /api/v1/people/650402    Gleyber
# ID624512  624512       Reese McGuire  /api/v1/people/624512      Reese
# ID686580  686580       Justin Slaten  /api/v1/people/686580     Justin
# ID666152  666152      David Hamilton  /api/v1/people/666152      David
# ID646240  646240       Rafael Devers  /api/v1/people/646240     Rafael
# ID664776  664776        Jake Cousins  /api/v1/people/664776       Jake
# ID624431  624431        Jose Trevino  /api/v1/people/624431       Jose
# ID605280  605280         Clay Holmes  /api/v1/people/605280    Clayton
# ID665742  665742           Juan Soto  /api/v1/people/665742       Juan
# ID678882  678882    Ceddanne Rafaela  /api/v1/people/678882   Ceddanne
# ID656671  656671    Josh Maciejewski  /api/v1/people/656671       Josh
# ID573186  573186      Marcus Stroman  /api/v1/people/573186     Marcus
# ID663757  663757       Trent Grisham  /api/v1/people/663757    Trenton
# ID605204  605204          J.D. Davis  /api/v1/people/605204   Jonathan
# ID543037  543037         Gerrit Cole  /api/v1/people/543037     Gerrit
# ID656557  656557        Tanner Houck  /api/v1/people/656557     Tanner
# ID663853  663853       Romy Gonzalez  /api/v1/people/663853      Roman
# ID607074  607074        Carlos Rodón  /api/v1/people/607074     Carlos
# ID663330  663330        Jahmai Jones  /api/v1/people/663330     Jahmai
# ID669711  669711       Greg Weissert  /api/v1/people/669711    Gregory
# ID657136  657136         Connor Wong  /api/v1/people/657136     Connor
# ID596133  596133         Luke Weaver  /api/v1/people/596133       Luke
# ID665828  665828     Oswaldo Cabrera  /api/v1/people/665828    Oswaldo
# ID592450  592450         Aaron Judge  /api/v1/people/592450      Aaron
# ID657571  657571      Caleb Ferguson  /api/v1/people/657571      Caleb
# ID641933  641933       Tyler O'Neill  /api/v1/people/641933      Tyler
# ID678394  678394        Brayan Bello  /api/v1/people/678394     Brayan
# ID657612  657612            Tim Hill  /api/v1/people/657612    Timothy
# ID690544  690544         Bailey Horn  /api/v1/people/690544     Bailey
# ID601713  601713        Nick Pivetta  /api/v1/people/601713   Nicholas
# ID592454  592454        Tommy Kahnle  /api/v1/people/592454     Thomas
# ID683011  683011       Anthony Volpe  /api/v1/people/683011    Anthony
# ID680776  680776        Jarren Duran  /api/v1/people/680776     Jarren
# ID661563  661563            Luis Gil  /api/v1/people/661563       Luis
# ID665839  665839     Enmanuel Valdez  /api/v1/people/665839   Enmanuel
# ID502624  502624      Chase Anderson  /api/v1/people/502624     Robert
# ID807799  807799    Masataka Yoshida  /api/v1/people/807799   Masataka
#
#              lastName primaryNumber   birthDate currentAge  \
# ID543859       Tonkin            50  1989-11-19         34
# ID641482       Cortes            65  1994-12-10         29
# ID518934     LeMahieu            26  1988-07-13         35
# ID608701    Refsnyder            30  1991-03-26         33
# ID657077      Verdugo            24  1996-05-15         28
# ID677161        Kelly            76  1995-03-03         29
# ID592155       Booser            71  1992-05-04         32
# ID445276       Jansen            74  1987-09-30         36
# ID677800        Abreu            52  1999-06-24         25
# ID670174   Winckowski            25  1998-06-28         26
# ID657514   Bernardino            83  1992-01-15         32
# ID676710     Crawford            50  1996-04-01         28
# ID669224        Wells            28  1999-07-12         24
# ID642086        Smith             2  1995-06-15         29
# ID700250         Rice            93  1999-02-22         25
# ID650402       Torres            25  1996-12-13         27
# ID624512      McGuire             3  1995-03-02         29
# ID686580       Slaten            63  1997-09-15         26
# ID666152     Hamilton            70  1997-09-29         26
# ID646240       Devers            11  1996-10-24         27
# ID664776      Cousins            61  1994-07-14         29
# ID624431      Trevino            39  1992-11-28         31
# ID605280       Holmes            35  1993-03-27         31
# ID665742         Soto            22  1998-10-25         25
# ID678882      Rafaela            43  2000-09-18         23
# ID656671  Maciejewski            63  1995-08-14         28
# ID573186      Stroman             0  1991-05-01         33
# ID663757      Grisham            12  1996-11-01         27
# ID605204        Davis            38  1993-04-27         31
# ID543037         Cole            45  1990-09-08         33
# ID656557        Houck            89  1996-06-29         28
# ID663853     Gonzalez            23  1996-09-06         27
# ID607074        Rodón            55  1992-12-10         31
# ID663330        Jones            14  1997-08-04         26
# ID669711     Weissert            57  1995-02-04         29
# ID657136         Wong            12  1996-05-19         28
# ID596133       Weaver            30  1993-08-21         30
# ID665828      Cabrera            95  1999-03-01         25
# ID592450        Judge            99  1992-04-26         32
# ID657571     Ferguson            64  1996-07-02         28
# ID641933      O'Neill            17  1995-06-22         29
# ID678394        Bello            66  1999-05-17         25
# ID657612         Hill            54  1990-02-10         34
# ID690544         Horn            78  1998-01-15         26
# ID601713      Pivetta            37  1993-02-14         31
# ID592454       Kahnle            41  1989-08-07         34
# ID683011        Volpe            11  2001-04-28         23
# ID680776        Duran            16  1996-09-05         27
# ID661563          Gil            81  1998-06-03         26
# ID665839       Valdez            47  1998-12-28         25
# ID502624     Anderson            48  1987-11-30         36
# ID807799      Yoshida             7  1993-07-15         30
#
#                        birthCity birthStateProvince        birthCountry  \
# ID543859                Glendale                 CA                 USA
# ID641482   Surgidero de Batabano                NaN                Cuba
# ID518934                 Visalia                 CA                 USA
# ID608701                   Seoul                NaN   Republic of Korea
# ID657077                  Tucson                 AZ                 USA
# ID677161                 Roanoke                 VA                 USA
# ID592155                 Seattle                 WA                 USA
# ID445276              Willemstad                NaN             Curacao
# ID677800               Maracaibo                NaN           Venezuela
# ID670174                  Toledo                 OH                 USA
# ID657514                Valencia                 CA                 USA
# ID676710              Okeechobee                 FL                 USA
# ID669224              Scottsdale                 AZ                 USA
# ID642086             Los Angeles                 CA                 USA
# ID700250                Cohasset                 MA                 USA
# ID650402                 Caracas                NaN           Venezuela
# ID624512                 Seattle                 WA                 USA
# ID686580                Longview                 TX                 USA
# ID666152              San Marcos                 TX                 USA
# ID646240                 Sanchez                NaN  Dominican Republic
# ID664776               Parkridge                 IL                 USA
# ID624431          Corpus Christi                 TX                 USA
# ID605280                  Dothan                 AL                 USA
# ID665742           Santo Domingo                NaN  Dominican Republic
# ID678882              Willemstad                NaN             Curacao
# ID656671             Morrisville                 NC                 USA
# ID573186                 Medford                 NY                 USA
# ID663757                Burleson                 TX                 USA
# ID605204               Elk Grove                 CA                 USA
# ID543037           Newport Beach                 CA                 USA
# ID656557               St. Louis                 MO                 USA
# ID663853                   Miami                 FL                 USA
# ID607074                   Miami                 FL                 USA
# ID663330                 Roswell                 GA                 USA
# ID669711               Bay Shore                 NY                 USA
# ID657136                 Houston                 TX                 USA
# ID596133                  DeLand                 FL                 USA
# ID665828                Guarenas                NaN           Venezuela
# ID592450                  Linden                 CA                 USA
# ID657571                Columbus                 OH                 USA
# ID641933                 Burnaby                 BC              Canada
# ID678394                  Samana                NaN  Dominican Republic
# ID657612           Mission Hills                 CA                 USA
# ID690544                    Waco                 TX                 USA
# ID601713                Victoria                 BC              Canada
# ID592454                  Latham                 NY                 USA
# ID683011                New York                 NY                 USA
# ID680776                  Corona                 CA                 USA
# ID661563                    Azua                NaN  Dominican Republic
# ID665839  San Juan de la Maguana                NaN  Dominican Republic
# ID502624           Wichita Falls                 TX                 USA
# ID807799                   Fukui                NaN               Japan
#
#           height weight active  \
# ID543859   6' 7"    220   True
# ID641482  5' 11"    210   True
# ID518934   6' 4"    220   True
# ID608701   6' 0"    215   True
# ID657077   6' 0"    209   True
# ID677161   6' 3"    231   True
# ID592155   6' 3"    225   True
# ID445276   6' 5"    265   True
# ID677800  5' 10"    215   True
# ID670174   6' 4"    215   True
# ID657514   6' 4"    180   True
# ID676710   6' 1"    195   True
# ID669224   6' 2"    220   True
# ID642086   6' 0"    224   True
# ID700250   6' 1"    215   True
# ID650402   6' 1"    205   True
# ID624512   6' 0"    233   True
# ID686580   6' 4"    222   True
# ID666152  5' 10"    188   True
# ID646240   6' 0"    235   True
# ID664776   6' 4"    195   True
# ID624431  5' 10"    215   True
# ID605280   6' 5"    245   True
# ID665742   6' 2"    224   True
# ID678882   5' 9"    165   True
# ID656671   6' 3"    210   True
# ID573186   5' 7"    180   True
# ID663757  5' 11"    224   True
# ID605204   6' 3"    218   True
# ID543037   6' 4"    220   True
# ID656557   6' 5"    226   True
# ID663853   6' 0"    215   True
# ID607074   6' 2"    255   True
# ID663330  5' 11"    210   True
# ID669711   6' 2"    235   True
# ID657136   6' 1"    190   True
# ID596133   6' 2"    183   True
# ID665828  5' 11"    200   True
# ID592450   6' 7"    282   True
# ID657571   6' 3"    226   True
# ID641933  5' 11"    200   True
# ID678394   6' 1"    195   True
# ID657612   6' 4"    210   True
# ID690544   6' 2"    210   True
# ID601713   6' 5"    210   True
# ID592454   6' 1"    230   True
# ID683011   5' 9"    180   True
# ID680776   6' 2"    205   True
# ID661563   6' 2"    185   True
# ID665839   5' 8"    191   True
# ID502624   6' 1"    210   True
# ID807799   5' 8"    192   True
#
#                                             primaryPosition   useName  \
# ID543859  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...   Michael
# ID641482  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Nestor
# ID518934  {'code': '5', 'name': 'Third Base', 'type': 'I...        DJ
# ID608701  {'code': '7', 'name': 'Outfielder', 'type': 'O...       Rob
# ID657077  {'code': '7', 'name': 'Outfielder', 'type': 'O...      Alex
# ID677161  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Zack
# ID592155  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...       Cam
# ID445276  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Kenley
# ID677800  {'code': '9', 'name': 'Outfielder', 'type': 'O...    Wilyer
# ID670174  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Josh
# ID657514  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...   Brennan
# ID676710  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Kutter
# ID669224  {'code': '2', 'name': 'Catcher', 'type': 'Catc...    Austin
# ID642086  {'code': '3', 'name': 'First Base', 'type': 'I...   Dominic
# ID700250  {'code': '3', 'name': 'First Base', 'type': 'I...       Ben
# ID650402  {'code': '4', 'name': 'Second Base', 'type': '...   Gleyber
# ID624512  {'code': '2', 'name': 'Catcher', 'type': 'Catc...     Reese
# ID686580  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Justin
# ID666152  {'code': '6', 'name': 'Shortstop', 'type': 'In...     David
# ID646240  {'code': '5', 'name': 'Third Base', 'type': 'I...    Rafael
# ID664776  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Jake
# ID624431  {'code': '2', 'name': 'Catcher', 'type': 'Catc...      Jose
# ID605280  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Clay
# ID665742  {'code': '9', 'name': 'Outfielder', 'type': 'O...      Juan
# ID678882  {'code': '8', 'name': 'Outfielder', 'type': 'O...  Ceddanne
# ID656671  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Josh
# ID573186  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Marcus
# ID663757  {'code': '8', 'name': 'Outfielder', 'type': 'O...     Trent
# ID605204  {'code': '3', 'name': 'First Base', 'type': 'I...      J.D.
# ID543037  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Gerrit
# ID656557  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Tanner
# ID663853  {'code': '6', 'name': 'Shortstop', 'type': 'In...      Romy
# ID607074  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Carlos
# ID663330  {'code': '9', 'name': 'Outfielder', 'type': 'O...    Jahmai
# ID669711  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Greg
# ID657136  {'code': '2', 'name': 'Catcher', 'type': 'Catc...    Connor
# ID596133  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Luke
# ID665828  {'code': '5', 'name': 'Third Base', 'type': 'I...   Oswaldo
# ID592450  {'code': '8', 'name': 'Outfielder', 'type': 'O...     Aaron
# ID657571  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...     Caleb
# ID641933  {'code': '7', 'name': 'Outfielder', 'type': 'O...     Tyler
# ID678394  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Brayan
# ID657612  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...       Tim
# ID690544  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...    Bailey
# ID601713  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Nick
# ID592454  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...     Tommy
# ID683011  {'code': '6', 'name': 'Shortstop', 'type': 'In...   Anthony
# ID680776  {'code': '7', 'name': 'Outfielder', 'type': 'O...    Jarren
# ID661563  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...      Luis
# ID665839  {'code': '4', 'name': 'Second Base', 'type': '...  Enmanuel
# ID502624  {'code': '1', 'name': 'Pitcher', 'type': 'Pitc...     Chase
# ID807799  {'code': '7', 'name': 'Outfielder', 'type': 'O...  Masataka
#
#           useLastName             middleName boxscoreName gender isPlayer  \
# ID543859       Tonkin                 Harvey       Tonkin      M     True
# ID641482       Cortes                    NaN       Cortes      M     True
# ID518934     LeMahieu                   John     LeMahieu      M     True
# ID608701    Refsnyder                 Daniel    Refsnyder      M     True
# ID657077      Verdugo                  Brady      Verdugo      M     True
# ID677161        Kelly                   Reed     Kelly, Z      M     True
# ID592155       Booser                 Joseph       Booser      M     True
# ID445276       Jansen               Geronimo       Jansen      M     True
# ID677800        Abreu                  David     Abreu, W      M     True
# ID670174   Winckowski                    NaN   Winckowski      M     True
# ID657514   Bernardino                  Allen   Bernardino      M     True
# ID676710     Crawford                 Martin  Crawford, K      M     True
# ID669224        Wells                Kenneth     Wells, A      M     True
# ID642086        Smith             David Rene    Smith, Do      M     True
# ID700250         Rice                Kimball         Rice      M     True
# ID650402       Torres                  David       Torres      M     True
# ID624512      McGuire                Jackson      McGuire      M     True
# ID686580       Slaten                Michael       Slaten      M     True
# ID666152     Hamilton                  Lewis  Hamilton, D      M     True
# ID646240       Devers                Calcano       Devers      M     True
# ID664776      Cousins                     O.      Cousins      M     True
# ID624431      Trevino                    NaN      Trevino      M     True
# ID605280       Holmes                 Walter    Holmes, C      M     True
# ID665742         Soto                   Jose      Soto, J      M     True
# ID678882      Rafaela  Chipper Nicasio Marte      Rafaela      M     True
# ID656671  Maciejewski                 Graham  Maciejewski      M     True
# ID573186      Stroman                   Earl      Stroman      M     True
# ID663757      Grisham                 Marcus      Grisham      M     True
# ID605204        Davis                Gregory     Davis, J      M     True
# ID543037         Cole                   Alan         Cole      M     True
# ID656557        Houck                    Lee        Houck      M     True
# ID663853     Gonzalez                     A.  Gonzalez, R      M     True
# ID607074        Rodón                Antonio        Rodón      M     True
# ID663330        Jones             Fitzgerald   Jones, Jah      M     True
# ID669711     Weissert                     R.     Weissert      M     True
# ID657136         Wong                Sun-Han         Wong      M     True
# ID596133       Weaver                  Allen       Weaver      M     True
# ID665828      Cabrera                Alberto   Cabrera, O      M     True
# ID592450        Judge                  James        Judge      M     True
# ID657571     Ferguson                   Paul  Ferguson, C      M     True
# ID641933      O'Neill                   Alan      O'Neill      M     True
# ID678394        Bello                    NaN        Bello      M     True
# ID657612         Hill                    NaN      Hill, T      M     True
# ID690544         Horn         Christian Tant         Horn      M     True
# ID601713      Pivetta              Johncarlo      Pivetta      M     True
# ID592454       Kahnle                 Robert       Kahnle      M     True
# ID683011        Volpe                Michael        Volpe      M     True
# ID680776        Duran                William    Duran, Ja      M     True
# ID661563          Gil                  Angel          Gil      M     True
# ID665839       Valdez                    NaN    Valdez, E      M     True
# ID502624     Anderson                  Chase     Anderson      M     True
# ID807799      Yoshida                    NaN      Yoshida      M     True
#
#          isVerified draftYear mlbDebutDate  \
# ID543859       True      2008   2013-07-11
# ID641482      False      2013   2018-03-31
# ID518934       True      2009   2011-05-30
# ID608701       True      2012   2015-07-11
# ID657077       True      2014   2017-09-01
# ID677161      False       NaN   2022-08-29
# ID592155       True       NaN   2024-04-19
# ID445276       True       NaN   2010-07-24
# ID677800       True       NaN   2023-08-22
# ID670174      False      2016   2022-05-28
# ID657514       True      2014   2022-07-31
# ID676710       True      2017   2021-09-05
# ID669224       True      2020   2023-09-01
# ID642086       True      2013   2017-08-11
# ID700250       True      2021   2024-06-18
# ID650402       True       NaN   2018-04-22
# ID624512       True      2013   2018-09-06
# ID686580       True      2019   2024-03-30
# ID666152       True      2019   2023-06-21
# ID646240       True       NaN   2017-07-25
# ID664776       True      2017   2021-06-21
# ID624431      False      2014   2018-06-15
# ID605280       True      2011   2018-04-06
# ID665742       True       NaN   2018-05-15
# ID678882       True       NaN   2023-08-28
# ID656671       True      2018   2024-04-08
# ID573186       True      2012   2014-05-04
# ID663757       True      2015   2019-08-01
# ID605204       True      2014   2017-08-05
# ID543037       True      2011   2013-06-11
# ID656557       True      2017   2020-09-15
# ID663853       True      2018   2021-09-03
# ID607074       True      2014   2015-04-21
# ID663330       True      2015   2020-08-31
# ID669711      False      2016   2022-08-25
# ID657136       True      2017   2021-06-22
# ID596133      False      2014   2016-08-13
# ID665828       True       NaN   2022-08-17
# ID592450       True      2013   2016-08-13
# ID657571       True      2014   2018-06-06
# ID641933       True      2013   2018-04-19
# ID678394       True       NaN   2022-07-06
# ID657612       True      2014   2018-03-29
# ID690544       True      2020   2024-06-29
# ID601713       True      2013   2017-04-30
# ID592454       True      2010   2014-04-03
# ID683011       True      2019   2023-03-30
# ID680776      False      2018   2021-07-17
# ID661563       True       NaN   2021-08-03
# ID665839      False       NaN   2023-04-19
# ID502624       True      2009   2014-05-11
# ID807799       True       NaN   2023-03-30
#
#                                          batSide  \
# ID543859   {'code': 'R', 'description': 'Right'}
# ID641482   {'code': 'R', 'description': 'Right'}
# ID518934   {'code': 'R', 'description': 'Right'}
# ID608701   {'code': 'R', 'description': 'Right'}
# ID657077    {'code': 'L', 'description': 'Left'}
# ID677161   {'code': 'R', 'description': 'Right'}
# ID592155    {'code': 'L', 'description': 'Left'}
# ID445276  {'code': 'S', 'description': 'Switch'}
# ID677800    {'code': 'L', 'description': 'Left'}
# ID670174   {'code': 'R', 'description': 'Right'}
# ID657514    {'code': 'L', 'description': 'Left'}
# ID676710   {'code': 'R', 'description': 'Right'}
# ID669224    {'code': 'L', 'description': 'Left'}
# ID642086    {'code': 'L', 'description': 'Left'}
# ID700250    {'code': 'L', 'description': 'Left'}
# ID650402   {'code': 'R', 'description': 'Right'}
# ID624512    {'code': 'L', 'description': 'Left'}
# ID686580   {'code': 'R', 'description': 'Right'}
# ID666152    {'code': 'L', 'description': 'Left'}
# ID646240    {'code': 'L', 'description': 'Left'}
# ID664776   {'code': 'R', 'description': 'Right'}
# ID624431   {'code': 'R', 'description': 'Right'}
# ID605280   {'code': 'R', 'description': 'Right'}
# ID665742    {'code': 'L', 'description': 'Left'}
# ID678882   {'code': 'R', 'description': 'Right'}
# ID656671   {'code': 'R', 'description': 'Right'}
# ID573186   {'code': 'R', 'description': 'Right'}
# ID663757    {'code': 'L', 'description': 'Left'}
# ID605204   {'code': 'R', 'description': 'Right'}
# ID543037   {'code': 'R', 'description': 'Right'}
# ID656557   {'code': 'R', 'description': 'Right'}
# ID663853   {'code': 'R', 'description': 'Right'}
# ID607074    {'code': 'L', 'description': 'Left'}
# ID663330   {'code': 'R', 'description': 'Right'}
# ID669711   {'code': 'R', 'description': 'Right'}
# ID657136   {'code': 'R', 'description': 'Right'}
# ID596133   {'code': 'R', 'description': 'Right'}
# ID665828  {'code': 'S', 'description': 'Switch'}
# ID592450   {'code': 'R', 'description': 'Right'}
# ID657571   {'code': 'R', 'description': 'Right'}
# ID641933   {'code': 'R', 'description': 'Right'}
# ID678394   {'code': 'R', 'description': 'Right'}
# ID657612   {'code': 'R', 'description': 'Right'}
# ID690544    {'code': 'L', 'description': 'Left'}
# ID601713   {'code': 'R', 'description': 'Right'}
# ID592454   {'code': 'R', 'description': 'Right'}
# ID683011   {'code': 'R', 'description': 'Right'}
# ID680776    {'code': 'L', 'description': 'Left'}
# ID661563   {'code': 'R', 'description': 'Right'}
# ID665839    {'code': 'L', 'description': 'Left'}
# ID502624   {'code': 'R', 'description': 'Right'}
# ID807799    {'code': 'L', 'description': 'Left'}
#
#                                       pitchHand       nameFirstLast  \
# ID543859  {'code': 'R', 'description': 'Right'}      Michael Tonkin
# ID641482   {'code': 'L', 'description': 'Left'}       Nestor Cortes
# ID518934  {'code': 'R', 'description': 'Right'}         DJ LeMahieu
# ID608701  {'code': 'R', 'description': 'Right'}       Rob Refsnyder
# ID657077   {'code': 'L', 'description': 'Left'}        Alex Verdugo
# ID677161  {'code': 'R', 'description': 'Right'}          Zack Kelly
# ID592155   {'code': 'L', 'description': 'Left'}          Cam Booser
# ID445276  {'code': 'R', 'description': 'Right'}       Kenley Jansen
# ID677800   {'code': 'L', 'description': 'Left'}        Wilyer Abreu
# ID670174  {'code': 'R', 'description': 'Right'}     Josh Winckowski
# ID657514   {'code': 'L', 'description': 'Left'}  Brennan Bernardino
# ID676710  {'code': 'R', 'description': 'Right'}     Kutter Crawford
# ID669224  {'code': 'R', 'description': 'Right'}        Austin Wells
# ID642086   {'code': 'L', 'description': 'Left'}       Dominic Smith
# ID700250  {'code': 'R', 'description': 'Right'}            Ben Rice
# ID650402  {'code': 'R', 'description': 'Right'}      Gleyber Torres
# ID624512  {'code': 'R', 'description': 'Right'}       Reese McGuire
# ID686580  {'code': 'R', 'description': 'Right'}       Justin Slaten
# ID666152  {'code': 'R', 'description': 'Right'}      David Hamilton
# ID646240  {'code': 'R', 'description': 'Right'}       Rafael Devers
# ID664776  {'code': 'R', 'description': 'Right'}        Jake Cousins
# ID624431  {'code': 'R', 'description': 'Right'}        Jose Trevino
# ID605280  {'code': 'R', 'description': 'Right'}         Clay Holmes
# ID665742   {'code': 'L', 'description': 'Left'}           Juan Soto
# ID678882  {'code': 'R', 'description': 'Right'}    Ceddanne Rafaela
# ID656671   {'code': 'L', 'description': 'Left'}    Josh Maciejewski
# ID573186  {'code': 'R', 'description': 'Right'}      Marcus Stroman
# ID663757   {'code': 'L', 'description': 'Left'}       Trent Grisham
# ID605204  {'code': 'R', 'description': 'Right'}          J.D. Davis
# ID543037  {'code': 'R', 'description': 'Right'}         Gerrit Cole
# ID656557  {'code': 'R', 'description': 'Right'}        Tanner Houck
# ID663853  {'code': 'R', 'description': 'Right'}       Romy Gonzalez
# ID607074   {'code': 'L', 'description': 'Left'}        Carlos Rodón
# ID663330  {'code': 'R', 'description': 'Right'}        Jahmai Jones
# ID669711  {'code': 'R', 'description': 'Right'}       Greg Weissert
# ID657136  {'code': 'R', 'description': 'Right'}         Connor Wong
# ID596133  {'code': 'R', 'description': 'Right'}         Luke Weaver
# ID665828  {'code': 'R', 'description': 'Right'}     Oswaldo Cabrera
# ID592450  {'code': 'R', 'description': 'Right'}         Aaron Judge
# ID657571   {'code': 'L', 'description': 'Left'}      Caleb Ferguson
# ID641933  {'code': 'R', 'description': 'Right'}       Tyler O'Neill
# ID678394  {'code': 'R', 'description': 'Right'}        Brayan Bello
# ID657612   {'code': 'L', 'description': 'Left'}            Tim Hill
# ID690544   {'code': 'L', 'description': 'Left'}         Bailey Horn
# ID601713  {'code': 'R', 'description': 'Right'}        Nick Pivetta
# ID592454  {'code': 'R', 'description': 'Right'}        Tommy Kahnle
# ID683011  {'code': 'R', 'description': 'Right'}       Anthony Volpe
# ID680776  {'code': 'R', 'description': 'Right'}        Jarren Duran
# ID661563  {'code': 'R', 'description': 'Right'}            Luis Gil
# ID665839  {'code': 'R', 'description': 'Right'}     Enmanuel Valdez
# ID502624  {'code': 'R', 'description': 'Right'}      Chase Anderson
# ID807799  {'code': 'R', 'description': 'Right'}    Masataka Yoshida
#
#                            nameSlug       firstLastName        lastFirstName  \
# ID543859      michael-tonkin-543859      Michael Tonkin      Tonkin, Michael
# ID641482       nestor-cortes-641482       Nestor Cortes       Cortes, Nestor
# ID518934         dj-lemahieu-518934         DJ LeMahieu         LeMahieu, DJ
# ID608701       rob-refsnyder-608701       Rob Refsnyder       Refsnyder, Rob
# ID657077        alex-verdugo-657077        Alex Verdugo        Verdugo, Alex
# ID677161          zack-kelly-677161          Zack Kelly          Kelly, Zack
# ID592155          cam-booser-592155          Cam Booser          Booser, Cam
# ID445276       kenley-jansen-445276       Kenley Jansen       Jansen, Kenley
# ID677800        wilyer-abreu-677800        Wilyer Abreu        Abreu, Wilyer
# ID670174     josh-winckowski-670174     Josh Winckowski     Winckowski, Josh
# ID657514  brennan-bernardino-657514  Brennan Bernardino  Bernardino, Brennan
# ID676710     kutter-crawford-676710     Kutter Crawford     Crawford, Kutter
# ID669224        austin-wells-669224        Austin Wells        Wells, Austin
# ID642086       dominic-smith-642086       Dominic Smith       Smith, Dominic
# ID700250            ben-rice-700250            Ben Rice            Rice, Ben
# ID650402      gleyber-torres-650402      Gleyber Torres      Torres, Gleyber
# ID624512       reese-mcguire-624512       Reese McGuire       McGuire, Reese
# ID686580       justin-slaten-686580       Justin Slaten       Slaten, Justin
# ID666152      david-hamilton-666152      David Hamilton      Hamilton, David
# ID646240       rafael-devers-646240       Rafael Devers       Devers, Rafael
# ID664776        jake-cousins-664776        Jake Cousins        Cousins, Jake
# ID624431        jose-trevino-624431        Jose Trevino        Trevino, Jose
# ID605280         clay-holmes-605280         Clay Holmes         Holmes, Clay
# ID665742           juan-soto-665742           Juan Soto           Soto, Juan
# ID678882    ceddanne-rafaela-678882    Ceddanne Rafaela    Rafaela, Ceddanne
# ID656671    josh-maciejewski-656671    Josh Maciejewski    Maciejewski, Josh
# ID573186      marcus-stroman-573186      Marcus Stroman      Stroman, Marcus
# ID663757       trent-grisham-663757       Trent Grisham       Grisham, Trent
# ID605204           j-d-davis-605204          J.D. Davis          Davis, J.D.
# ID543037         gerrit-cole-543037         Gerrit Cole         Cole, Gerrit
# ID656557        tanner-houck-656557        Tanner Houck        Houck, Tanner
# ID663853       romy-gonzalez-663853       Romy Gonzalez       Gonzalez, Romy
# ID607074        carlos-rodon-607074        Carlos Rodón        Rodón, Carlos
# ID663330        jahmai-jones-663330        Jahmai Jones        Jones, Jahmai
# ID669711       greg-weissert-669711       Greg Weissert       Weissert, Greg
# ID657136         connor-wong-657136         Connor Wong         Wong, Connor
# ID596133         luke-weaver-596133         Luke Weaver         Weaver, Luke
# ID665828     oswaldo-cabrera-665828     Oswaldo Cabrera     Cabrera, Oswaldo
# ID592450         aaron-judge-592450         Aaron Judge         Judge, Aaron
# ID657571      caleb-ferguson-657571      Caleb Ferguson      Ferguson, Caleb
# ID641933       tyler-o-neill-641933       Tyler O'Neill       O'Neill, Tyler
# ID678394        brayan-bello-678394        Brayan Bello        Bello, Brayan
# ID657612            tim-hill-657612            Tim Hill            Hill, Tim
# ID690544         bailey-horn-690544         Bailey Horn         Horn, Bailey
# ID601713        nick-pivetta-601713        Nick Pivetta        Pivetta, Nick
# ID592454        tommy-kahnle-592454        Tommy Kahnle        Kahnle, Tommy
# ID683011       anthony-volpe-683011       Anthony Volpe       Volpe, Anthony
# ID680776        jarren-duran-680776        Jarren Duran        Duran, Jarren
# ID661563            luis-gil-661563            Luis Gil            Gil, Luis
# ID665839     enmanuel-valdez-665839     Enmanuel Valdez     Valdez, Enmanuel
# ID502624      chase-anderson-502624      Chase Anderson      Anderson, Chase
# ID807799    masataka-yoshida-807799    Masataka Yoshida    Yoshida, Masataka
#
#             lastInitName   initLastName  \
# ID543859       Tonkin, M       M Tonkin
# ID641482       Cortes, N       N Cortes
# ID518934     LeMahieu, D     D LeMahieu
# ID608701    Refsnyder, R    R Refsnyder
# ID657077      Verdugo, A      A Verdugo
# ID677161        Kelly, Z        Z Kelly
# ID592155       Booser, C       C Booser
# ID445276       Jansen, K       K Jansen
# ID677800        Abreu, W        W Abreu
# ID670174   Winckowski, J   J Winckowski
# ID657514   Bernardino, B   B Bernardino
# ID676710     Crawford, K     K Crawford
# ID669224        Wells, A        A Wells
# ID642086       Smith, Do       Do Smith
# ID700250         Rice, B         B Rice
# ID650402       Torres, G       G Torres
# ID624512      McGuire, R      R McGuire
# ID686580       Slaten, J       J Slaten
# ID666152     Hamilton, D     D Hamilton
# ID646240       Devers, R       R Devers
# ID664776      Cousins, J      J Cousins
# ID624431      Trevino, J      J Trevino
# ID605280       Holmes, C       C Holmes
# ID665742         Soto, J         J Soto
# ID678882      Rafaela, C      C Rafaela
# ID656671  Maciejewski, J  J Maciejewski
# ID573186      Stroman, M      M Stroman
# ID663757      Grisham, T      T Grisham
# ID605204        Davis, J        J Davis
# ID543037         Cole, G         G Cole
# ID656557        Houck, T        T Houck
# ID663853     Gonzalez, R     R Gonzalez
# ID607074        Rodón, C        C Rodón
# ID663330        Jones, J        J Jones
# ID669711     Weissert, G     G Weissert
# ID657136         Wong, C         C Wong
# ID596133       Weaver, L       L Weaver
# ID665828      Cabrera, O      O Cabrera
# ID592450        Judge, A        A Judge
# ID657571     Ferguson, C     C Ferguson
# ID641933      O'Neill, T      T O'Neill
# ID678394        Bello, B        B Bello
# ID657612         Hill, T         T Hill
# ID690544         Horn, B         B Horn
# ID601713      Pivetta, N      N Pivetta
# ID592454       Kahnle, T       T Kahnle
# ID683011        Volpe, A        A Volpe
# ID680776        Duran, J        J Duran
# ID661563          Gil, L          L Gil
# ID665839       Valdez, E       E Valdez
# ID502624     Anderson, C     C Anderson
# ID807799      Yoshida, M      M Yoshida
#
#                                      fullFMLName  \
# ID543859                   Michael Harvey Tonkin
# ID641482                          Nestor  Cortes
# ID518934                     David John LeMahieu
# ID608701                 Robert Daniel Refsnyder
# ID657077                 Alexander Brady Verdugo
# ID677161                      Zachery Reed Kelly
# ID592155                   Cameron Joseph Booser
# ID445276                  Kenley Geronimo Jansen
# ID677800                      Wilyer David Abreu
# ID670174                       Joshua Winckowski
# ID657514                Brennan Allen Bernardino
# ID676710                  Kutter Martin Crawford
# ID669224                    Austin Kenneth Wells
# ID642086                Dominic David Rene Smith
# ID700250                   Benjamin Kimball Rice
# ID650402                    Gleyber David Torres
# ID624512                   Reese Jackson McGuire
# ID686580                   Justin Michael Slaten
# ID666152                    David Lewis Hamilton
# ID646240                   Rafael Calcano Devers
# ID664776                         Jake O. Cousins
# ID624431                            Jose Trevino
# ID605280                   Clayton Walter Holmes
# ID665742                          Juan Jose Soto
# ID678882  Ceddanne Chipper Nicasio Marte Rafaela
# ID656671                 Josh Graham Maciejewski
# ID573186                     Marcus Earl Stroman
# ID663757                  Trenton Marcus Grisham
# ID605204                  Jonathan Gregory Davis
# ID543037                        Gerrit Alan Cole
# ID656557                        Tanner Lee Houck
# ID663853                       Roman A. Gonzalez
# ID607074                    Carlos Antonio Rodón
# ID663330                 Jahmai Fitzgerald Jones
# ID669711                     Gregory R. Weissert
# ID657136                     Connor Sun-Han Wong
# ID596133                       Luke Allen Weaver
# ID665828                 Oswaldo Alberto Cabrera
# ID592450                       Aaron James Judge
# ID657571                     Caleb Paul Ferguson
# ID641933                      Tyler Alan O'Neill
# ID678394                           Brayan  Bello
# ID657612                            Timothy Hill
# ID690544              Bailey Christian Tant Horn
# ID601713              Nicholas Johncarlo Pivetta
# ID592454                    Thomas Robert Kahnle
# ID683011                   Anthony Michael Volpe
# ID680776                    Jarren William Duran
# ID661563                          Luis Angel Gil
# ID665839                         Enmanuel Valdez
# ID502624                   Robert Chase Anderson
# ID807799                        Masataka Yoshida
#
#                                       fullLFMName strikeZoneTop  \
# ID543859                   Tonkin, Michael Harvey         3.756
# ID641482                           Cortes, Nestor         3.319
# ID518934                     LeMahieu, David John          3.31
# ID608701                 Refsnyder, Robert Daniel          3.53
# ID657077                 Verdugo, Alexander Brady          3.52
# ID677161                      Kelly, Zachery Reed          3.49
# ID592155                   Booser, Cameron Joseph          3.49
# ID445276                  Jansen, Kenley Geronimo         3.575
# ID677800                      Abreu, Wilyer David          3.39
# ID670174                       Winckowski, Joshua         3.549
# ID657514                Bernardino, Brennan Allen         3.549
# ID676710                  Crawford, Kutter Martin         3.411
# ID669224                    Wells, Austin Kenneth          3.42
# ID642086                Smith, Dominic David Rene          3.24
# ID700250                   Rice, Benjamin Kimball          3.75
# ID650402                    Torres, Gleyber David          3.23
# ID624512                   McGuire, Reese Jackson          3.41
# ID686580                   Slaten, Justin Michael         3.549
# ID666152                    Hamilton, David Lewis           3.3
# ID646240                   Devers, Rafael Calcano          3.43
# ID664776                         Cousins, Jake O.         3.549
# ID624431                            Trevino, Jose          3.14
# ID605280                   Holmes, Clayton Walter         3.575
# ID665742                          Soto, Juan Jose          3.08
# ID678882  Rafaela, Ceddanne Chipper Nicasio Marte          3.27
# ID656671                 Maciejewski, Josh Graham          3.49
# ID573186                     Stroman, Marcus Earl          3.38
# ID663757                  Grisham, Trenton Marcus          3.69
# ID605204                  Davis, Jonathan Gregory           3.5
# ID543037                        Cole, Gerrit Alan         3.549
# ID656557                        Houck, Tanner Lee         3.575
# ID663853                       Gonzalez, Roman A.          3.52
# ID607074                    Rodón, Carlos Antonio         3.467
# ID663330                 Jones, Jahmai Fitzgerald          3.49
# ID669711                     Weissert, Gregory R.         3.467
# ID657136                     Wong, Connor Sun-Han          3.25
# ID596133                       Weaver, Luke Allen         3.467
# ID665828                 Cabrera, Oswaldo Alberto          3.16
# ID592450                       Judge, Aaron James          4.04
# ID657571                     Ferguson, Caleb Paul          3.49
# ID641933                      O'Neill, Tyler Alan          3.24
# ID678394                            Bello, Brayan         3.411
# ID657612                            Hill, Timothy         3.549
# ID690544              Horn, Bailey Christian Tant         3.467
# ID601713              Pivetta, Nicholas Johncarlo         3.575
# ID592454                    Kahnle, Thomas Robert         3.411
# ID683011                   Volpe, Anthony Michael          3.38
# ID680776                    Duran, Jarren William          3.59
# ID661563                          Gil, Luis Angel         3.467
# ID665839                         Valdez, Enmanuel          3.21
# ID502624                   Anderson, Robert Chase         3.411
# ID807799                       Yoshida, Masataka           3.22
#
#          strikeZoneBottom      nickName nameTitle nameSuffix  \
# ID543859            1.746           NaN       NaN        NaN
# ID641482            1.513   Hialeah Kid       Jr.        Jr.
# ID518934             1.54     Big Fundy       NaN        NaN
# ID608701             1.61           Ref       NaN        NaN
# ID657077             1.56         Dugie       NaN        NaN
# ID677161            1.601           NaN       NaN        NaN
# ID592155            1.601           NaN       NaN        NaN
# ID445276            1.681  Kenleyfornia       NaN        NaN
# ID677800             1.62           NaN       NaN        NaN
# ID670174            1.627           NaN       NaN        NaN
# ID657514            1.627           NaN       NaN        NaN
# ID676710            1.565           NaN       NaN        NaN
# ID669224             1.59           NaN       NaN        NaN
# ID642086             1.56           Sug       NaN        NaN
# ID700250             1.79           NaN       NaN        NaN
# ID650402             1.49    De Caracas       NaN        NaN
# ID624512              1.7        Pieces       NaN        NaN
# ID686580            1.627           NaN       NaN        NaN
# ID666152             1.56           NaN       NaN        NaN
# ID646240              1.6        Carita       NaN        NaN
# ID664776            1.627           NaN       NaN        NaN
# ID624431             1.47         Trevi       NaN        NaN
# ID605280            1.681           NaN       NaN        NaN
# ID665742             1.49  Soto Pacheco       NaN        NaN
# ID678882             1.54           NaN       NaN        NaN
# ID656671            1.601           NaN       NaN        NaN
# ID573186             1.56          HDMH       NaN        NaN
# ID663757             1.76         Grish       NaN        NaN
# ID605204              1.6        Dizzle       NaN        NaN
# ID543037            1.627        Chef G       NaN        NaN
# ID656557            1.681           NaN       NaN        NaN
# ID663853             1.73           NaN       NaN        NaN
# ID607074            1.589           Los       NaN        NaN
# ID663330             1.66           NaN       NaN        NaN
# ID669711            1.589           NaN       NaN        NaN
# ID657136             1.38           NaN       NaN        NaN
# ID596133            1.589         Dream       NaN        NaN
# ID665828             1.46           NaN       NaN        NaN
# ID592450             1.86           Baj       NaN        NaN
# ID657571            1.601           NaN       NaN        NaN
# ID641933             1.52           NaN       NaN        NaN
# ID678394            1.565           NaN       NaN        NaN
# ID657612            1.627       Tim Jim       NaN        NaN
# ID690544            1.589           NaN       NaN        NaN
# ID601713            1.681           Piv       NaN        NaN
# ID592454            1.565     King Kahn       NaN        NaN
# ID683011             1.59           NaN       NaN        NaN
# ID680776             1.73           NaN       NaN        NaN
# ID661563            1.589           NaN       NaN        NaN
# ID665839             1.59           NaN       NaN        NaN
# ID502624            1.565        Chaser       NaN        NaN
# ID807799             1.42           NaN       NaN        NaN
#
#              pronunciation nameMatrilineal
# ID543859               NaN             NaN
# ID641482               NaN             NaN
# ID518934      luh-MAY-hyoo             NaN
# ID608701               NaN             NaN
# ID657077       vehr-DOO-go             NaN
# ID677161               NaN             NaN
# ID592155               NaN             NaN
# ID445276  KEHN-lee JAN-sin             NaN
# ID677800               NaN      Villalobos
# ID670174      win-COW-skee             NaN
# ID657514               NaN             NaN
# ID676710               NaN             NaN
# ID669224               NaN             NaN
# ID642086               NaN             NaN
# ID700250               NaN             NaN
# ID650402         GLAY-burr          Castro
# ID624512               NaN             NaN
# ID686580               NaN             NaN
# ID666152               NaN             NaN
# ID646240          DEHV-ers             NaN
# ID664776               NaN             NaN
# ID624431      treh-VEEN-yo             NaN
# ID605280               NaN             NaN
# ID665742               NaN         Pacheco
# ID678882               NaN             NaN
# ID656671               NaN             NaN
# ID573186               NaN             NaN
# ID663757          GRISH-um             NaN
# ID605204               NaN             NaN
# ID543037               NaN             NaN
# ID656557              HOWk             NaN
# ID663853               NaN             NaN
# ID607074           row-DON             NaN
# ID663330            juh-MY             NaN
# ID669711               NaN             NaN
# ID657136               NaN             NaN
# ID596133               NaN             NaN
# ID665828               NaN      Mabaricuna
# ID592450               NaN             NaN
# ID657571               NaN             NaN
# ID641933               NaN             NaN
# ID678394               NaN         Jimenez
# ID657612               NaN             NaN
# ID690544               NaN             NaN
# ID601713               NaN             NaN
# ID592454          cain-lee             NaN
# ID683011               NaN             NaN
# ID680776           duh-ran             NaN
# ID661563              Heel           Brito
# ID665839               NaN            Bido
# ID502624       AN-durr-sun             NaN
# ID807799               NaN             NaN

# %% [markdown]
# Trying out the python MLB_Stats_API library:

# %%
import statsapi

# %%
print('The A\'s won %s games in 2018.' % sum(1 for x in statsapi.schedule(team=133,start_date='03/29/2018',end_date='12/31/2018') if x.get('winning_team','')=='Oakland Athletics'))
# Out:
# The A's won 97 games in 2018.

# %%
most_recent_game_id = statsapi.last_game(133)
a = statsapi.boxscore(most_recent_game_id)
b = statsapi.linescore(most_recent_game_id)
# print(a)
# print(b)

# %%
# Get standings as a string to be printed
standings = statsapi.standings(leagueId="103,104", division="all", include_wildcard=True, season=None, standingsTypes=None, date=None)
print(standings)
# Out:
# American League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Baltimore Orioles     56  32   -    -      -      -    -
#  2   New York Yankees      55  36  2.5   71     1    +5.5   -
#  3   Boston Red Sox        48  40  8.0   67     3      -    -
#  4   Tampa Bay Rays        44  44  12.0  63     6     4.0   71
#  5   Toronto Blue Jays     39  49  17.0  58     9     9.0   66
#
# American League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Cleveland Guardians   54  32   -    -      -      -    -
#  2   Minnesota Twins       49  39  6.0   70     2    +1.0   -
#  3   Kansas City Royals    48  42  8.0   67     4     1.0   73
#  4   Detroit Tigers        40  48  15.0  61     7     8.0   67
#  5   Chicago White Sox     26  64  30.0  45    12    23.0   51
#
# American League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Seattle Mariners      49  41   -    -      -      -    -
#  2   Houston Astros        46  42  2.0   72     5     2.0   73
#  3   Texas Rangers         40  48  8.0   66     8     8.0   67
#  4   Los Angeles Angels    36  51  11.5  63    10    11.5   64
#  5   Oakland Athletics     33  57  16.0  57    11    16.0   58
#
# National League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Philadelphia Phillies 58  30   -    -      -      -    -
#  2   Atlanta Braves        47  39  10.0  66     1    +1.5   -
#  3   New York Mets         42  44  15.0  61     6     3.5   73
#  4   Washington Nationals  41  47  17.0  58     9     5.5   70
#  5   Miami Marlins         30  58  28.0  47    12    16.5   59
#
# National League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Milwaukee Brewers     52  37   -    -      -      -    -
#  2   St. Louis Cardinals   46  41  5.0   70     3      -    -
#  3   Pittsburgh Pirates    42  45  9.0   66     7     4.0   72
#  4   Cincinnati Reds       42  46  9.5   65     8     4.5   71
#  5   Chicago Cubs          41  48  11.0  63    10     6.0   69
#
# National League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Los Angeles Dodgers   54  35   -    -      -      -    -
#  2   San Diego Padres      49  43  6.5   66     2    +0.5   -
#  3   San Francisco Giants  44  45  10.0  64     4     3.0   72
#  4   Arizona Diamondbacks  43  45  10.5  64     5     3.5   72
#  5   Colorado Rockies      31  57  22.5  52    11    15.5   60

# %%
# Get standings as a dictionary:
standings_data = statsapi.standings_data(leagueId="103,104", division="all", include_wildcard=True, season=None, standingsTypes=None, date=None)

# %%
# Get team info:
teams = statsapi.lookup_team("", activeStatus="Y")
teams = pd.DataFrame(teams)
teams.sort_values(by=['id'])
# Out:
#      id                   name teamCode fileCode   teamName    locationName  \
# 16  108     Los Angeles Angels      ana      ana     Angels         Anaheim
# 17  109   Arizona Diamondbacks      ari      ari    D-backs         Phoenix
# 18  110      Baltimore Orioles      bal      bal    Orioles       Baltimore
# 19  111         Boston Red Sox      bos      bos    Red Sox          Boston
# 20  112           Chicago Cubs      chn      chc       Cubs         Chicago
# 21  113        Cincinnati Reds      cin      cin       Reds      Cincinnati
# 22  114    Cleveland Guardians      cle      cle  Guardians       Cleveland
# 23  115       Colorado Rockies      col      col    Rockies          Denver
# 24  116         Detroit Tigers      det      det     Tigers         Detroit
# 25  117         Houston Astros      hou      hou     Astros         Houston
# 26  118     Kansas City Royals      kca       kc     Royals     Kansas City
# 27  119    Los Angeles Dodgers      lan       la    Dodgers     Los Angeles
# 28  120   Washington Nationals      was      was  Nationals      Washington
# 29  121          New York Mets      nyn      nym       Mets        Flushing
# 0   133      Oakland Athletics      oak      oak  Athletics         Oakland
# 1   134     Pittsburgh Pirates      pit      pit    Pirates      Pittsburgh
# 2   135       San Diego Padres      sdn       sd     Padres       San Diego
# 3   136       Seattle Mariners      sea      sea   Mariners         Seattle
# 4   137   San Francisco Giants      sfn       sf     Giants   San Francisco
# 5   138    St. Louis Cardinals      sln      stl  Cardinals       St. Louis
# 6   139         Tampa Bay Rays      tba       tb       Rays  St. Petersburg
# 7   140          Texas Rangers      tex      tex    Rangers       Arlington
# 8   141      Toronto Blue Jays      tor      tor  Blue Jays         Toronto
# 9   142        Minnesota Twins      min      min      Twins     Minneapolis
# 10  143  Philadelphia Phillies      phi      phi   Phillies    Philadelphia
# 11  144         Atlanta Braves      atl      atl     Braves         Atlanta
# 12  145      Chicago White Sox      cha      cws  White Sox         Chicago
# 13  146          Miami Marlins      mia      mia    Marlins           Miami
# 14  147       New York Yankees      nya      nyy    Yankees           Bronx
# 15  158      Milwaukee Brewers      mil      mil    Brewers       Milwaukee
#
#         shortName
# 16      LA Angels
# 17        Arizona
# 18      Baltimore
# 19         Boston
# 20       Chi Cubs
# 21     Cincinnati
# 22      Cleveland
# 23       Colorado
# 24        Detroit
# 25        Houston
# 26    Kansas City
# 27     LA Dodgers
# 28     Washington
# 29        NY Mets
# 0         Oakland
# 1      Pittsburgh
# 2       San Diego
# 3         Seattle
# 4   San Francisco
# 5       St. Louis
# 6       Tampa Bay
# 7           Texas
# 8         Toronto
# 9       Minnesota
# 10   Philadelphia
# 11        Atlanta
# 12  Chi White Sox
# 13          Miami
# 14     NY Yankees
# 15      Milwaukee

# %%
# Write out the teams data to a csv file
teams.to_csv(path_or_buf="baseball-data/team_data.csv", index=False)
