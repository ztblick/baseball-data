# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745720  26c39ab7-ba4b-4a03-a661-034f3148daec
# 1   747093  e0f09639-1ccb-4fd7-97f2-c042e21eb293
# 2   747096  544bcd7b-3766-4e09-9fb4-36207b8b09d7
# 3   744910  de72f558-409a-4a64-820e-0c68716ecba5
# 4   745638  9a64e28b-4001-4713-91e5-90c8a5b90a04
# 5   746041  1586aedb-4155-43a9-9d55-3961aa837cc2
# 6   745478  e09da135-b3b1-43cc-ba18-bedfff76f37c
# 7   744830  477d0d42-5345-4c40-8d84-5b5b8b84d98c
# 8   744994  2d50a694-005f-40ea-8547-3e67e31e8834
# 9   746613  fc1692ad-47ec-4c26-8882-3510e211abf4
# 10  746286  1c890c97-daf4-42c5-a57f-088a9bcc6cca
# 11  745880  39cba7e9-604e-4268-94bf-3e4eed895826
# 12  746852  7b583a6b-e62f-4a5d-93c9-f2bc5d8e6a19
# 13  746121  93a506bd-8de9-40ad-a5a9-fc0eca35fa05
# 14  746527  9acc484b-3c0b-4580-b240-61c344733f38
# 15  745229  9ea44381-b586-4141-a4cc-5bbc0bf42e4c
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745720/feed/live        R   2024  2024-07-20T17:05:00Z
# 1   /api/v1.1/game/747093/feed/live        R   2024  2024-07-20T17:07:00Z
# 2   /api/v1.1/game/747096/feed/live        R   2024  2024-07-20T23:20:00Z
# 3   /api/v1.1/game/744910/feed/live        R   2024  2024-07-20T19:07:00Z
# 4   /api/v1.1/game/745638/feed/live        R   2024  2024-07-20T20:07:00Z
# 5   /api/v1.1/game/746041/feed/live        R   2024  2024-07-20T20:10:00Z
# 6   /api/v1.1/game/745478/feed/live        R   2024  2024-07-20T22:40:00Z
# 7   /api/v1.1/game/744830/feed/live        R   2024  2024-07-20T22:45:00Z
# 8   /api/v1.1/game/744994/feed/live        R   2024  2024-07-20T23:05:00Z
# 9   /api/v1.1/game/746613/feed/live        R   2024  2024-07-20T23:10:00Z
# 10  /api/v1.1/game/746286/feed/live        R   2024  2024-07-20T23:10:00Z
# 11  /api/v1.1/game/745880/feed/live        R   2024  2024-07-20T23:10:00Z
# 12  /api/v1.1/game/746852/feed/live        R   2024  2024-07-20T23:15:00Z
# 13  /api/v1.1/game/746121/feed/live        R   2024  2024-07-20T23:15:00Z
# 14  /api/v1.1/game/746527/feed/live        R   2024  2024-07-21T00:10:00Z
# 15  /api/v1.1/game/745229/feed/live        R   2024  2024-07-21T01:40:00Z
#
#    officialDate                                             status  \
# 0    2024-07-20  {'abstractGameState': 'Live', 'codedGameState'...
# 1    2024-07-20  {'abstractGameState': 'Live', 'codedGameState'...
# 2    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 3    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 4    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 5    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 6    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 7    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 8    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 9    2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 10   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 11   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 12   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 13   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 14   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
# 15   2024-07-20  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 48, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 48, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 41, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 62, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 47, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 59, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 27, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 55, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 50, 'losses...
# 13  {'away': {'leagueRecord': {'wins': 53, 'losses...
# 14  {'away': {'leagueRecord': {'wins': 47, 'losses...
# 15  {'away': {'leagueRecord': {'wins': 51, 'losses...
#
#                                                 venue  ... inningBreakLength  \
# 0   {'id': 3313, 'name': 'Yankee Stadium', 'link':...  ...               120
# 1   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...               120
# 2   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...               120
# 3   {'id': 14, 'name': 'Rogers Centre', 'link': '/...  ...               120
# 4   {'id': 10, 'name': 'Oakland Coliseum', 'link':...  ...               120
# 5   {'id': 4169, 'name': 'loanDepot park', 'link':...  ...               120
# 6   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...  ...               120
# 7   {'id': 3309, 'name': 'Nationals Park', 'link':...  ...               120
# 8   {'id': 5325, 'name': 'Globe Life Field', 'link...  ...               120
# 9   {'id': 5, 'name': 'Progressive Field', 'link':...  ...               120
# 10  {'id': 7, 'name': 'Kauffman Stadium', 'link': ...  ...               120
# 11  {'id': 3312, 'name': 'Target Field', 'link': '...  ...               120
# 12  {'id': 17, 'name': 'Wrigley Field', 'link': '/...  ...               145
# 13  {'id': 22, 'name': 'Dodger Stadium', 'link': '...  ...               145
# 14  {'id': 19, 'name': 'Coors Field', 'link': '/ap...  ...               120
# 15  {'id': 680, 'name': 'T-Mobile Park', 'link': '...  ...               120
#
#     gamesInSeries  seriesGameNumber seriesDescription recordSource  \
# 0               4                 2    Regular Season            S
# 1               3                 1    Regular Season            S
# 2               3                 2    Regular Season            S
# 3               3                 2    Regular Season            S
# 4               3                 2    Regular Season            S
# 5               4                 2    Regular Season            S
# 6               3                 2    Regular Season            S
# 7               3                 2    Regular Season            S
# 8               3                 2    Regular Season            S
# 9               3                 2    Regular Season            S
# 10              3                 2    Regular Season            S
# 11              2                 1    Regular Season            S
# 12              3                 2    Regular Season            S
# 13              3                 2    Regular Season            S
# 14              3                 2    Regular Season            S
# 15              3                 2    Regular Season            S
#
#    ifNecessary ifNecessaryDescription       rescheduledFrom  \
# 0            N            Normal Game                   NaN
# 1            N            Normal Game  2024-07-19T23:20:00Z
# 2            N            Normal Game                   NaN
# 3            N            Normal Game                   NaN
# 4            N            Normal Game                   NaN
# 5            N            Normal Game                   NaN
# 6            N            Normal Game                   NaN
# 7            N            Normal Game                   NaN
# 8            N            Normal Game                   NaN
# 9            N            Normal Game                   NaN
# 10           N            Normal Game                   NaN
# 11           N            Normal Game                   NaN
# 12           N            Normal Game                   NaN
# 13           N            Normal Game                   NaN
# 14           N            Normal Game                   NaN
# 15           N            Normal Game                   NaN
#
#    rescheduledFromDate         description
# 0                  NaN                 NaN
# 1           2024-07-19  Makeup of 7/19 PPD
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# 5                  NaN                 NaN
# 6                  NaN                 NaN
# 7                  NaN                 NaN
# 8                  NaN                 NaN
# 9                  NaN                 NaN
# 10                 NaN                 NaN
# 11                 NaN                 NaN
# 12                 NaN                 NaN
# 13                 NaN                 NaN
# 14                 NaN                 NaN
# 15                 NaN                 NaN
#
# [16 rows x 31 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T

player_df
# Out:
#               id            fullName                   link  firstName  \
# ID543859  543859      Michael Tonkin  /api/v1/people/543859    Michael
# ID670764  670764        Taylor Walls  /api/v1/people/670764     Taylor
# ID641482  641482       Nestor Cortes  /api/v1/people/641482     Nestor
# ID542888  542888     Shawn Armstrong  /api/v1/people/542888      Shawn
# ID518934  518934         DJ LeMahieu  /api/v1/people/518934      David
# ID664040  664040        Brandon Lowe  /api/v1/people/664040    Brandon
# ID671737  671737         Taj Bradley  /api/v1/people/671737        Taj
# ID664126  664126      Pete Fairbanks  /api/v1/people/664126      Peter
# ID686752  686752         Ryan Pepiot  /api/v1/people/686752       Ryan
# ID657077  657077        Alex Verdugo  /api/v1/people/657077  Alexander
# ID676356  676356        Jonny DeLuca  /api/v1/people/676356   Jonathan
# ID669224  669224        Austin Wells  /api/v1/people/669224     Austin
# ID700250  700250            Ben Rice  /api/v1/people/700250   Benjamin
# ID650402  650402      Gleyber Torres  /api/v1/people/650402    Gleyber
# ID670955  670955         Edwin Uceta  /api/v1/people/670955      Edwin
# ID664776  664776        Jake Cousins  /api/v1/people/664776       Jake
# ID605280  605280         Clay Holmes  /api/v1/people/605280    Clayton
# ID621363  621363         Colin Poche  /api/v1/people/621363      Colin
# ID641793  641793        Zack Littell  /api/v1/people/641793       Zack
# ID665742  665742           Juan Soto  /api/v1/people/665742       Juan
# ID656671  656671    Josh Maciejewski  /api/v1/people/656671       Josh
# ID573186  573186      Marcus Stroman  /api/v1/people/573186     Marcus
# ID663757  663757       Trent Grisham  /api/v1/people/663757    Trenton
# ID605204  605204          J.D. Davis  /api/v1/people/605204   Jonathan
# ID543037  543037         Gerrit Cole  /api/v1/people/543037     Gerrit
# ID642350  642350           Jose Siri  /api/v1/people/642350       Jose
# ID670623  670623       Isaac Paredes  /api/v1/people/670623      Isaac
# ID676609  676609      José Caballero  /api/v1/people/676609       José
# ID666163  666163        Ben Rortvedt  /api/v1/people/666163   Benjamin
# ID607074  607074        Carlos Rodón  /api/v1/people/607074     Carlos
# ID680700  680700     Richie Palacios  /api/v1/people/680700    Richard
# ID668227  668227     Randy Arozarena  /api/v1/people/668227      Randy
# ID663330  663330        Jahmai Jones  /api/v1/people/663330     Jahmai
# ID669358  669358           Shane Baz  /api/v1/people/669358      Shane
# ID596133  596133         Luke Weaver  /api/v1/people/596133       Luke
# ID592094  592094          Jason Adam  /api/v1/people/592094      Jason
# ID642708  642708        Amed Rosario  /api/v1/people/642708     German
# ID665828  665828     Oswaldo Cabrera  /api/v1/people/665828    Oswaldo
# ID592450  592450         Aaron Judge  /api/v1/people/592450      Aaron
# ID657571  657571      Caleb Ferguson  /api/v1/people/657571      Caleb
# ID678554  678554         Curtis Mead  /api/v1/people/678554     Curtis
# ID657612  657612            Tim Hill  /api/v1/people/657612    Timothy
# ID664076  664076  Garrett Cleavinger  /api/v1/people/664076    Garrett
# ID687330  687330         Kevin Kelly  /api/v1/people/687330      Kevin
# ID621107  621107          Zach Eflin  /api/v1/people/621107    Zachary
# ID666139  666139           Josh Lowe  /api/v1/people/666139     Joshua
# ID592454  592454        Tommy Kahnle  /api/v1/people/592454     Thomas
# ID683011  683011       Anthony Volpe  /api/v1/people/683011    Anthony
# ID665966  665966      Carlos Narvaez  /api/v1/people/665966     Carlos
# ID661563  661563            Luis Gil  /api/v1/people/661563       Luis
# ID655889  655889    Manuel Rodríguez  /api/v1/people/655889     Manuel
# ID656577  656577        Alex Jackson  /api/v1/people/656577  Alexander
#
#              lastName primaryNumber   birthDate currentAge  \
# ID543859       Tonkin            50  1989-11-19         34
# ID670764        Walls             6  1996-07-10         28
# ID641482       Cortes            65  1994-12-10         29
# ID542888    Armstrong            64  1990-09-11         33
# ID518934     LeMahieu            26  1988-07-13         36
# ID664040         Lowe             8  1994-07-06         30
# ID671737      Bradley            45  2001-03-20         23
# ID664126    Fairbanks            29  1993-12-16         30
# ID686752       Pepiot            44  1997-08-21         26
# ID657077      Verdugo            24  1996-05-15         28
# ID676356       DeLuca            21  1998-07-10         26
# ID669224        Wells            28  1999-07-12         25
# ID700250         Rice            93  1999-02-22         25
# ID650402       Torres            25  1996-12-13         27
# ID670955        Uceta            63  1998-01-09         26
# ID664776      Cousins            61  1994-07-14         30
# ID605280       Holmes            35  1993-03-27         31
# ID621363        Poche            38  1994-01-17         30
# ID641793      Littell            52  1995-10-05         28
# ID665742         Soto            22  1998-10-25         25
# ID656671  Maciejewski            63  1995-08-14         28
# ID573186      Stroman             0  1991-05-01         33
# ID663757      Grisham            12  1996-11-01         27
# ID605204        Davis            38  1993-04-27         31
# ID543037         Cole            45  1990-09-08         33
# ID642350         Siri            22  1995-07-22         28
# ID670623      Paredes            17  1999-02-18         25
# ID676609    Caballero             7  1996-08-30         27
# ID666163     Rortvedt            30  1997-09-25         26
# ID607074        Rodón            55  1992-12-10         31
# ID680700     Palacios             1  1997-05-16         27
# ID668227    Arozarena            56  1995-02-28         29
# ID663330        Jones            14  1997-08-04         26
# ID669358          Baz            11  1999-06-17         25
# ID596133       Weaver            30  1993-08-21         30
# ID592094         Adam            47  1991-08-04         32
# ID642708      Rosario            10  1995-11-20         28
# ID665828      Cabrera            95  1999-03-01         25
# ID592450        Judge            99  1992-04-26         32
# ID657571     Ferguson            64  1996-07-02         28
# ID678554         Mead            25  2000-10-26         23
# ID657612         Hill            54  1990-02-10         34
# ID664076   Cleavinger            60  1994-04-23         30
# ID687330        Kelly            49  1997-11-28         26
# ID621107        Eflin            24  1994-04-08         30
# ID666139         Lowe            15  1998-02-02         26
# ID592454       Kahnle            41  1989-08-07         34
# ID683011        Volpe            11  2001-04-28         23
# ID665966      Narvaez            94  1998-11-26         25
# ID661563          Gil            81  1998-06-03         26
# ID655889    Rodríguez            39  1996-08-06         27
# ID656577      Jackson            28  1995-12-25         28
#
#                       birthCity birthStateProvince  ...   initLastName  \
# ID543859               Glendale                 CA  ...       M Tonkin
# ID670764                Cordele                 GA  ...        T Walls
# ID641482  Surgidero de Batabano                NaN  ...       N Cortes
# ID542888               New Bern                 NC  ...    S Armstrong
# ID518934                Visalia                 CA  ...     D LeMahieu
# ID664040                Suffolk                 VA  ...         B Lowe
# ID671737            Los Angeles                 CA  ...      T Bradley
# ID664126              Milwaukee                 WI  ...    P Fairbanks
# ID686752           Indianapolis                 IN  ...       R Pepiot
# ID657077                 Tucson                 AZ  ...      A Verdugo
# ID676356          Thousand Oaks                 CA  ...       J DeLuca
# ID669224             Scottsdale                 AZ  ...        A Wells
# ID700250               Cohasset                 MA  ...         B Rice
# ID650402                Caracas                NaN  ...       G Torres
# ID670955    Villa Los Almacigos                NaN  ...        E Uceta
# ID664776              Parkridge                 IL  ...      J Cousins
# ID605280                 Dothan                 AL  ...       C Holmes
# ID621363           Flower Mound                 TX  ...        C Poche
# ID641793             Burlington                 NC  ...      Z Littell
# ID665742          Santo Domingo                NaN  ...         J Soto
# ID656671            Morrisville                 NC  ...  J Maciejewski
# ID573186                Medford                 NY  ...      M Stroman
# ID663757               Burleson                 TX  ...      T Grisham
# ID605204              Elk Grove                 CA  ...        J Davis
# ID543037          Newport Beach                 CA  ...         G Cole
# ID642350  Sabana Grande de Boya                NaN  ...         J Siri
# ID670623             Hermosillo             Sonora  ...      I Paredes
# ID676609             Las Tablas                NaN  ...    J Caballero
# ID666163                Madison                 WI  ...     B Rortvedt
# ID607074                  Miami                 FL  ...        C Rodón
# ID680700               Brooklyn                 NY  ...     R Palacios
# ID668227                 Havana                NaN  ...    R Arozarena
# ID663330                Roswell                 GA  ...        J Jones
# ID669358                Houston                 TX  ...          S Baz
# ID596133                 DeLand                 FL  ...       L Weaver
# ID592094                  Omaha                 NE  ...         J Adam
# ID642708   Santo Domingo Centro                NaN  ...      A Rosario
# ID665828               Guarenas                NaN  ...      O Cabrera
# ID592450                 Linden                 CA  ...        A Judge
# ID657571               Columbus                 OH  ...     C Ferguson
# ID678554               Adelaide                NaN  ...         C Mead
# ID657612          Mission Hills                 CA  ...         T Hill
# ID664076               Lawrence                 KS  ...   G Cleavinger
# ID687330            Springfield                 VA  ...        K Kelly
# ID621107                Orlando                 FL  ...        Z Eflin
# ID666139             Chesapeake                 VA  ...         J Lowe
# ID592454                 Latham                 NY  ...       T Kahnle
# ID683011               New York                 NY  ...        A Volpe
# ID665966                Maracay                NaN  ...      C Narvaez
# ID661563                   Azua                NaN  ...          L Gil
# ID655889                 Merida            Yucatan  ...    M Rodríguez
# ID656577              San Diego                 CA  ...      A Jackson
#
#                         fullFMLName                 fullLFMName strikeZoneTop  \
# ID543859      Michael Harvey Tonkin      Tonkin, Michael Harvey         3.756
# ID670764               Taylor Walls               Walls, Taylor          3.47
# ID641482             Nestor  Cortes              Cortes, Nestor         3.319
# ID542888    Shawn Michael Armstrong    Armstrong, Shawn Michael         3.467
# ID518934        David John LeMahieu        LeMahieu, David John           3.3
# ID664040        Brandon Norman Lowe        Lowe, Brandon Norman          3.29
# ID671737            Taj Ali Bradley            Bradley, Taj Ali         3.467
# ID664126   Peter Anderson Fairbanks   Fairbanks, Peter Anderson         3.656
# ID686752        Ryan Michael Pepiot        Pepiot, Ryan Michael          3.49
# ID657077    Alexander Brady Verdugo    Verdugo, Alexander Brady          3.55
# ID676356      Jonathan Davis DeLuca      DeLuca, Jonathan Davis          3.28
# ID669224       Austin Kenneth Wells       Wells, Austin Kenneth          3.44
# ID700250      Benjamin Kimball Rice      Rice, Benjamin Kimball          3.73
# ID650402       Gleyber David Torres       Torres, Gleyber David          3.26
# ID670955         Edwin Daniel Uceta         Uceta, Edwin Daniel         3.371
# ID664776            Jake O. Cousins            Cousins, Jake O.         3.549
# ID605280      Clayton Walter Holmes      Holmes, Clayton Walter         3.575
# ID621363        Colin Michael Poche        Poche, Colin Michael          3.49
# ID641793        Zack Stuart Littell        Littell, Zack Stuart         3.549
# ID665742             Juan Jose Soto             Soto, Juan Jose          3.12
# ID656671    Josh Graham Maciejewski    Maciejewski, Josh Graham          3.49
# ID573186        Marcus Earl Stroman        Stroman, Marcus Earl          3.38
# ID663757     Trenton Marcus Grisham     Grisham, Trenton Marcus          3.67
# ID605204     Jonathan Gregory Davis     Davis, Jonathan Gregory          3.51
# ID543037           Gerrit Alan Cole           Cole, Gerrit Alan         3.549
# ID642350        Jose Alexander Siri        Siri, Jose Alexander          3.52
# ID670623      Isaac Edgardo Paredes      Paredes, Isaac Edgardo          3.28
# ID676609             José Caballero            Caballero, José           3.05
# ID666163   Benjamin Thomas Rortvedt   Rortvedt, Benjamin Thomas          3.16
# ID607074       Carlos Antonio Rodón       Rodón, Carlos Antonio         3.467
# ID680700          Richard  Palacios          Palacios, Richard           3.49
# ID668227            Randy Arozarena            Arozarena, Randy           3.3
# ID663330    Jahmai Fitzgerald Jones    Jones, Jahmai Fitzgerald           3.5
# ID669358           Shane Austin Baz           Baz, Shane Austin         3.467
# ID596133          Luke Allen Weaver          Weaver, Luke Allen         3.467
# ID592094         Jason Kendall Adam         Adam, Jason Kendall          3.49
# ID642708        German Amed Rosario        Rosario, German Amed           3.3
# ID665828    Oswaldo Alberto Cabrera    Cabrera, Oswaldo Alberto          3.19
# ID592450          Aaron James Judge          Judge, Aaron James          4.07
# ID657571        Caleb Paul Ferguson        Ferguson, Caleb Paul          3.49
# ID678554          Curtis James Mead          Mead, Curtis James          3.56
# ID657612               Timothy Hill               Hill, Timothy         3.549
# ID664076      Garrett J. Cleavinger      Cleavinger, Garrett J.         3.411
# ID687330        Kevin Clayton Kelly        Kelly, Kevin Clayton         3.467
# ID621107        Zachary Adams Eflin        Eflin, Zachary Adams          3.68
# ID666139         Joshua Edward Lowe         Lowe, Joshua Edward          3.72
# ID592454       Thomas Robert Kahnle       Kahnle, Thomas Robert         3.411
# ID683011      Anthony Michael Volpe      Volpe, Anthony Michael          3.38
# ID665966        Carlos Luis Narvaez        Narvaez, Carlos Luis         3.319
# ID661563             Luis Angel Gil             Gil, Luis Angel         3.467
# ID655889  Manuel De Jesus Rodríguez  Rodríguez, Manuel De Jesus         3.319
# ID656577    Alexander James Jackson    Jackson, Alexander James           3.5
#
#          strikeZoneBottom      nickName nameTitle nameSuffix  \
# ID543859            1.746           NaN       NaN        NaN
# ID670764             1.58           NaN       NaN        NaN
# ID641482            1.513   Hialeah Kid       Jr.        Jr.
# ID542888            1.589         Armie       NaN        NaN
# ID518934             1.55     Big Fundy       NaN        NaN
# ID664040             1.53     Bamm-Bamm       NaN        NaN
# ID671737            1.589           NaN       NaN        NaN
# ID664126            1.677           NaN       NaN        NaN
# ID686752            1.601           NaN       NaN        NaN
# ID657077             1.59         Dugie       NaN        NaN
# ID676356             1.56           NaN       NaN        NaN
# ID669224             1.61           NaN       NaN        NaN
# ID700250             1.81           NaN       NaN        NaN
# ID650402             1.54    De Caracas       NaN        NaN
# ID670955            1.535           NaN       NaN        NaN
# ID664776            1.627           NaN       NaN        NaN
# ID605280            1.681           NaN       NaN        NaN
# ID621363            1.601            Po       NaN        NaN
# ID641793            1.627           Lit       NaN        NaN
# ID665742             1.52  Soto Pacheco       NaN        NaN
# ID656671            1.601           NaN       NaN        NaN
# ID573186             1.56          HDMH       NaN        NaN
# ID663757             1.79         Grish       NaN        NaN
# ID605204              1.6        Dizzle       NaN        NaN
# ID543037            1.627        Chef G       NaN        NaN
# ID642350             1.68           NaN       NaN        NaN
# ID670623             1.62           NaN       NaN        NaN
# ID676609             1.38           NaN       NaN        NaN
# ID666163             1.49           NaN       NaN        NaN
# ID607074            1.589           Los       NaN        NaN
# ID680700             1.63           NaN       NaN        NaN
# ID668227             1.58           NaN       NaN        NaN
# ID663330             1.64           NaN       NaN        NaN
# ID669358            1.589           NaN       NaN        NaN
# ID596133            1.589         Dream       NaN        NaN
# ID592094            1.601           NaN       NaN        NaN
# ID642708             1.56         Rosie       NaN        NaN
# ID665828             1.49           NaN       NaN        NaN
# ID592450              1.8           Baj       NaN        NaN
# ID657571            1.601           NaN       NaN        NaN
# ID678554             1.66           NaN       NaN        NaN
# ID657612            1.627       Tim Jim       NaN        NaN
# ID664076            1.565           NaN       NaN        NaN
# ID687330            1.589           NaN       NaN        NaN
# ID621107              1.7            Ef       NaN        NaN
# ID666139             1.76           NaN       NaN        NaN
# ID592454            1.565     King Kahn       NaN        NaN
# ID683011             1.61           NaN       NaN        NaN
# ID665966            1.513           NaN       NaN        NaN
# ID661563            1.589           NaN       NaN        NaN
# ID655889            1.513           NaN       NaN        NaN
# ID656577             1.65           NaN       NaN        NaN
#
#                  pronunciation nameMatrilineal
# ID543859                   NaN             NaN
# ID670764                   NaN             NaN
# ID641482                   NaN             NaN
# ID542888                   NaN             NaN
# ID518934          luh-MAY-hyoo             NaN
# ID664040     rhymes with 'now'             NaN
# ID671737                   NaN             NaN
# ID664126                   NaN             NaN
# ID686752            PEH-pee-oh             NaN
# ID657077           vehr-DOO-go             NaN
# ID676356                   NaN             NaN
# ID669224                   NaN             NaN
# ID700250                   NaN             NaN
# ID650402             GLAY-burr          Castro
# ID670955                   NaN        Martinez
# ID664776                   NaN             NaN
# ID605280                   NaN             NaN
# ID621363              poh-SHAY             NaN
# ID641793              lah-TELL             NaN
# ID665742                   NaN         Pacheco
# ID656671                   NaN             NaN
# ID573186                   NaN             NaN
# ID663757              GRISH-um             NaN
# ID605204                   NaN             NaN
# ID543037                   NaN             NaN
# ID642350                   NaN             NaN
# ID670623  e-sa-AK Puh-ray-dess        Calderon
# ID676609                   NaN             NaN
# ID666163              rort-vet             NaN
# ID607074               row-DON             NaN
# ID680700                   NaN             NaN
# ID668227    ah-row-sah-RAY-nah        Gonzalez
# ID663330                juh-MY             NaN
# ID669358                   BOZ             NaN
# ID596133                   NaN             NaN
# ID592094                   NaN             NaN
# ID642708        row-SAH-ree-oh          Valdez
# ID665828                   NaN      Mabaricuna
# ID592450                   NaN             NaN
# ID657571                   NaN             NaN
# ID678554                   NaN             NaN
# ID657612                   NaN             NaN
# ID664076                   NaN             NaN
# ID687330                   NaN             NaN
# ID621107               EFF-lin             NaN
# ID666139                   low             NaN
# ID592454              cain-lee             NaN
# ID683011                   NaN             NaN
# ID665966                   NaN           Olivo
# ID661563                  Heel           Brito
# ID655889                   NaN          Caamal
# ID656577                   NaN             NaN
#
# [52 rows x 41 columns]

# %%
def get_avg(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['avg'])

def get_atBats(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['atBats'])



averages = player_df.id.apply(get_avg)
player_df = player_df.assign(avg=averages.values)

player_atBats = player_df.id.apply(get_atBats)
player_df = player_df.assign(atBats=player_atBats.values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[154], line 15
#      10         return 0
#      11     return float(player['stats'][0]['stats']['atBats'])
# ---> 15 averages = player_df.id.apply(get_avg)
#      16 player_df = player_df.assign(avg=averages.values)
#      18 player_atBats = player_df.id.apply(get_atBats)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[154], line 5, in get_avg(player_id)
#       3 if player['position'] == 'P':
#       4     return 0
# ----> 5 return float(player['stats'][0]['stats']['avg'])
#
# IndexError: list index out of range

# %%
batScore = player_df.avg * player_df.atBats / 30
player_df = player_df.assign(batScore=batScore.values)
    


dayScore = player_df.batScore
player_df = player_df.assign(dayScore=dayScore.values)

dayStatus = player_df.dayScore >= 3
player_df = player_df.assign(dayStatus=dayStatus.values)

valid_hitters = player_df['dayStatus'] == True

player_df.loc[valid_hitters].T

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
