# %%
import pandas as pd
import requests
import numpy as np
import statsapi

# %%
url = 'http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1'
r = requests.get(url=url).json()
dates = r['dates'][0]['games']
df = pd.DataFrame(dates)
df
# Out:
#     gamePk                              gameGuid  \
# 0   745882  6be6256c-7c00-416e-9afe-e3e7b28b08eb
# 1   744831  bca44bc5-6d75-45f5-8e35-a293f4e100e8
# 2   745470  ba48d1f6-638d-47a8-8da8-00c0121903ba
# 3   747094  36a034a1-327e-4dac-b747-094ce9c05dcc
# 4   745722  aa746aae-c89b-48d1-877a-a11537ae660e
# 5   744909  92862612-bc6d-4377-b9ec-42daccc94c87
# 6   746610  05543077-d94a-4c0a-99b8-119a78cec933
# 7   746042  3f976558-a336-4c62-80c3-8767bd60080a
# 8   746287  e68faedc-7238-4f84-8fb7-65aed09aed8d
# 9   746853  5fe12793-9d72-4a57-a58a-9fcee8c591dd
# 10  744991  ccfadee6-3678-4a2f-9490-b0600de4c0da
# 11  746528  90f62b1b-1555-4985-b98c-0c894ba0efc5
# 12  745633  c6298b80-8b19-4bc0-94df-f7bed83d4e77
# 13  745230  fed57153-ede6-4c4d-96fe-50e20e12b27d
# 14  746125  012eb5d5-a3a1-4cc1-9734-5b51bd6397b7
#
#                                link gameType season              gameDate  \
# 0   /api/v1.1/game/745882/feed/live        R   2024  2024-07-21T17:05:00Z
# 1   /api/v1.1/game/744831/feed/live        R   2024  2024-07-21T17:35:00Z
# 2   /api/v1.1/game/745470/feed/live        R   2024  2024-07-21T17:35:00Z
# 3   /api/v1.1/game/747094/feed/live        R   2024  2024-07-21T17:35:00Z
# 4   /api/v1.1/game/745722/feed/live        R   2024  2024-07-21T17:35:00Z
# 5   /api/v1.1/game/744909/feed/live        R   2024  2024-07-21T17:37:00Z
# 6   /api/v1.1/game/746610/feed/live        R   2024  2024-07-21T17:40:00Z
# 7   /api/v1.1/game/746042/feed/live        R   2024  2024-07-21T17:40:00Z
# 8   /api/v1.1/game/746287/feed/live        R   2024  2024-07-21T18:10:00Z
# 9   /api/v1.1/game/746853/feed/live        R   2024  2024-07-21T18:20:00Z
# 10  /api/v1.1/game/744991/feed/live        R   2024  2024-07-21T18:35:00Z
# 11  /api/v1.1/game/746528/feed/live        R   2024  2024-07-21T19:10:00Z
# 12  /api/v1.1/game/745633/feed/live        R   2024  2024-07-21T20:07:00Z
# 13  /api/v1.1/game/745230/feed/live        R   2024  2024-07-21T20:10:00Z
# 14  /api/v1.1/game/746125/feed/live        R   2024  2024-07-21T23:10:00Z
#
#    officialDate                                             status  \
# 0    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 1    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 2    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 3    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 4    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 5    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 6    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 7    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 8    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 9    2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 10   2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 11   2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 12   2024-07-21  {'abstractGameState': 'Live', 'codedGameState'...
# 13   2024-07-21  {'abstractGameState': 'Preview', 'codedGameSta...
# 14   2024-07-21  {'abstractGameState': 'Preview', 'codedGameSta...
#
#                                                 teams  \
# 0   {'away': {'leagueRecord': {'wins': 56, 'losses...
# 1   {'away': {'leagueRecord': {'wins': 47, 'losses...
# 2   {'away': {'leagueRecord': {'wins': 62, 'losses...
# 3   {'away': {'leagueRecord': {'wins': 51, 'losses...
# 4   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 5   {'away': {'leagueRecord': {'wins': 49, 'losses...
# 6   {'away': {'leagueRecord': {'wins': 51, 'losses...
# 7   {'away': {'leagueRecord': {'wins': 50, 'losses...
# 8   {'away': {'leagueRecord': {'wins': 27, 'losses...
# 9   {'away': {'leagueRecord': {'wins': 51, 'losses...
# 10  {'away': {'leagueRecord': {'wins': 60, 'losses...
# 11  {'away': {'leagueRecord': {'wins': 47, 'losses...
# 12  {'away': {'leagueRecord': {'wins': 41, 'losses...
# 13  {'away': {'leagueRecord': {'wins': 52, 'losses...
# 14  {'away': {'leagueRecord': {'wins': 53, 'losses...
#
#                                                 venue  ... dayNight  \
# 0   {'id': 3312, 'name': 'Target Field', 'link': '...  ...      day
# 1   {'id': 3309, 'name': 'Nationals Park', 'link':...  ...      day
# 2   {'id': 31, 'name': 'PNC Park', 'link': '/api/v...  ...      day
# 3   {'id': 4705, 'name': 'Truist Park', 'link': '/...  ...      day
# 4   {'id': 3313, 'name': 'Yankee Stadium', 'link':...  ...      day
# 5   {'id': 14, 'name': 'Rogers Centre', 'link': '/...  ...      day
# 6   {'id': 5, 'name': 'Progressive Field', 'link':...  ...      day
# 7   {'id': 4169, 'name': 'loanDepot park', 'link':...  ...      day
# 8   {'id': 7, 'name': 'Kauffman Stadium', 'link': ...  ...      day
# 9   {'id': 17, 'name': 'Wrigley Field', 'link': '/...  ...      day
# 10  {'id': 5325, 'name': 'Globe Life Field', 'link...  ...      day
# 11  {'id': 19, 'name': 'Coors Field', 'link': '/ap...  ...      day
# 12  {'id': 10, 'name': 'Oakland Coliseum', 'link':...  ...      day
# 13  {'id': 680, 'name': 'T-Mobile Park', 'link': '...  ...      day
# 14  {'id': 22, 'name': 'Dodger Stadium', 'link': '...  ...      day
#
#     scheduledInnings  reverseHomeAwayStatus inningBreakLength gamesInSeries  \
# 0                  9                  False               145             2
# 1                  9                  False               120             3
# 2                  9                  False               120             3
# 3                  9                  False               120             3
# 4                  9                  False               120             4
# 5                  9                  False               120             3
# 6                  9                  False               120             3
# 7                  9                  False               120             4
# 8                  9                  False               120             3
# 9                  9                  False               120             3
# 10                 9                  False               120             3
# 11                 9                  False               120             3
# 12                 9                  False               120             3
# 13                 9                  False               120             3
# 14                 9                  False               145             3
#
#    seriesGameNumber seriesDescription recordSource ifNecessary  \
# 0                 2    Regular Season            S           N
# 1                 3    Regular Season            S           N
# 2                 3    Regular Season            S           N
# 3                 3    Regular Season            S           N
# 4                 3    Regular Season            S           N
# 5                 3    Regular Season            S           N
# 6                 3    Regular Season            S           N
# 7                 3    Regular Season            S           N
# 8                 3    Regular Season            S           N
# 9                 3    Regular Season            S           N
# 10                3    Regular Season            S           N
# 11                3    Regular Season            S           N
# 12                3    Regular Season            S           N
# 13                3    Regular Season            S           N
# 14                3    Regular Season            S           N
#
#     ifNecessaryDescription
# 0              Normal Game
# 1              Normal Game
# 2              Normal Game
# 3              Normal Game
# 4              Normal Game
# 5              Normal Game
# 6              Normal Game
# 7              Normal Game
# 8              Normal Game
# 9              Normal Game
# 10             Normal Game
# 11             Normal Game
# 12             Normal Game
# 13             Normal Game
# 14             Normal Game
#
# [15 rows x 28 columns]

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T

player_df
# Out:
#               id                 fullName                   link    firstName  \
# ID687401  687401               Joey Ortiz  /api/v1/people/687401       Joseph
# ID665856  665856             Jair Camargo  /api/v1/people/665856         Jair
# ID668964  668964             Tobias Myers  /api/v1/people/668964       Tobias
# ID686797  686797               Brooks Lee  /api/v1/people/686797       Brooks
# ID668885  668885            Austin Martin  /api/v1/people/668885  Christopher
# ID680573  680573  Simeon Woods Richardson  /api/v1/people/680573       Simeon
# ID595345  595345             Steven Okert  /api/v1/people/595345       Steven
# ID660636  660636        Diego A. Castillo  /api/v1/people/660636        Diego
# ID678692  678692          Ronny Henriquez  /api/v1/people/678692        Ronny
# ID650489  650489             Willi Castro  /api/v1/people/650489        Willi
# ID622534  622534            Manuel Margot  /api/v1/people/622534       Manuel
# ID666397  666397           Edouard Julien  /api/v1/people/666397      Edouard
# ID650644  650644             Aaron Civale  /api/v1/people/650644        Aaron
# ID622251  622251            Josh Staumont  /api/v1/people/622251       Joshua
# ID663368  663368            Blake Perkins  /api/v1/people/663368        Blake
# ID665625  665625            Elvis Peguero  /api/v1/people/665625        Elvis
# ID663485  663485               Cole Sands  /api/v1/people/663485       Bryson
# ID661388  661388        William Contreras  /api/v1/people/661388      William
# ID607067  607067                Colin Rea  /api/v1/people/607067        Colin
# ID643377  643377              Griffin Jax  /api/v1/people/643377        James
# ID668930  668930             Brice Turang  /api/v1/people/668930        Brice
# ID641154  641154              Pablo López  /api/v1/people/641154        Pablo
# ID596001  596001              Jakob Junis  /api/v1/people/596001        Jakob
# ID642715  642715             Willy Adames  /api/v1/people/642715        Willy
# ID657649  657649             Jared Koenig  /api/v1/people/657649        Jared
# ID669060  669060             Bryse Wilson  /api/v1/people/669060        Bryse
# ID621439  621439             Byron Buxton  /api/v1/people/621439        Byron
# ID543877  543877        Christian Vázquez  /api/v1/people/543877    Christian
# ID670242  670242             Matt Wallner  /api/v1/people/670242      Matthew
# ID656555  656555             Rhys Hoskins  /api/v1/people/656555         Rhys
# ID571948  571948              Hoby Milner  /api/v1/people/571948         Hoby
# ID642239  642239            Rob Zastryzny  /api/v1/people/642239       Robert
# ID694192  694192          Jackson Chourio  /api/v1/people/694192      Jackson
# ID661395  661395              Jhoan Duran  /api/v1/people/661395        Jhoan
# ID592885  592885         Christian Yelich  /api/v1/people/592885    Christian
# ID641343  641343              Jake Bauers  /api/v1/people/641343        Jakob
# ID573204  573204           Caleb Thielbar  /api/v1/people/573204        Caleb
# ID686217  686217              Sal Frelick  /api/v1/people/686217    Salvatore
# ID660896  660896             Jorge Alcala  /api/v1/people/660896        Jorge
# ID606303  606303             Joel Payamps  /api/v1/people/606303         Joel
# ID655316  655316        Andruw Monasterio  /api/v1/people/655316       Andruw
# ID669003  669003         Garrett Mitchell  /api/v1/people/669003      Garrett
# ID642547  642547           Freddy Peralta  /api/v1/people/642547       Freddy
# ID680777  680777             Ryan Jeffers  /api/v1/people/680777         Ryan
# ID663542  663542             Bryan Hudson  /api/v1/people/663542        Bryan
# ID606992  606992               Eric Haase  /api/v1/people/606992         Eric
# ID641927  641927              Bailey Ober  /api/v1/people/641927         John
# ID596146  596146               Max Kepler  /api/v1/people/596146   Maximilian
# ID663616  663616           Trevor Larnach  /api/v1/people/663616       Trevor
# ID467793  467793           Carlos Santana  /api/v1/people/467793       Carlos
# ID657746  657746                 Joe Ryan  /api/v1/people/657746       Joseph
# ID656730  656730            Trevor Megill  /api/v1/people/656730       Trevor
#
#                   lastName primaryNumber   birthDate currentAge  \
# ID687401             Ortiz             3  1998-07-14         26
# ID665856           Camargo            85  1999-07-01         25
# ID668964             Myers            36  1998-08-05         25
# ID686797               Lee            72  2001-02-14         23
# ID668885            Martin            82  1999-03-23         25
# ID680573  Woods Richardson            78  2000-09-27         23
# ID595345             Okert            16  1991-07-09         33
# ID660636          Castillo            39  1997-10-28         26
# ID678692         Henriquez            31  2000-06-20         24
# ID650489            Castro            50  1997-04-24         27
# ID622534            Margot            13  1994-09-28         29
# ID666397            Julien            47  1999-04-30         25
# ID650644            Civale            32  1995-06-12         29
# ID622251          Staumont            63  1993-12-21         30
# ID663368           Perkins            16  1996-09-10         27
# ID665625           Peguero            59  1997-03-20         27
# ID663485             Sands            44  1997-07-17         27
# ID661388         Contreras            24  1997-12-24         26
# ID607067               Rea            48  1990-07-01         34
# ID643377               Jax            22  1994-11-22         29
# ID668930            Turang             2  1999-11-21         24
# ID641154             López            49  1996-03-07         28
# ID596001             Junis            35  1992-09-16         31
# ID642715            Adames            27  1995-09-02         28
# ID657649            Koenig            47  1994-01-24         30
# ID669060            Wilson            46  1997-12-20         26
# ID621439            Buxton            25  1993-12-18         30
# ID543877           Vázquez             8  1990-08-21         33
# ID670242           Wallner            38  1997-12-12         26
# ID656555           Hoskins            12  1993-03-17         31
# ID571948            Milner            55  1991-01-13         33
# ID642239         Zastryzny            58  1992-03-26         32
# ID694192           Chourio            11  2004-03-11         20
# ID661395             Duran            59  1998-01-08         26
# ID592885            Yelich            22  1991-12-05         32
# ID641343            Bauers             9  1995-10-06         28
# ID573204          Thielbar            56  1987-01-31         37
# ID686217           Frelick            10  2000-04-19         24
# ID660896            Alcala            66  1995-07-28         28
# ID606303           Payamps            31  1994-04-07         30
# ID655316        Monasterio            14  1997-05-30         27
# ID669003          Mitchell             5  1998-09-04         25
# ID642547           Peralta            51  1996-06-04         28
# ID680777           Jeffers            27  1997-06-03         27
# ID663542            Hudson            52  1997-05-08         27
# ID606992             Haase            13  1992-12-18         31
# ID641927              Ober            17  1995-07-12         29
# ID596146            Kepler            26  1993-02-10         31
# ID663616           Larnach             9  1997-02-26         27
# ID467793           Santana            30  1986-04-08         38
# ID657746              Ryan            41  1996-06-05         28
# ID656730            Megill            29  1993-12-05         30
#
#                 birthCity birthStateProvince  ...             lastFirstName  \
# ID687401     Garden Grove                 CA  ...               Ortiz, Joey
# ID665856     Barranquilla                NaN  ...             Camargo, Jair
# ID668964     Winter Haven                 FL  ...             Myers, Tobias
# ID686797  San Luis Obispo                 CA  ...               Lee, Brooks
# ID668885           DeLand                 FL  ...            Martin, Austin
# ID680573       Sugar Land                 TX  ...  Woods Richardson, Simeon
# ID595345        Riverside                 CA  ...             Okert, Steven
# ID660636     Barquisimeto                NaN  ...        Castillo, Diego A.
# ID678692            Bonao                NaN  ...          Henriquez, Ronny
# ID650489      Rio Piedras                NaN  ...             Castro, Willi
# ID622534    San Cristobal                NaN  ...            Margot, Manuel
# ID666397      Quebec City                 QC  ...           Julien, Edouard
# ID650644     East Windsor                 CT  ...             Civale, Aaron
# ID622251         La Habra                 CA  ...            Staumont, Josh
# ID663368  Litchfield Park                 AZ  ...            Perkins, Blake
# ID665625            Cotui                NaN  ...            Peguero, Elvis
# ID663485      Tallahassee                 FL  ...               Sands, Cole
# ID661388   Puerto Cabello                NaN  ...        Contreras, William
# ID607067          Cascade                 IA  ...                Rea, Colin
# ID643377          Phoenix                 AZ  ...              Jax, Griffin
# ID668930           Corona                 CA  ...             Turang, Brice
# ID641154          Cabimas                NaN  ...              López, Pablo
# ID596001     Jacksonville                 AR  ...              Junis, Jakob
# ID642715         Santiago                NaN  ...             Adames, Willy
# ID657649            Aptos                 CA  ...             Koenig, Jared
# ID669060           Durham                 NC  ...             Wilson, Bryse
# ID621439           Baxley                 GA  ...             Buxton, Byron
# ID543877          Bayamon                NaN  ...        Vázquez, Christian
# ID670242      Forest Lake                 MN  ...             Wallner, Matt
# ID656555       Sacramento                 CA  ...             Hoskins, Rhys
# ID571948           Dallas                 TX  ...              Milner, Hoby
# ID642239         Edmonton                 AB  ...            Zastryzny, Rob
# ID694192        Maracaibo                NaN  ...          Chourio, Jackson
# ID661395        Esperanza                NaN  ...              Duran, Jhoan
# ID592885    Thousand Oaks                 CA  ...         Yelich, Christian
# ID641343    Newport Beach                 CA  ...              Bauers, Jake
# ID573204       Northfield                 MN  ...           Thielbar, Caleb
# ID686217           Boston                 MA  ...              Frelick, Sal
# ID660896   Bajos de Haina                NaN  ...             Alcala, Jorge
# ID606303         Santiago                NaN  ...             Payamps, Joel
# ID655316          Caracas                NaN  ...        Monasterio, Andruw
# ID669003           Orange                 CA  ...         Mitchell, Garrett
# ID642547             Moca                NaN  ...           Peralta, Freddy
# ID680777          Raleigh                 NC  ...             Jeffers, Ryan
# ID663542          Godfrey                 IL  ...             Hudson, Bryan
# ID606992          Detroit                 MI  ...               Haase, Eric
# ID641927     Huntersville                 NC  ...              Ober, Bailey
# ID596146           Berlin                NaN  ...               Kepler, Max
# ID663616     Walnut Creek                 CA  ...           Larnach, Trevor
# ID467793    Santo Domingo                NaN  ...           Santana, Carlos
# ID657746    San Francisco                 CA  ...                 Ryan, Joe
# ID656730       Long Beach                 CA  ...            Megill, Trevor
#
#                  lastInitName        initLastName  \
# ID687401             Ortiz, J             J Ortiz
# ID665856           Camargo, J           J Camargo
# ID668964             Myers, T             T Myers
# ID686797               Lee, B               B Lee
# ID668885            Martin, A            A Martin
# ID680573  Woods Richardson, S  S Woods Richardson
# ID595345             Okert, S             S Okert
# ID660636          Castillo, D          D Castillo
# ID678692         Henriquez, R         R Henriquez
# ID650489            Castro, W            W Castro
# ID622534            Margot, M            M Margot
# ID666397            Julien, E            E Julien
# ID650644            Civale, A            A Civale
# ID622251          Staumont, J          J Staumont
# ID663368           Perkins, B           B Perkins
# ID665625           Peguero, E           E Peguero
# ID663485             Sands, C             C Sands
# ID661388         Contreras, W         W Contreras
# ID607067               Rea, C               C Rea
# ID643377               Jax, G               G Jax
# ID668930            Turang, B            B Turang
# ID641154             López, P             P López
# ID596001             Junis, J             J Junis
# ID642715            Adames, W            W Adames
# ID657649            Koenig, J            J Koenig
# ID669060            Wilson, B            B Wilson
# ID621439            Buxton, B            B Buxton
# ID543877           Vázquez, C           C Vázquez
# ID670242           Wallner, M           M Wallner
# ID656555           Hoskins, R           R Hoskins
# ID571948            Milner, H            H Milner
# ID642239         Zastryzny, R         R Zastryzny
# ID694192           Chourio, J           J Chourio
# ID661395             Duran, J             J Duran
# ID592885            Yelich, C            C Yelich
# ID641343            Bauers, J            J Bauers
# ID573204          Thielbar, C          C Thielbar
# ID686217           Frelick, S           S Frelick
# ID660896            Alcala, J            J Alcala
# ID606303           Payamps, J           J Payamps
# ID655316        Monasterio, A        A Monasterio
# ID669003          Mitchell, G          G Mitchell
# ID642547           Peralta, F           F Peralta
# ID680777           Jeffers, R           R Jeffers
# ID663542            Hudson, B            B Hudson
# ID606992             Haase, E             E Haase
# ID641927              Ober, B              B Ober
# ID596146            Kepler, M            M Kepler
# ID663616           Larnach, T           T Larnach
# ID467793           Santana, C           C Santana
# ID657746              Ryan, J              J Ryan
# ID656730            Megill, T            T Megill
#
#                               fullFMLName                       fullLFMName  \
# ID687401             Joseph Anthony Ortiz             Ortiz, Joseph Anthony
# ID665856               Jair David Camargo               Camargo, Jair David
# ID668964                Tobias Kane Myers                Myers, Tobias Kane
# ID686797                Brooks Thomas Lee                Lee, Brooks Thomas
# ID668885        Christopher Austin Martin        Martin, Christopher Austin
# ID680573          Simeon Woods Richardson          Woods Richardson, Simeon
# ID595345            Steven Chandler Okert            Okert, Steven Chandler
# ID660636         Diego Alejandro Castillo         Castillo, Diego Alejandro
# ID678692                 Ronny  Henriquez                 Henriquez, Ronny
# ID650489              Willi Rafael Castro              Castro, Willi Rafael
# ID622534                    Manuel Margot                    Margot, Manuel
# ID666397                   Edouard Julien                   Julien, Edouard
# ID650644               Aaron James Civale               Civale, Aaron James
# ID622251            Joshua Tyler Staumont            Staumont, Joshua Tyler
# ID663368          Blake Alexander Perkins          Perkins, Blake Alexander
# ID665625            Elvis Antonio Peguero            Peguero, Elvis Antonio
# ID663485                Bryson Cole Sands                Sands, Bryson Cole
# ID661388          William Jesus Contreras          Contreras, William Jesus
# ID607067                     Colin D. Rea                     Rea, Colin D.
# ID643377                James Griffin Jax                Jax, James Griffin
# ID668930               Brice Craig Turang               Turang, Brice Craig
# ID641154                 Pablo Jose López                 López, Pablo Jose
# ID596001         Jakob Benjamin Lee Junis         Junis, Jakob Benjamin Lee
# ID642715              Willy Rafael Adames              Adames, Willy Rafael
# ID657649               Jared Tyler Koenig               Koenig, Jared Tyler
# ID669060             Bryse Everett Wilson             Wilson, Bryse Everett
# ID621439              Byron Keiron Buxton              Buxton, Byron Keiron
# ID543877         Christian Rafael Vázquez         Vázquez, Christian Rafael
# ID670242                  Matthew Wallner                  Wallner, Matthew
# ID656555                Rhys Dean Hoskins                Hoskins, Rhys Dean
# ID571948                      Hoby Milner                      Milner, Hoby
# ID642239            Robert John Zastryzny            Zastryzny, Robert John
# ID694192            Jackson Bryan Chourio            Chourio, Jackson Bryan
# ID661395               Jhoan Manuel Duran               Duran, Jhoan Manuel
# ID592885         Christian Stephen Yelich         Yelich, Christian Stephen
# ID641343         Jakob Christopher Bauers         Bauers, Jakob Christopher
# ID573204              Caleb John Thielbar              Thielbar, Caleb John
# ID686217        Salvatore Michael Frelick        Frelick, Salvatore Michael
# ID660896                Jorge Luis Alcala                Alcala, Jorge Luis
# ID606303               Joel Elias Payamps               Payamps, Joel Elias
# ID655316           Andruw José Monasterio           Monasterio, Andruw José
# ID669003  Garrett Antony-Charles Mitchell  Mitchell, Garrett Antony-Charles
# ID642547                   Freddy Peralta                   Peralta, Freddy
# ID680777             Ryan Michael Jeffers             Jeffers, Ryan Michael
# ID663542             Bryan Michael Hudson             Hudson, Bryan Michael
# ID606992               Eric Michael Haase               Haase, Eric Michael
# ID641927                 John Bailey Ober                 Ober, John Bailey
# ID596146                Maximilian Kepler                Kepler, Maximilian
# ID663616   Trevor John-Ikaiakaloa Larnach   Larnach, Trevor John-Ikaiakaloa
# ID467793                   Carlos Santana                   Santana, Carlos
# ID657746               Joseph Philip Ryan               Ryan, Joseph Philip
# ID656730                 Trevor J. Megill                 Megill, Trevor J.
#
#          strikeZoneTop strikeZoneBottom nameMatrilineal   nickName  \
# ID687401          3.41             1.52             NaN        NaN
# ID665856         3.301            1.504          Alonso        NaN
# ID668964         3.411            1.565             NaN        NaN
# ID686797          3.33             1.51             NaN        NaN
# ID668885           3.2              1.5             NaN        NaN
# ID680573          3.49            1.601             NaN        NaN
# ID595345         3.467            1.589             NaN          O
# ID660636          3.42             1.56       Rodriguez        NaN
# ID678692         3.301            1.504          Aquino        NaN
# ID650489          3.57             1.62        Capellan        NaN
# ID622534          3.45              1.6           Gomez    Yoandry
# ID666397          3.34             1.67             NaN        NaN
# ID650644         3.467            1.589             NaN        NaN
# ID622251          3.49            1.601             NaN        NaN
# ID663368          3.39             1.61             NaN        NaN
# ID665625         3.575            1.681           Reyes        NaN
# ID663485          3.49            1.601             NaN        NaN
# ID661388          3.53             1.69        Castillo        NaN
# ID607067         3.575            1.681             NaN        NaN
# ID643377         3.467            1.589             NaN      Griff
# ID668930          3.17             1.48             NaN        NaN
# ID641154          3.66             1.72           Serra      Pache
# ID596001          3.49            1.601             NaN   June Bug
# ID642715          3.44             1.71            Luna    The Kid
# ID657649         3.575            1.681             NaN        NaN
# ID669060          3.55             1.66             NaN        NaN
# ID621439          3.41             1.49             NaN       Buck
# ID543877          3.28             1.57             NaN       Colo
# ID670242          3.76             1.76             NaN        NaN
# ID656555          3.54             1.64             NaN  Big Fella
# ID571948          3.49            1.601             NaN        NaN
# ID642239          3.49            1.601             NaN        NaN
# ID694192          3.32             1.59            Lugo        NaN
# ID661395         3.575            1.681         Sanchez        NaN
# ID592885           3.4             1.73             NaN       Yeli
# ID641343          3.44             1.63             NaN         JB
# ID573204         3.371            1.535             NaN        NaN
# ID686217          3.07             1.46             NaN        NaN
# ID660896          3.49            1.601             NaN        NaN
# ID606303         3.467            1.589          Garcia        NaN
# ID655316          3.25             1.54        Palacios        NaN
# ID669003          3.45             1.64             NaN        NaN
# ID642547          3.28             1.55            Diaz     Kacike
# ID680777          3.27             1.52             NaN        NaN
# ID663542         3.688            1.747             NaN        NaN
# ID606992          3.23             1.54             NaN        NaN
# ID641927          3.82            1.665          Bailey        NaN
# ID596146           3.6             1.66         Rozycki    Rozycki
# ID663616          3.87             1.74             NaN        NaN
# ID467793          3.45             1.66             NaN   Slamtana
# ID657746         3.467            1.589             NaN        NaN
# ID656730         3.688            1.747             NaN        NaN
#
#              pronunciation
# ID687401               NaN
# ID665856               NaN
# ID668964               NaN
# ID686797               NaN
# ID668885               NaN
# ID680573               NaN
# ID595345               NaN
# ID660636               NaN
# ID678692               NaN
# ID650489            willie
# ID622534  man-WEHL mahr-GO
# ID666397               NaN
# ID650644         SIV-all-e
# ID622251         STAH-mont
# ID663368               NaN
# ID665625               NaN
# ID663485               NaN
# ID661388               NaN
# ID607067               NaN
# ID643377               NaN
# ID668930               NaN
# ID641154               NaN
# ID596001               NaN
# ID642715        ah-DAH-mes
# ID657649               NaN
# ID669060               NaN
# ID621439               NaN
# ID543877          VAZ-kehz
# ID670242               NaN
# ID656555    REES HAH-skinz
# ID571948               NaN
# ID642239               NaN
# ID694192               NaN
# ID661395   YO-ahn DOO-rahn
# ID592885         YELL-itch
# ID641343               NaN
# ID573204         THEEL-bar
# ID686217               NaN
# ID660896        AL-cah-lah
# ID606303         PIE-yamps
# ID655316               NaN
# ID669003               NaN
# ID642547               NaN
# ID680777               NaN
# ID663542               NaN
# ID606992              Haas
# ID641927           OH-burr
# ID596146               NaN
# ID663616          LAR-nack
# ID467793               NaN
# ID657746               NaN
# ID656730               NaN
#
# [52 rows x 39 columns]

# %%
def get_avg(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['avg'])

def get_atBats(player_id):
    player = statsapi.player_stat_data(int(player_id), group= "hitting", type="season", sportId=1)
    if player['position'] == 'P':
        return 0
    return float(player['stats'][0]['stats']['atBats'])



averages = player_df.id.apply(get_avg)
player_df = player_df.assign(avg=averages.values)

player_atBats = player_df.id.apply(get_atBats)
player_df = player_df.assign(atBats=player_atBats.values)

# %%
batScore = player_df.avg * player_df.atBats / 30
player_df = player_df.assign(batScore=batScore.values)
    


dayScore = player_df.batScore
player_df = player_df.assign(dayScore=dayScore.values)

dayStatus = player_df.dayScore >= 3
player_df = player_df.assign(dayStatus=dayStatus.values)

valid_hitters = player_df['dayStatus'] == True

player_df.loc[valid_hitters].T
# Out:
#                                                              ID650489  \
# id                                                             650489
# fullName                                                 Willi Castro
# link                                            /api/v1/people/650489
# firstName                                                       Willi
# lastName                                                       Castro
# primaryNumber                                                      50
# birthDate                                                  1997-04-24
# currentAge                                                         27
# birthCity                                                 Rio Piedras
# birthStateProvince                                                NaN
# birthCountry                                              Puerto Rico
# height                                                          6' 1"
# weight                                                            206
# active                                                           True
# primaryPosition     {'code': '4', 'name': 'Second Base', 'type': '...
# useName                                                         Willi
# useLastName                                                    Castro
# middleName                                                     Rafael
# boxscoreName                                                Castro, W
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                         NaN
# mlbDebutDate                                               2019-08-24
# batSide                        {'code': 'S', 'description': 'Switch'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Willi Castro
# nameSlug                                          willi-castro-650489
# firstLastName                                            Willi Castro
# lastFirstName                                           Castro, Willi
# lastInitName                                                Castro, W
# initLastName                                                 W Castro
# fullFMLName                                       Willi Rafael Castro
# fullLFMName                                      Castro, Willi Rafael
# strikeZoneTop                                                    3.57
# strikeZoneBottom                                                 1.62
# nameMatrilineal                                              Capellan
# nickName                                                          NaN
# pronunciation                                                  willie
# avg                                                             0.266
# atBats                                                          346.0
# batScore                                                     3.067867
# dayScore                                                     3.067867
# dayStatus                                                        True
#
#                                                              ID661388  \
# id                                                             661388
# fullName                                            William Contreras
# link                                            /api/v1/people/661388
# firstName                                                     William
# lastName                                                    Contreras
# primaryNumber                                                      24
# birthDate                                                  1997-12-24
# currentAge                                                         26
# birthCity                                              Puerto Cabello
# birthStateProvince                                                NaN
# birthCountry                                                Venezuela
# height                                                         5' 11"
# weight                                                            212
# active                                                           True
# primaryPosition     {'code': '2', 'name': 'Catcher', 'type': 'Catc...
# useName                                                       William
# useLastName                                                 Contreras
# middleName                                                      Jesus
# boxscoreName                                            Contreras, Wm
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2020-07-24
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                       William Contreras
# nameSlug                                     william-contreras-661388
# firstLastName                                       William Contreras
# lastFirstName                                      Contreras, William
# lastInitName                                             Contreras, W
# initLastName                                              W Contreras
# fullFMLName                                   William Jesus Contreras
# fullLFMName                                  Contreras, William Jesus
# strikeZoneTop                                                    3.53
# strikeZoneBottom                                                 1.69
# nameMatrilineal                                              Castillo
# nickName                                                          NaN
# pronunciation                                                     NaN
# avg                                                             0.285
# atBats                                                          386.0
# batScore                                                        3.667
# dayScore                                                        3.667
# dayStatus                                                        True
#
#                                                              ID668930  \
# id                                                             668930
# fullName                                                 Brice Turang
# link                                            /api/v1/people/668930
# firstName                                                       Brice
# lastName                                                       Turang
# primaryNumber                                                       2
# birthDate                                                  1999-11-21
# currentAge                                                         24
# birthCity                                                      Corona
# birthStateProvince                                                 CA
# birthCountry                                                      USA
# height                                                          6' 0"
# weight                                                            188
# active                                                           True
# primaryPosition     {'code': '4', 'name': 'Second Base', 'type': '...
# useName                                                         Brice
# useLastName                                                    Turang
# middleName                                                      Craig
# boxscoreName                                                   Turang
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                      False
# draftYear                                                        2018
# mlbDebutDate                                               2023-03-30
# batSide                          {'code': 'L', 'description': 'Left'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Brice Turang
# nameSlug                                          brice-turang-668930
# firstLastName                                            Brice Turang
# lastFirstName                                           Turang, Brice
# lastInitName                                                Turang, B
# initLastName                                                 B Turang
# fullFMLName                                        Brice Craig Turang
# fullLFMName                                       Turang, Brice Craig
# strikeZoneTop                                                    3.17
# strikeZoneBottom                                                 1.48
# nameMatrilineal                                                   NaN
# nickName                                                          NaN
# pronunciation                                                     NaN
# avg                                                             0.272
# atBats                                                          345.0
# batScore                                                        3.128
# dayScore                                                        3.128
# dayStatus                                                        True
#
#                                                              ID642715
# id                                                             642715
# fullName                                                 Willy Adames
# link                                            /api/v1/people/642715
# firstName                                                       Willy
# lastName                                                       Adames
# primaryNumber                                                      27
# birthDate                                                  1995-09-02
# currentAge                                                         28
# birthCity                                                    Santiago
# birthStateProvince                                                NaN
# birthCountry                                       Dominican Republic
# height                                                          6' 1"
# weight                                                            219
# active                                                           True
# primaryPosition     {'code': '6', 'name': 'Shortstop', 'type': 'In...
# useName                                                         Willy
# useLastName                                                    Adames
# middleName                                                     Rafael
# boxscoreName                                                   Adames
# gender                                                              M
# isPlayer                                                         True
# isVerified                                                       True
# draftYear                                                         NaN
# mlbDebutDate                                               2018-05-22
# batSide                         {'code': 'R', 'description': 'Right'}
# pitchHand                       {'code': 'R', 'description': 'Right'}
# nameFirstLast                                            Willy Adames
# nameSlug                                          willy-adames-642715
# firstLastName                                            Willy Adames
# lastFirstName                                           Adames, Willy
# lastInitName                                                Adames, W
# initLastName                                                 W Adames
# fullFMLName                                       Willy Rafael Adames
# fullLFMName                                      Adames, Willy Rafael
# strikeZoneTop                                                    3.44
# strikeZoneBottom                                                 1.71
# nameMatrilineal                                                  Luna
# nickName                                                      The Kid
# pronunciation                                              ah-DAH-mes
# avg                                                             0.249
# atBats                                                          377.0
# batScore                                                       3.1291
# dayScore                                                       3.1291
# dayStatus                                                        True

# %%
HOST = 'https://statsapi.mlb.com'
url = HOST + df.loc[0,'link']
r = requests.get(url=url).json()
player_df = pd.DataFrame(r['gameData']['players'])
player_df_all = pd.DataFrame(['players'])
player_df = player_df.T
